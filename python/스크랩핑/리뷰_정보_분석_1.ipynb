# %%
# routes.py
import pandas as pd
from flask import Blueprint, jsonify, request
from sqlalchemy import create_engine
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from konlpy.tag import Okt

recommend_bp = Blueprint('recommend_bp', __name__)

# SQLAlchemy 엔진 생성
engine = create_engine('oracle+cx_oracle://kyb:1111@localhost:1521/xe')

# 데이터 가져오기
query_zero = "SELECT id, info, hash_tags, name FROM zero"
query_zero_re = "SELECT id, review, review2, review3, review4, review5, review6 FROM zero_re"

df_zero = pd.read_sql(query_zero, con=engine)
df_zero_re = pd.read_sql(query_zero_re, con=engine)

# 리뷰 데이터 병합
df_zero_re['combined_reviews'] = df_zero_re.apply(lambda row: ' '.join(row[['review', 'review2', 'review3', 'review4', 'review5', 'review6']].values.astype(str)), axis=1)

# zero 테이블과 zero_re 테이블 병합
df_merged = pd.merge(df_zero, df_zero_re, on='id')

# 형태소 분석기 초기화
okt = Okt()

# 한국어 텍스트 전처리 함수
def preprocess_korean_text(text):
    tokens = okt.morphs(text)
    return ' '.join(tokens)

# 정보, 해시태그, 리뷰 데이터 병합 (None 값을 빈 문자열로 처리)
df_merged['combined_text'] = df_merged.apply(lambda row: ' '.join([str(row['info']) if row['info'] else '', 
                                                                   str(row['hash_tags']) if row['hash_tags'] else '', 
                                                                   str(row['combined_reviews']) if row['combined_reviews'] else '']), axis=1)

# 병합된 텍스트 데이터 전처리
df_merged['processed_text'] = df_merged['combined_text'].apply(preprocess_korean_text)

# TF-IDF 벡터화
tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(df_merged['processed_text'])

# 코사인 유사도 계산
cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)

# 추천 함수 정의
def get_recommendations(index, cosine_sim=cosine_sim):
    sim_scores = list(enumerate(cosine_sim[index]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:6]  # 상위 5개의 유사한 리뷰 선택
    review_indices = [i[0] for i in sim_scores]
    return df_merged.iloc[review_indices]

@recommend_bp.route('/recommend/<int:index>', methods=['GET'])
def recommend(index):
    recommendations = get_recommendations(index)
    return jsonify(recommendations[['id', 'name', 'info', 'hash_tags', 'review', 'review2', 'review3', 'review4', 'review5', 'review6']].to_dict(orient='records'))
# Out:
#    id                                               info  \
# 0  51  남양주 덕소 최초의 제로웨이스트샵\n'용기내 담아가게' 입니다.\n\n저희 매장은 ...
# 1  52  제로웨이스트 친환경 소분샵 입니다.\n친환경세탁세제 , 섬유유연제, 섬유탈취제,진드...
# 2  53  제로웨이스트 바람가게입니다.\n 제로웨이스트란 생활 속에서 배출되는 쓰레기를 최소화...
# 3  58  2021년 7월 10일 오픈한 제로웨이스트 오프라인 플랫폼 입니다. 쓰레기 배출을 ...
# 4  59  가치가게는 세류동에 위치한 복합문화공간으로 카페와 제로웨이스트 상점을 겸하고 있습니...
#
#                                    hash_tags          name
# 0                                          #  남양주_용기내 담아가게
# 1          #소분샵, #리필스테이션, #배달, #천연세제, #천연탈취제      남양주_친한가게
# 2        #제로웨이스트, #부천소품샵, #친환경, #리필스테이션, #역곡       부천_바람가게
# 3    #성남제로웨이스트샵, #분당제로웨이스트샵, #리필샵, #친환경, #비건     성남_슬기로운생활
# 4  #공정무역커피, #제로웨이스트상점, #유기농과일청, #공간대여, #자원순환       수원_가치상점
#    id                                             review  \
# 0  30  제로웨이스트 매장이에요. 여러 샤워 비누와 다양한 친환경 제품이 있어요. 구경하기 ...
# 1  32             제로웨이스트 소품샵~\n가격 부담스럽지 않아서 어쩌다 보니 하나 겟~
# 2  34  제로웨이스트, 친환경 제품 등등 다양한 물품이 가득한곳. 특히 차(옥수수, 작두콩)...
# 3  36  인테리어 예뻐서 들어갔다가 쇼핑하고 온 곳 \n샴푸바 샀어요~! \n사면서도 지구 ...
# 4  40                                              친절하세요
#
#                                              review2  \
# 0  친구 선물, 제가 쓸 물건들 구매했습니다!\n이 날 이후로 꾸준히 쓰고 있어요!!\...
# 1                                         식빵수세미 귀여워요
# 2                          지구도살리고~~~다양한  수거함도 있어요~~~
# 3  귀여운 당근 양말과 초콜렛 구입했어요 🧑‍🌾🥕\n키링이랑 다양한 실용적인 물건들이 ...
# 4  가까운ㄷ ㅔ에 리필샾 있어서 좋아요 물건도 다양하고 친절하게 하나하나 절명해주시고욤...
#
#                                              review3  \
# 0                                                 ^^
# 1          계단이 가파르긴하지만,, 위층 아래층 꼼꼼히 잘 둘러봤어요, 예쁜게 많아여
# 2                                         고무장갑이 좋아요.
# 3  바오밥나무 퍼퓸 샴푸바, 현무암 비누받침 샀어요. 친환경 제품이 굉장히 다양해서 좋...
# 4  걸어서 갈 수 있는 거리에 있어서 좋아요. 물건들 질도 좋고 매니저님도 친절하세요....
#
#                                              review4  \
# 0                                     생각보다 엄청 낡앗움 ㅠㅠ
# 1              트리트먼트바 구매했는데 잘 쓰고 있어요~~\n조용히 구경하기 좋아요
# 2                                         좋은상퓸들이 많아요
# 3  리필스테이션 이용하는게 참 지구를 위해 좋은 아이디어라구 생각이들었고 낭비 없이 살...
# 4                           집 근처에 제로웨이스트샵이 생겨서 좋아요 👍
#
#                                       review5  \
# 0  특색있는 소품들, 생활용품들이 많더라고요.\n에코백 사서 잘 사용중이에요^^
# 1                    상품이 많고 환경을 아끼는 물건들이 많아요!
# 2                                       좋아요👍🏼
# 3                               제로웨이스트 제품이많아요
# 4                    친절하시고 물건도 좋아요. 꼭 재방문할게요!
#
#                                              review6
# 0  필요한 물품들이 있어서 들렀는데 환경을 생각한 제로웨이스트 제품들을 살 수 있어서 ...
# 1       다양한 상품 중에 맘에 드는 가방이 있어서 바로 샀어요ㅋㅋㅋ 아주 만족스럽습니다
# 2                                    자연을 살리는 지구마을이에요
# 3                              튜브짜개 노랑노랑\n온몸비누 자몽향킁킁
# 4                                               None
#      id          name                                               info  \
# 10    3      서울_1.5도씨  건강한 지구 건강한 나의 삶을 지키기 위해\n1.5 라이프스타일 속 제로웨이스트 샵...
# 58   30         서울_원점  -성수동 제로웨이스트샵 원점.\n-플라스틱과 쓰레기 없는 가게.\n-플라스틱 업사이...
# 40  107      대구_그린그루브  카페그린그루브는 건강한 음료와 제로웨이스트 상품을 판매중이며 사람과 환경이 지속가능...
# 78  120        안동_오롯이  아름다운 문경새재길을 걷고 잠시 쉬어가는 곳~문경 종합온천 옆 간단한 음료를 마시며...
# 85  141  제주_지구별가게 노형점  제로웨이스트 리빙랩, 지구별가게\n내 몸과 지구를 살리는 소소한 즐거움, 소락\n\...
#
#                                        hash_tags  \
# 10                                             #
# 58         #제로웨이스트, #제로웨이스트샵, #플라스틱프리, #친환경, #체험
# 40                                             #
# 78          #제로웨이스트샵, #카페, #다육, #친환경생활용품, #문경소품샵
# 85  #제로웨이스트샵, #제로웨이스트스토어, #리필스테이션, #다회용품점, #면생리대
#
#                                                review  \
# 10  해피해빗에서 주는 리필스테이션 20%할인 쿠폰으로 샴푸를 사려고 처음 방문했어요.\...
# 58  제로웨이스트 매장이에요. 여러 샤워 비누와 다양한 친환경 제품이 있어요. 구경하기 ...
# 40  커피 맛있구 스콘도 맛있어요 매장이 친환경이라 눈길이 가요 깔끔한 느낌의 인테리어도...
# 78                                                  ㅎ
# 85                                대파행주   구입  소재 참 좋아요
#
#                                               review2  \
# 10  병뚜껑도 재활용할 수 있고, 다양한 제로웨이스트 제품이 있어서 좋아요😁 아기자기한 ...
# 58  친구 선물, 제가 쓸 물건들 구매했습니다!\n이 날 이후로 꾸준히 쓰고 있어요!!\...
# 40  매일 아침 출근길에 들리는 곳입니당!\n커피가 정말 맛있고 쿠키랑 디저트도 맛있어요...
# 78  카페를 겸한 작은 소품점으로, 작은 생활용품 주방용품 다육이 등을 전시 판매하고 있...
# 85  친환경 제품을 파는 곳이라 궁금해서 방문 해봤어요\n면 생리대는 관리할 엄두가 안나...
#
#                                               review3  \
# 10                                     아기세제 구매했는데 좋아요
# 58                                                 ^^
# 40           매장도 깨끗하고 커피도 맛있어요! 친환경 제품들도 살 수 있어서 좋네요~
# 78  여기 분위기도 있고 제로웨이스트 매장입니다.\n커피. 라떼 맛있습니다.\n편집샵으로...
# 85                                          좋은상품이 많아요
#
#                                               review4  \
# 10                                      바닐라라떼 진짜 맛있어요
# 58                                     생각보다 엄청 낡앗움 ㅠㅠ
# 40  오랜만에 수목원 근처에 점심 먹으러 왔다가 밖에서 보니 너무 깔끔해보이는 제로웨이스...
# 78  예쁜 소품과 커피를 함께할 수 있는 곳이라 구경하는 재미도 있었고 조용히 차 마시기...
# 85  네이버 지도에 제로웨이스트샵 목록을 저장해 뒀었는데 여행 중 근처에 있어서 방문했어...
#
#                                               review5  \
# 10                                            제로웨이스트샵
# 58         특색있는 소품들, 생활용품들이 많더라고요.\n에코백 사서 잘 사용중이에요^^
# 40  회사앞에 이런 카페 있는 것 너무 좋아요~ 늘 라떼 마시는데 우유가 고소해서, 커피...
# 78  문경 소품샵 오롯이🤩\n사장님 정말 친절하세요😀\n문경제로웨이스트샵 소품들이 많아요...
# 85  지구를 지키기 위해 저도 텀블러랑 용기내 좋아하는데\n지켜백이 있는 곳이 있네요! ...
#
#                                               review6
# 10  친환경 관련 제품들을 판매한다길래 구경갔다가 살림생활하는데 친환경 실천하고싶기도 해...
# 58  필요한 물품들이 있어서 들렀는데 환경을 생각한 제로웨이스트 제품들을 살 수 있어서 ...
# 40  💚 그린 그루브💚\n\n매장도 깔끔하고 \n커피도 저렴하고 맛있었어요.\n또 방문해...
# 78  환경에 도움이 되는 물건들을 구매할 수 있어 좋았어요 가격도 합리적이고 품질도 전부...
# 85  요즘 제로웨이스트에 관심이 생겨서 찾아보다 발견한 가게인데 친절하시고 넘 좋은거 같...
