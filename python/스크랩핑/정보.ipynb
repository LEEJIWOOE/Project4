# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.support.ui import WebDriverWait

import time
from datetime import datetime
from bs4 import BeautifulSoup

import cx_Oracle


# 데이터베이스 연결 설정
connection = cx_Oracle.connect('kyb/1111@localhost:1521/xe')
cursor = connection.cursor()

# 웹드라이버 설정
options = Options()
options.add_experimental_option("detach", True)
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=options)
driver.get("https://map.naver.com/v5/search")
time.sleep(3)  # 페이지 로딩 대기

# 검색어 목록 가져오기
cursor.execute('SELECT id, search_name FROM zero') 
data_list = [(row[0], row[1]) for row in cursor.fetchall()]

# frame 변경 메소드
def switch_frame(frame):
    driver.switch_to.default_content()  # frame 초기화
    driver.switch_to.frame(frame)  # frame 변경

# 현재 스크래핑된 HTML 요소 스냅샷 만드는 함수 (이거 있어야지 나중에 안될때 알아보기편함)
def save_html_snapshot(page_str, file_prefix):
    current_date = datetime.now().strftime('%y%m%d_%H%M%S')
    file_path = f'{file_prefix}_{current_date}.html'
    soup = BeautifulSoup(page_str, 'html.parser')
    pretty_html = soup.prettify()
    with open(file_path, 'w', encoding='utf-8') as file:
        file.write(pretty_html)

# 해당 요소 찾을 때까지 10초 대기
def time_wait(num, code):
    try:
        wait = WebDriverWait(driver, num).until(
            EC.presence_of_element_located((By.CSS_SELECTOR, code)))
        return wait
    except Exception as e:
        print(f"{code} 태그를 찾지 못하였습니다. {e}")
        return None

# 각 검색어에 대해 작업 수행
for id, search_name in data_list:
    try:
        # 검색창 찾기 및 검색어 입력
        search_box = time_wait(10, 'div.input_box > input.input_search')
        if search_box:
            search_box.clear() #검색창 깨끗하게
            search_box.send_keys(search_name) #검색어 입력
            search_box.send_keys(Keys.ENTER) # 엔터누르기
            time.sleep(3)  # 검색 결과 로딩 대기

            # 검색 결과 프레임으로 전환 및 스냅샷 저장
            switch_frame('searchIframe')
            save_html_snapshot(driver.page_source, f"search_result_{id}") #저장이름

            # 정보 탭 클릭 및 프레임으로 전환 전 스냅샷 저장
            switch_frame('entryIframe')
            save_html_snapshot(driver.page_source, f"before_info_tab_click_{id}")

            info_tab_found = False
            try:
                tabs = driver.find_elements(By.XPATH, '//a[@role="tab"]//span') # 홈 리뷰 정보 등 탭있는곳 중에서
                for tab in tabs:
                    if tab.text == '정보':  #정보탭 찾기
                        driver.execute_script("arguments[0].scrollIntoView();", tab)
                        driver.execute_script("arguments[0].click();", tab)
                        info_tab_found = True
                        break
            except Exception as e:
                print(f"정보 탭을 찾지 못하였습니다: {e}")

            if not info_tab_found:
                print(f"정보 탭을 찾지 못하였습니다 for id: {id}")
                continue

            time.sleep(3)  # 정보 탭 로딩 대기
            save_html_snapshot(driver.page_source, f"info_{id}")

            # "펼쳐보기" 버튼 클릭
            more_buttons = driver.find_elements(By.CLASS_NAME, 'OWPIf')
            for btn in more_buttons:
                try:
                    driver.execute_script("arguments[0].click();", btn)
                    time.sleep(1)  # 버튼 클릭 후 로딩 대기
                except Exception as e:
                    print(f"Failed to click '펼쳐보기' for ID {id}: {e}")

            # 업데이트된 페이지 소스 가져오기
            updated_page_source = driver.page_source
            save_html_snapshot(updated_page_source, f"updated_info_{id}")

            # 정보와 해시태그 추출 및 데이터베이스 저장
            soup = BeautifulSoup(updated_page_source, 'html.parser')
            info = ''
            hash_tags = []

            info_element = soup.find("div", class_="T8RFa")
            hash_tag_elements = soup.find_all("span", class_="RLvZP")
            
            if info_element:
                info = info_element.get_text(separator=' ').strip()

            if hash_tag_elements:
                hash_tags = [element.get_text(separator=' ').strip() for element in hash_tag_elements]

            # 해시태그를 '#태그1, #태그2' 형식으로 변환
            hash_tags_str = '#{}'.format(', #'.join(hash_tags))

            # 디버깅: 추출된 정보와 해시태그 출력
            print(f"ID {id}: Extracted info and hash tags")
            print(f"Info: {info}")
            print(f"Hash Tags: {hash_tags_str}")

            # 데이터베이스에 정보와 해시태그 저장
            try:
                print("Binding variables for SQL query:")

                cursor.execute("""
                    UPDATE zero
                    SET info = :info, hash_tags = :hash_tags
                    WHERE id = :id
                """, {
                    'info': info,
                    'hash_tags': hash_tags_str,
                    'id': id
                })
                connection.commit()
                print(f"Successfully stored info and hash tags for ID {id} in the database")  # 데이터베이스 저장 성공 로그
            except cx_Oracle.DatabaseError as db_e:
                error, = db_e.args
                print(f"Database error occurred while storing info and hash tags for ID {id}: {error.message}")
                print(f"SQL Query: {cursor.statement}")
                print(f"Bound Variables: {cursor.bindvars()}")
            except Exception as e:
                print(f"Unexpected error occurred while storing info and hash tags for ID {id}: {e}")
    except Exception as e:
        print(f"Error occurred while processing search_name '{search_name}' with id '{id}': {e}")

    # 검색어 처리 후 브라우저 새로 고침
    driver.get("https://map.naver.com/v5/search")
    time.sleep(3)

# 드라이버 종료 및 연결 종료
driver.quit()
cursor.close()
connection.close()
# Out:
# ID 1: Extracted info and hash tags
# Info: 더 나은 지구가 더 나은 우리를 만듭니다.
# 기후위기 시대에 살고 있는 우리와 다음세대를 위해 사람과 환경에 무해한 지속가능한 제품을 소개하고 리필스테이션, 자원순환소 운영, 플로깅 및 환경 강의 등 로컬 기반의 환경 캠페인을 도모합니다.
# 도시 재생과 지역의 상생을 목표로 더 좋은 지역,
# 더 좋은 지구를 만드는 데 선한 영향을 더하고자 합니다.
# 완벽한 소수보다 불완전한 다수가 함께 행동 할 수 있도록, 더 가까이, 더 쉽게, 더 나은 가치 소비의 삶을 실천하는 제로웨이스트 라이프스타일 편집샵.
#
# 취급품목: 친환경 생활용품, 세제류 리필
# Hash Tags: #제로웨이스트, #편집샵, #친환경, #리필스테이션, #자원순환
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 1 in the database
# ID 3: Extracted info and hash tags
# Info: 건강한 지구 건강한 나의 삶을 지키기 위해
# 1.5 라이프스타일 속 제로웨이스트 샵 겸 카페 1.5도씨 입니다.
# 우리가 사는 동네에서 커피도 한잔하며 제로웨이스트를 알아가는
# 곳이며 우리의 일상을 공감하며 문화,예술 워크숍을 진행하는 곳이기도 합니다.
#
# 화장품 , 세제를 그람 당 필요한 만큼 담아갈 수 있는 리필스테이션
# 여러가지 식료품, 친환경 식자재 그로서리 리필스토어 입니다.
#
# 1.5도씨에서 1.5라이프스타일을 함께 하며
# 나의 건강한 삶을 만들고 자연과 동물 그리고 우리가 모두와
# 마음을 공감하며 지속 가능한 삶을 경험해 보세요~^^
# Hash Tags: #
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 3 in the database
# ID 4: Extracted info and hash tags
# Info: 건강과 환경을 모두 지킬 수 있는
# 지속가능한
# 에코 라이프스타일을 만들고,
# 정착시켜 나갑니다.
#
# - 환경호르몬이 나오는 포장지 쓰지 않기
# - 배송가방을 사용하여 택배상자 줄이기
# - 다회용기를 사용하여 쓰레기 줄이기
#
# 우리가 만들어가는 움직임은
# 물 한 모금의 양 30ml처럼
# 아주 작을 순 있지만
#
# 동시에 우리의 움직임은,
# 물 한 모금의 양 30ml처럼
# 모두에게 꼭 필요한 것입니다.
#
# 30ml가 만드는
# 초록빛 물결은
#
# 우리가 살아가는 세상을
# 더욱 아름다운 곳으로
# 만들어 갑니다!
# Hash Tags: #바이소셜, #인증제품쇼핑몰, #에코라이프스타일, #제로웨이스트
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 4 in the database
# ID 5: Extracted info and hash tags
# Info: ※지속가능한 봄을 위한 생활문화 공간: 제로웨이스트 공방 꽃삼월에서는
# -DIY 천연화장품, 제로웨이스트 클래스 운영
# -리필스테이션, 자원순환, 무포장 제품 판매
#
# [DIY화장품 클래스, 예약제]
# [리필 및 자원순환 이용시 회당 2,000원의 탄소중립 실천 포인트 적립]
# *화장품류, 세제류, 원료 등의 리필 구매
# *수거 자원: 종이팩(우유,두유팩), 플라스틱용기(PE/PP/PS), 폐전선 및 폐휴대폰, 브리타폐필터
# !!포인트 적립 가능한 자원!! 종이팩 및 플라스틱 용기 1kg이상 또는 폐휴대폰
#
# -탄소중립실천 녹색실천 포인트 적립을 위한 회원가입 필수, (앱)해피해빗 또는 보틀클럽 이용 포인트 적립 가능, (플라스틱용기)업사이어티의 경우 자제 포인트 적립 가능!
# Hash Tags: #원데이수업, #답십리비누공방, #제로웨이스트가게, #리필스테이션, #청량리비누공방
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 5 in the database
# ID 6: Extracted info and hash tags
# Info: 대안생활 <공기>는 자연과 우리의 일상을 생각하는 제로웨이스트샵입니다. 비움의 습관을 통해 자연을 배려합니다.
#
# 제로웨이스트샵/세제소분샵/커뮤니티앵커스토어/플라스틱제로/쓰레기 없는 습관/필환경
#
# 소소한 생활 혁신, 마을이 대안이다.
# Hash Tags: #제로웨이스트샵, #세제소분샵, #플라스틱제로, #필환경, #커뮤니티앵커스토어
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 6 in the database
# ID 7: Extracted info and hash tags
# Info: 건강한 소비가 만드는 건강한 지구
# Sustainable Planet for All
#
# 더피커(thepicker)는,
# 건강한 자연의 소산을
# 환경에 유해한 포장 없이 순환 가능하도록
# 세심하게 고르는 사람을 의미합니다.
#
# 2016년, 포장없는 채식 그로서란트로 시작한 더피커는
# 국내 최초 제로웨이스트샵이자
# 친환경 그로서리 리필스토어로
# 현재까지 다양한 주체들과 함께
# 제로웨이스트 사례를 만들고,
# 건강한 소비문화 회복을 위해 노력하고 있습니다.
#
# 더피커에서
# 자연과 동물, 사물, 그리고
# 우리 모두와 공감하는 마음을 통해
# 건강한 에피소드를 만들며
# 지속 가능한 경험을 담아보세요. :)
# Hash Tags: #제로웨이스트, #제로웨이스트샵, #플라스틱프리, #자원순환, #소비문화회복
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 7 in the database
# ID 8: Extracted info and hash tags
# Info: 지구와 다음세대, 생명과 환경을 사랑으로 지켜나가기 위한 제로웨이스트 라이프스타일 플랫폼
# 리필스테이션 및 제로웨이스트 용품 판매
# Hash Tags: #제로웨이스트, #플라스틱프리, #세제소분샵
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 8 in the database
# ID 9: Extracted info and hash tags
# Info: 제로 웨이스트 상점
# 원데이클래스
# Hash Tags: #대나무칫솔, #친환경, #제로웨이스트
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 9 in the database
# ID 10: Extracted info and hash tags
# Info: 도돌이상점은 친환경 제품을 판매하는 제로웨이스트샵입니다.
#
# 상호 도돌이는 반복을 나타내는 의미로 제품의 용기나 포장재 등을 반복 사용하여 쓰레기와 환경오염을 조금이나마 줄여보자는 의미를 담아 지었습니다.
#
# 도돌이상점에서는 레스웨이스트를 실천하며 환경을 위해 불필요한 쓰레기 배출량을 줄이고 건강한 자원의 순환을 지향합니다.
#
# 저희 상점에 오실때에는
# * 쇼핑백, 에코백 등 장바구니 가져오세요.
# * 세제, 샴푸 등 리필해가실 용기 깨끗이 씻어 말려오시면 좋아요^^
# * 작은 PP플라스틱, 병뚜껑 수거합니다.
# * 깨끗이 씻어 말린우유팩, 멸균팩(두유, 주스택 등) 수거합니다.
# Hash Tags: #제로웨이스트샵, #리필스테이션, #제로웨이스트, #친환경, #에코
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 10 in the database
# ID 11: Extracted info and hash tags
# Info: 스토어36.5노원점새록은 노원구의 사회적경제기업제품 판로의 거점매장으로 명실상부 9년째 성업중에서 있습니다.
#
# 전국 3000개가 넘는 사회적경제기업들의 좋은 제품들을 오프라인 매장인 스토어36.5노원점에서 직접 만져보고 먹어볼 수 있는 쇼룸의 형식으로 사회적기업제품들을 만나고 있습니다.
#
# 더욱이 매장에서 함께 운영하고 있는 카페에는 우리나라 공정무역의 구심점 역할을 하고 있는 <아름다운커피>의 향기로운 원두를 사용하여 많은 고객분들에게 공정무역의 올바른 가치와 취지에 대해서 조금이나마 알려드리고 있습니다.
#
# 무포장가게새록
#
# 최근엔 샵인샵 개념의 무포장가게새록을 오픈하여 과대포장과 플라스틱 사용을 줄여 생활 속 쓰레기도 줄이면서
# 순환경제와 자원순환 문화가 지속적으로 확산되어 더 살기 좋은 힐링 노원이 되고 더 나아가 지구환경 보호에 앞장서는 일상의 환경지킴이 역할을 하고 있습니다.
#
# 스토어36.5노원점새록이 여러분들과 늘 함께 우리 삷과 지구를 돌보는 일상을 차곡차곡 쌓아갑니다. 함께 해 주셔요^^
#
# 입점문의 .상품문의. 종이팩,멸균팩 수거 문의 등 언제라도 반갑게 인사드립니다.
# 전화: 02-3391-3650
# 메일주소: store365nw@gmail.com
# Hash Tags: #무포장가게새록, #사회적경제기업제품판매, #제로웨이스트, #자원순환, #한국사회적기업진흥원
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 11 in the database
# ID 12: Extracted info and hash tags
# Info:
# Hash Tags: #제로웨이스트, #친환경, #무포장가게새록, #사회적기업, #자원순환
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 12 in the database
# ID 14: Extracted info and hash tags
# Info: 동네책방 지구불시착
# Hash Tags: #문구, #일반서적, #독립출판
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 14 in the database
# ID 15: Extracted info and hash tags
# Info: '행복중심 서울동북생협'은 생산자와 소비자의 협동 및 대안 생활운동을 전개하여 지속가능한 사회의 실현에 기여합니다.
# "무포장가게 새록"이 함께 하게 되어 1차 농산물들을 무포장으로 구입가능하게 하고자 노력하고 있습니다.
# Hash Tags: #제로웨이스트샵, #유기농, #친환경, #제로웨이스트, #행복중심생협
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 15 in the database
# ID 16: Extracted info and hash tags
# Info:
# Hash Tags: #유기농축산물, #환경가공식품
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 16 in the database
# ID 17: Extracted info and hash tags
# Info: 안녕하세요! 중랑구 제로웨이스트샵 보탬상점입니다. 환경을 살리고 지구와 마을에 보탬이 되는 친환경 생활용품과 리필소분세제류, 되살림 물품들을 구입하실 수 있습니다. 친환경용품을 이용한 워크샵과 교육도 준비 중입니다. 마을활동가가 힘을 보태 열게 된 보탬상점에서 환경을 생활에서 실천하는 여러분을 기다리고 있겠습니다.
# Hash Tags: #제로웨이스트샵, #되살림물품, #소분리필세제
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 17 in the database
# ID 18: Extracted info and hash tags
# Info: Less waste & Plant-based Cafe / Grocery / Shop 더 나은 일상을 제안하는 카페, 그로서리, 숍입니다. 보틀팩토리가 운영하고 있어요.
# Hash Tags: #
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 18 in the database
# ID 20: Extracted info and hash tags
# Info: 100% 식물성 재료를 이용하는 비건 카페 달냥입니다 :)
# 휴무 및 기타 공지, 홀케이크 예약은 인스타로 부탁드립니다!
# Hash Tags: #
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 20 in the database
# ID 21: Extracted info and hash tags
# Info: 니가 그런다고 지구가 달라지는
# 선택지
#
# 작은 플라스틱 구하기 - PP성내
# 재활용이 가능하지만 재활용이 되지 않는 '작은 플라스틱'을 수거합니다.
#
# 플라스틱 공방 - 플플 PLPL
# 한 번 쓰고 버리는 플라스틱을 '오래도록 쓸 수 있는 오브제'로 만들어냅니다.
#
# 플라스틱 업사이클링 클래스 - Z클
# 재활용 플라스틱으로 작은 오브제를 만드는 '체험 프로그램'을 운영합니다.
#
# [작은 플라스틱 수거 품목]
# - 손바닥보다 크기가 작은(약 18cm 이하) 플라스틱 'PP, PE'
#   (예시: 병뚜껑, 두부곽, 작은 배달용기, 요거트통, 치약뚜껑, 약병 등)
# - 분리배출 표시가 있는 플라스틱을 깨끗하게 씻어서 가져와 주세요. :)
#
# [리워드 ('24년 3월부터 시행)]
# - 선택지 멤버십이 되시면 Z-쿠폰에 스탬프를 찍어드립니다.
# - 플라스틱 100g 당 스탬프 1개
# - 스탬프를 10개 모으면 '재활용 플라스틱 비즈'를 선물로 드립니다.
# ※ 종류를 알 수 없어 재활용이 불가능한 플라스틱, 지저분한 플라스틱은 무게 산정에서 제외됩니다.
#
# [협업 문의]
# 선택지는 친환경 생활 실천을 위한 활동을 지원합니다.
# 선택지와 함께 캠페인, 이벤트 개최, 콜라보 굿즈 제작을 원하시면
# 인스타그램 DM 또는 suntackz@gmail.com 으로 문의해주세요.
# Hash Tags: #병뚜껑재활용, #재활용, #업사이클링, #업사이클링공방, #클래스
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 21 in the database
# ID 22: Extracted info and hash tags
# Info: 아름다운 참여를 통한 이로운 사업으로 더 나은 문화를 만드는 사회적기업, 아름다운가게입니다.
#
# 아름다운가게는 시민 여러분의 소중한 기증품을 판매하여 우리 사회의 지치고 소외된 이웃을 돕습니다.
# - 물품기부 문의 : 1577-1113
# 일주일에 4시간, 세상을 아름답게 만드는 아름다운가게 자원봉사를 시작하세요.
# - 아름다운가게 자원봉사 문의는 해당 매장으로 연락부탁드립니다.
# Hash Tags: #중고물품, #자원봉사, #공익상품, #업사이클링, #물품기부
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 22 in the database
# ID 23: Extracted info and hash tags
# Info: 순환지구를 위한 제로웨이스트숍
#
# 1. 소분제품_식품류
# 1) 곡류: 유기농백미, 유기농현미, 유기농찰현미, 무농약 귀리, 찰보리, 무농약찰흑미, 무농약 혼합잡곡
# 2) 향신료: 통후추, 페페론치노, 바질, 로즈마리, 오레가노, 큐민
# 3) 가공 식품류: 그래놀라
#
# 2. 소분제품_세제류
# (세탁세제) 에코라운드 중성세제, 에코라운드 섬유유연제, 브라운리브스 세탁세제(약알칼리성)
# (주방세제) 코코리제주 주방세제
# (소다류) 구연산, 과탄산소다, 베이킹소다
#
# 3. 완제품_식료품
# 파아프 템페(비건), 위미트 프라이드(비건), 이노센트 팔라펠(비건), 댄싱컴퍼니 애플사이더 등 유기농 또는 비건 식료품
# Hash Tags: #제로웨이스트, #비건, #전통주, #제로웨이스트샵, #식료품점
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 23 in the database
# ID 24: Extracted info and hash tags
# Info: 아로마테라피의 정수를 담아 건강한 아름다움을 표방하는 지속가능한 뷰티&라이프 브랜드
#
# 아로마티카 플래그십 스토어 AROMATICA SINSA
#
# 공간대여 문의 환영 (팝업, 전시 갤러리 등)
# Hash Tags: #리필스테이션, #제로웨이스트, #아로마티카, #플래그십스토어, #아로마테라피
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 24 in the database
# ID 25: Extracted info and hash tags
# Info: 제로웨이스트샵 안녕상점은 자원순환센터(작은플라스틱, 우유팩,멸균팩, 종이백, 플라스틱 칫솔 등 모음), 제로웨이스트물품 판매, 선물세트 판매, 각종 교육, 체험을 이용하실 수 있는 공간입니다.
# Hash Tags: #제로웨이스트선물세트, #세제류소분, #식품소분, #자원순환센터, #비누제작
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 25 in the database
# ID 26: Extracted info and hash tags
# Info: 국내 최초 리필스테이션 알맹상점
#
# 알맹상점은 한국형 제로웨이스트 샵의 긍정적 기준을 제시하며 전국의 다양한 제로웨이스트 샵들과 연대합니다.
# 서울 망원점은 국내에서 가장 다양한 제로웨이스트 제품과 리필 벌크 제품을 갖추고 있습니다.
# 서울역점은 일회용품 없는 비건 카페와 제로웨이스트 매장을 운영합니다.
# Hash Tags: #플라스틱프리, #제로웨이스트, #리필, #소분, #친환경
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 26 in the database
# ID 27: Extracted info and hash tags
# Info: 껍데기는가라, 알맹이만 오라, 쓰레기를 줄이려 노력하는 가게
# 알맹상점입니다. 22년 부터 리필도 가능합니다 (샴푸, 린스,바디워시, 핸드워시 4종류)
#
# 서울역옥상정원에 위치한 리스테이션
#
# 1. '일회용 없는 (쓰레기없는) 카페'를 운영
# 2022년 시행예정인 컵 보증금제 시행전 체험을 하는공간입니다.
# 개인 텀블러 지참시 모든음료 1000원 할인됩니다. 용기 없을시 보증금 2000원이 추가 결제됩니다. 컵 반납시 2000원 리펀됩니다.
#
# 2. 알맹 커뮤니티 회수센터 운영
# 재활용이 어려운 물품들을 회수하고 있습니다. (회수품목 변경시 인스타, 블로그 참고)
#
# 1) 씻고 말린 우유팩, 테트라팩 (화장지로 재활용)
# 2) 말린 원두가루(커피화분, 커피 연필로 재활용)
# 3) PP,PE 재질 작은 플라스틱, 병뚜껑(플라스틱 치약 짜개로 재활용)
# 4) 사용 후 브리타 필터(정수기)
# 5) 실리콘 단일 재질 (데펜소 도시락 통 패킹에 재활용)
# 6) 세척한 재사용 유리병 (리필스테이션에서 리필 용기로 재사용)
# 7) 크래용 (리크래용)
# (회수 품목은 양에 따라 변동될 수 있음)
#
# 3. 리필 매장을 늘리기 위한 노력 (식약처 샌드박스 규재 시범운영)
# 단순 리필은 교육을 듣고 관리감독할 수 있도록 하는 체계를 만들어내는데 목소리를 내었고
# 2년동안(~2024년까지) 진행되며, 자격증 시험이 아닌 위생교육을 듣고 운영할 수 있도록 규재사업시행중입니다.
#
# 워시류 4종류 (샴푸, 린스, 바디워시, 핸드워시) 리필 가능
# 용기를 들고 오시면 리필이 가능합니다. (크림류, 스킨토너는 리필불가, 망원점에만 리필이 가능합니다)
#
# 준비물 : 깨끗해서 물기 없이 바짝 말려오신 용기
# Hash Tags: #제로웨이스트샵, #서울역옥상정원, #알맹상점, #제로웨이스트, #재활용
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 27 in the database
# ID 30: Extracted info and hash tags
# Info: -성수동 제로웨이스트샵 원점.
# -플라스틱과 쓰레기 없는 가게.
# -플라스틱 업사이클 체험.
# -자원순환.
# -리필스테이션.
# Hash Tags: #제로웨이스트, #제로웨이스트샵, #플라스틱프리, #친환경, #체험
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 30 in the database
# ID 32: Extracted info and hash tags
# Info: 안녕하세요
# 초록색 소비 공간, 제로띵스입니다:)
# Hash Tags: #제로웨이스트, #리빙, #소품, #제로웨이스트샵, #잡화
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 32 in the database
# ID 34: Extracted info and hash tags
# Info: 양천구 목2동 골목에 있는 제로웨이스트숍 지구살림터는 강서양천시민햇빛발전협동조합이 운영하는 곳입니다.
# 기후위기시대에 재생에너지 생산을 통해 에너지전환을 하고자 햇빛발전소를 설립하여 착한 전기를 생산해 판매하는 협동조합입니다. 조합원은 현재 170여명입니다.
# 재생에너지 생산을 통해 생긴 수익으로 조합원들에게 수익배당을 하기도 하지만, 일상생활에서 #플라스틱프리 #제로웨이스트 #소분판매 #자원순환생활을 가능하게 하는 제로웨이스트숍을 만들면 좋겠다는 의견들을 모아 지구살림터를 2021년 4월 30일 개업하게 되었습니다.
# 대량생산 대량소비를 해오는 바람에 위기에 처하게 한 지구를 더 늦기 전에 무포장, 플라스틱없이, 자연순환으로 살리자는 뜻이 담긴 지구살림터가 탄생한 배경입니다. 많은 관심과 애정 부탁드립니다 ^^
# Hash Tags: #
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 34 in the database
# ID 36: Extracted info and hash tags
# Info: 지구를 위한 첫걸음, 지구샵입니다.
# <지구샵 제로웨이스트홈>은 일상 속 제로웨이스트 가치를 더 가깝게 느끼고 친환경 소비를 실천할 수 있도록 독려하고자 '제로웨이스터의 집'이라는 컨셉으로 공간을 구성했습니다.
#
# 매장은 아래와 같이 운영되고 있습니다.
# - 제로웨이스트 및 비건 제품 소개
# - 리필 스테이션 : 세탁세제, 섬유유연제, 주방세제, 핸드워시, 천연가루3종, 디퓨저2종
# - 자원순환스테이션 : 종이가방, 브리타 필터, 월경컵
#
# 지구샵은 하나뿐인 지구를 위해 함께 살아갈 우리 모두를 위해
# 지속 가능한 삶을 제안하고 함께 실천하겠습니다 :)
# Hash Tags: #
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 36 in the database
# ID 37: Extracted info and hash tags
# Info: 핸드메이드 빈티지 비건비누 비건향수 테라리움등 심리상담사가 직접힐링템을 선정하여 판매합니다
# Hash Tags: #타이거릴리비누, #빈티지, #핸드메이드, #애완동물용품, #악세사리
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 37 in the database
# ID 38: Extracted info and hash tags
# Info: @제로웨이스트샵, 지구적 소비를 위한 제안
# +용기내! 세제 리필스테이션_ 필요한 만큼만 덜어가요.
# +플라스틱 프리! 비닐포장 없는 비누, 세제, 화장품, 칫솔
# +사람&자연에 무해한 천연 소재 삼베망, 수세미, 손수건, 행주
# +다시 재활용해서 쓰는 리싸이클 문구, 가방, 파우치
# +한번 쓰고 버리지 않는 다회용 빨대, 화장솜, 밀랍랩
#
# @다시, 책으로 동네서점
# @대안생활문화공간
# @자원순환캠페인
# Hash Tags: #
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 38 in the database
# ID 40: Extracted info and hash tags
# Info: 기후위기에 대처하는 새로운 라이프스타일 : 에너지&제로웨이스트 상점
# Hash Tags: #제로웨이스트, #플라스틱프리, #자연소재, #비건, #세제리필스테이션
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 40 in the database
# Error occurred while processing search_name '허그어웨일' with id '41': Message: entryIframe
#
# ID 44: Extracted info and hash tags
# Info: * 불광역 3번 출구에서 도보 약 7분 거리 입니다.
# * 유모차, 휠체어 이용 가능합니다.
# Hash Tags: #제로웨이스트샵, #친환경, #생활용품점, #비누
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 44 in the database
# ID 47: Extracted info and hash tags
# Info: 지구돌봄은 쓰레기 줄이는 마을 플랫폼으로 플라스틱을 대체할 다양한 친환경용품을 소개하고 자원순환운동을 펼치고 있습니다.
# 지역의 환경문제에 대한 캠페인도 진행하여 지구를 돌보는 일에 적극 동참합니다.
# 옥길동 매장은 여러 제로웨이스트 용품과 리필 벌크 용품을 갖추고 있습니다.
# 하안동 매장은 제로웨이스트 용품만 구비하여 운영합니다.
# Hash Tags: #노플라스틱, #제로웨이스트, #리필스테이션, #친환경, #자원순환
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 47 in the database
# ID 48: Extracted info and hash tags
# Info: 우리와 아이들이 살아갈 지구를 위한 실천 제로웨이스트!! 우리동네 제로웨이스트샵 지구랑마을이입니다.
# 지구랑마을이는 쓰레기 없는 삶의 실천을 추구하는 사람들의 소비생활을 돕는 상점입니다. 포장지나 플라스틱 용기를 사용하지 않고 일회용품 대신 다회용품, 친환경 제품을 판매합니다. 마을과 함께 지구를 지키기 위해 세워진 '지구랑마을이협동조합'에서 운영합니다.
# Hash Tags: #제로웨이스트, #플라스틱프리, #리필스테이션, #제로웨이스트샵
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 48 in the database
# ID 49: Extracted info and hash tags
# Info: 포레슈 리필트럭은 움직이는 제로웨이스트샵입니다.
#
# 주방세제, 세탁세제, 섬유유연제를 리필 할 수 있고 다양한 친환경 제품들을 만나보실 수 있습니다.
#
# 기존에 개인 예약 서비스와 단체 행사 두가지 서비스를 제공하고 있었습니다. 현재 인력 부족으로 당분간은 개인 예약 서비스는 중단하고 기업행사와 이벤트 위주로 참여를 하게 되었습니다. 빠른 시일 내로 재 정비를 해서 다시 찾아뵙도록 하겠습니다.
# Hash Tags: #리필스테이션, #포레슈, #제로웨이스트, #김포제로웨이스트샵, #리필트럭
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 49 in the database
# ID 51: Extracted info and hash tags
# Info: 남양주 덕소 최초의 제로웨이스트샵
# '용기내 담아가게' 입니다.
#
# 저희 매장은 플라스틱, 비닐봉지를 사용하지 않고
# 포장을 최소화하여 불필요한 쓰레기를 만들지 않고
# 친환경 유기농식품, 생활용품, 주방용품, 세제,
# 화장품 등을 필요한 만큼만 자신의 용기에 담아가는
# 리필스테이션, 무포장가게, 자원순환, 플라스틱프리
# 매장 입니다.
#
# 담아가게와 함께 제로웨이스트 라이프를 시작해보세요!
# Hash Tags: #
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 51 in the database
# ID 52: Extracted info and hash tags
# Info: 제로웨이스트 친환경 소분샵 입니다.
# 친환경세탁세제 , 섬유유연제, 섬유탈취제,진드기기피제 등
# 예약받고 배송 혹은 배달 (호평평내) 합니다
#
# 온라인매장은 네이버스마트스토어
# .친한가게온라인. 으로 검색하세요!
#
# 종종 팝업이벤트로
# 오프라인 마켓에 참여하거나
# 호평,평내 딜리버리 서비스 준비중입니다!
# Hash Tags: #소분샵, #리필스테이션, #배달, #천연세제, #천연탈취제
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 52 in the database
# ID 53: Extracted info and hash tags
# Info: 제로웨이스트 바람가게입니다.
#  제로웨이스트란 생활 속에서 배출되는 쓰레기를 최소화하고 불가피한 부분은 재활용 및 재사용 하는 친환경 소비입니다.
# 바람가게는 제로웨이스트 상품을 판매하고 있습니다~
#  여러 세제 리필이 가능하고, 대나무칫솔, 스텐빨대, 천연 수세미 등 다양한 상품을 만나보세요:)
# Hash Tags: #제로웨이스트, #부천소품샵, #친환경, #리필스테이션, #역곡
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 53 in the database
# ID 54: Extracted info and hash tags
# Info: 부천의 제1호 제로웨이스트샵
# '사다' 의 뜻  '산'
# 'Zero ' 의 '0'
# 그동안 소모하거나, 채우던 소비패턴을
# "산을 되살리는 소비" 로 바꿔보자
# 착한소비, 가치소비, 윤리적소비로
# 나아가는 첫걸음👣
# 쓰레기를 줄이는 리필스테이션
# 지구를 위한 선택🌱
# 산제로상점입니다
# Hash Tags: #제로웨이스트샵, #리필스테이션, #노플라스틱, #용기내, #부천리필
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 54 in the database
# ID 58: Extracted info and hash tags
# Info: 2021년 7월 10일 오픈한 제로웨이스트 오프라인 플랫폼 입니다. 쓰레기 배출을 줄이기 위해 온라인 숍과 배송은 진행하지 않습니다. 비건을 지향하고 있기에 타샵에서 판매하고 있는 몇 가지의 제품이 없기도 해요. 고집스럽지만 그저 공간을 만든 의미가 잘 유지되었으면 좋겠습니다. 더불어 휴무일에는 연락이 되지 않을 수 있습니다. 인스타그램으로 메세지 남겨두시면 영업일 내 빠르게 확인 후 답변 드리겠습니다.
# Hash Tags: #성남제로웨이스트샵, #분당제로웨이스트샵, #리필샵, #친환경, #비건
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 58 in the database
# ID 59: Extracted info and hash tags
# Info: 가치가게는 세류동에 위치한 복합문화공간으로 카페와 제로웨이스트 상점을 겸하고 있습니다. 매주 월, 수 쏘잉 공방을 운영하고 격주 수요일에는 자급자족 워크숍을 진행합니다.
# 가치가게는 환경을 사랑하고 관계를 중시여기는 가치지향적인 공간입니다.
# Hash Tags: #공정무역커피, #제로웨이스트상점, #유기농과일청, #공간대여, #자원순환
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 59 in the database
# ID 61: Extracted info and hash tags
# Info: 일상 여행자들의 쉼터, 여기는 낯설여관입니다!
#
# 낯설여관은 과거 여관이 여행자들이 잠시 쉬어가던 공간이었던 점에서 착안하여, 일상 여행자들이 책과 사진을 통해 지친 마음을 달래고 쉼을 얻길 바라며 시작한 복합문화공간입니다. 공간은 204호 동네책방&제로웨이스트샵, 203호 동네사진관&작은영화관으로 구성되어 있고요. 각 공간은 마치 여관처럼 기다란 복도로 연결되어 있습니다.
#
# * 204호 동네책방 & 제로웨이스트샵
# * 203호 동네사진관 & 작은영화관
# Hash Tags: #제로웨이스트, #독립서점, #동네책방, #리필스테이션, #친환경소분샵
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 61 in the database
# ID 64: Extracted info and hash tags
# Info: '다시쓰고, 거듭쓰다' (주)재재再再
#
# 제로웨이스트샵 재재상점
# 다회용품제작 재재포목
# 워크샵환경교육 재재클래스
#
# 단체선물,굿즈제작/환경교육 문의 가능
# Hash Tags: #제로웨이스트샵, #다시쓰고거듭쓰다, #다회용품, #ESG, #친환경선물세트
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 64 in the database
# ID 65: Extracted info and hash tags
# Info: 수원 행궁동에 있는 제로웨이스트 샵으로써 로컬 창작자들이 운영하는 마을기업 입니다
# 33인의 무해한 창작자들이 실컷 놀면서 지구도 지키고 싶어서 그랬어 라는 슬로건으로 운영 합니다
# 지구인의 놀이터에 오시면 로컬 작가들의 특별한 작품을 만나실 수 있으며 제로웨이스트 물품, 독립책방 의 주인장이 소개하는 책, 그리고 공정무역 상품과 로컬 수원에 대한 관광 상품을 만나실 수 있습니다
# 마을기업 문화협동조합 참좋은수다 에서 운영 하며 로컬 창작자 입점작가를 희망하는 창작자들을 기다리고 있습니다.
# Hash Tags: #제로웨이스트샵, #책방, #행궁동카페, #행궁동소품샵, #수원제로웨이스트샵
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 65 in the database
# ID 66: Extracted info and hash tags
# Info: 도돌이상점은 친환경 제품을 판매하는 제로웨이스트샵입니다.
#
# 상호 도돌이는 반복을 나타내는 의미로 제품의 용기나 포장재 등을 반복 사용하여 쓰레기와 환경오염을 조금이나마 줄여보자는 의미를 담아 지었습니다.
#
# 도돌이상점에서는 레스웨이스트를 실천하며 환경을 위해 불필요한 쓰레기 배출량을 줄이고 건강한 자원의 순환을 지향합니다.
#
# 저희 상점에 오실때에는
# * 쇼핑백, 에코백 등 장바구니 가져오세요.
# * 세제, 샴푸 등 리필해가실 용기 깨끗이 씻어 말려오시면 좋아요^^
# * 작은 PP플라스틱, 병뚜껑 수거합니다.
# * 깨끗이 씻어 말린우유팩, 멸균팩(두유, 주스택 등) 수거합니다.
# Hash Tags: #제로웨이스트샵, #리필스테이션, #제로웨이스트, #친환경, #에코
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 66 in the database
# ID 67: Extracted info and hash tags
# Info: 일상의 작은 선택이 쌓여서 세상을 바꿉니다
# Hash Tags: #제로웨이스트샵, #세제리필, #친환경제품, #플라스틱프리, #선물
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 67 in the database
# ID 70: Extracted info and hash tags
# Info: 단순함과 필요함을 담은 친환경 비누상점입니다.
# 주로 비누판매와 자원순환 위주로 운영합니다.
# 멸균팩 / 브리타 필터 / 업사이어티 수거처입니다. (** 화장품용기와 페트는 수거 X )
# ** 자리를 비울 수 있으니 방문하시기 전 문자나 전화를 꼭 해주시면 감사하겠습니다.
# Hash Tags: #용인제로웨이스트, #멸균팩수거, #브리타필터수거, #업사이어티수거처, #용인비누상점
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 70 in the database
# ID 72: Extracted info and hash tags
# Info:
# Hash Tags: #
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 72 in the database
# ID 73: Extracted info and hash tags
# Info:
# Hash Tags: #제로웨이스트, #생활용품, #업사이클링
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 73 in the database
# ID 74: Extracted info and hash tags
# Info: 비건과 제로웨이스트를 함께 실천하는 즐거운 공간! 비숍입니다.
# Vegan Bakery & Zero Waste shop, VISHOP
# *** 무코팅 종이 및 대나무소재 컵으로 포장 가능해요***
#
# 유제품, 꿀, 달걀 등의 동물성 재료를 쓰지 않는
# 비건(완전채식) 베이커리만을 굽고 있어요.
#
# *** 23.11.3.부터 매장에서 가벼운 비건 식사를 즐길 수 있습니다.
# 네이버 예약을 이용하시면 더욱 편리해요!***
#
# 1. 글루텐프리, 슈가프리, 오일프리 옵션과 통곡물 사용으로 먹을수록 몸이 건강해지는 맛있는 베이커리와 음료를 준비합니다. 음료 중 라테는 오트밀크가 기본이에요. (못 드시는 분을 위해, 우유 변경 가능)
#
# 2. 플라스틱과 일회용을 줄일 수 있는 친환경(제로웨이스트) 용품 판매 및 식재료 리필스테이션을 운영합니다.
#
# 3. 비건와인과 내추럴와인 보틀구매 가능해요.
#
# 4. 매일 달라지는 라인업은 블로그 및 인스타그램을 통해 확인해주세요. 인스타그램 : vishop_vegan 또는 블로그 https://blog.naver.com/greenvishop
#
# 5. 배달의민족, 요기요, 쿠팡 포장 및 배달 주문가능합니다.
#
# 6. 당일 픽업 예약은 네이버 톡톡 또는 카카오톡채널 비숍 채팅,
# 매장 전화로 부탁드려요.
#
# 7. 타르트, 케이크 예약은 픽업하시기 최소 4일 전) 미리 채팅 또는 전화로 문의주시면 감사하겠습니다.
#
# 8. 평택시와의 제휴로 할인쿠폰(10%)을 다운로드받으실 수 있어요. 자세한 다운로드 방법은 인스타그램 vishop_vegan 또는 블로그 https://blog.naver.com/greenvishop 참조해주세요.
#
# 8. 스마트스토어 비숍에서 택배 주문 가능합니다.
# 스토어 주소 - https://smartstore.naver.com/bistro_dujour
#
# *** 비숍에 방문하실 때는~ ****
#
# 다회용 개인용기나 텀블러 지참시,용기에 담은 음식은 10% 할인혜택을 드립니다.(평택시 할인쿠폰과 중복 가능)
#
# 혹시 용기를 잊으셨더라도 무코팅(plastic free) 종이포장 상시 가능합니다. 마음 편히 오셔서 머물러주세요~
# Hash Tags: #
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 74 in the database
# ID 28: Extracted info and hash tags
# Info: 매일 사용하는 씻을거리, 먹거리에서 남기지 않고 씻어내는 건강함
# 올바른 상점이 만들어가는 일상의 작은 변화
# 지구에서 자연과 사람이 조화롭게 공존하는 세상
# 친환경을 불편하게 표현하는 것, 이것이 우리의 브랜드의 시작입니다!
# Hash Tags: #해시워시, #헤어바, #설거지바
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 28 in the database
# ID 81: Extracted info and hash tags
# Info: **친환경소품점_ zerowasteshop / 제로웨이스트샵
# -일회용품 , 플라스틱 용품을 대체할 수 있는
# 친환경 용품들 중에서 직접 사용해본 후
# 만족도가 높은 제품들을 선정했습니다.
# 제품들의 종류는 상시 업데이트 됩니다.
#
# **무포장보고가장
# 매 월 마지막 토요일은 쓰레기없는 장터가 열립니다.
# 개인용기를 지참하고 오셔서
# 정성껏 차린 일주일 반찬 겟 하세요!
# Hash Tags: #제로웨이스트샵, #제로웨이스트, #리필샵, #비건버터라떼, #비건메뉴
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 81 in the database
# 정보 탭을 찾지 못하였습니다 for id: 82
# div.input_box > input.input_search 태그를 찾지 못하였습니다. Message:
# Stacktrace:
# 	GetHandleVerifier [0x008FB8E3+45827]
# 	(No symbol) [0x0088DCC4]
# 	(No symbol) [0x0078150F]
# 	(No symbol) [0x007C20BC]
# 	(No symbol) [0x007C216B]
# 	(No symbol) [0x007FE0F2]
# 	(No symbol) [0x007E2E44]
# 	(No symbol) [0x007FC034]
# 	(No symbol) [0x007E2B96]
# 	(No symbol) [0x007B6998]
# 	(No symbol) [0x007B751D]
# 	GetHandleVerifier [0x00BB4513+2899763]
# 	GetHandleVerifier [0x00C0793D+3240797]
# 	GetHandleVerifier [0x009813B4+593364]
# 	GetHandleVerifier [0x009882DC+621820]
# 	(No symbol) [0x008970A4]
# 	(No symbol) [0x008937A8]
# 	(No symbol) [0x00893947]
# 	(No symbol) [0x008859FE]
# 	BaseThreadInitThunk [0x76D8FCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77CB80CE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77CB809E+238]
#
# ID 84: Extracted info and hash tags
# Info: 저희 가게는 무포장 친환경 제품으로 엄선하여 판매하고 있습니다. 최대한 우리 몸과 지구 환경에 해를 덜 끼지는 방법으로 소비될 수 있는 제품들을 소개하며 판매하고 있습니다. 특별히 쉽게 쓰고 버려지는 일회용, 플라스틱 제품을 대체하는 제품들 대나무 칫솔, 수세미, 고무장갑, 고체 치약, 대나무 화장솜, 장바구니 등을 판매하고 있습니다. 그 외에도 품질이 좋은 패브릭 제품들과 각종 비누들을 판매하고 있습니다. 유기농 비누에서 저렴한 재생유 비누 그리고 설거지, 온몸용, 샴푸, 린스 등 다양한 비누 제품들을 소개하고 있습니다. 리필이 가능한 액체 세제와 가루 세제도 구비하여 소분 판매도 하고 있습니다.
# Hash Tags: #제로웨이스트샵, #제로웨이스트, #리필스테이션, #자원순환센터, #환경동아리
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 84 in the database
# ID 85: Extracted info and hash tags
# Info: 우리동네 제로웨이스트샵 제자리로는
# 인천광역시 미추홀구 학익동에 있습니다.
#
# 강화도 소창제품과 천연수세미를 직접 제작 합니다.
#
# 다양한 제로웨이스트 제품들과 세제리필(주방세제, 세탁세제, 섬유유연제)
# 이 가능하니 언제든 들러 주세요^^
#
# 기관 및 단체선물 상담도 가능합니다.
#
# 운영에 관한 문의사항은 0507-1391-7440 으로 연락주세요 :-)
#
# 감사합니다.
# Hash Tags: #제로웨이스트, #삼베수세미, #친환경, #인천제로웨이스트샵, #디자인스튜디오새벽숲
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 85 in the database
# ID 86: Extracted info and hash tags
# Info: 지구를 지키는 인천 제로웨이스트상점
# 지구별수호대입니다.
# 친환경제품과 사회적경제의 제품을 홍보하고
# 구매할 수 있는 공간입니다.
#
# 플라스틱을 줄이고, 1회용품을 줄이는
# 제로웨이스트 문화 확산에 앞장서는
# 지구별수호대입니다.
#
# 용기와 포장가방을 지참하고 방문해주세요..^^
# 뜨거운 지구에게 쉼표를 찍어주세요.
#
# 친환경제품과 사회적경제 파트너사를 기다리고
# 있습니다.
#
# 언제든지 편하게 문의해주세요 010-9227-5911
# Hash Tags: #청라비누공방, #청라향수공방, #청라꽃공방, #청라쉼
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 86 in the database
# 정보 탭을 찾지 못하였습니다 for id: 88
# div.input_box > input.input_search 태그를 찾지 못하였습니다. Message:
# Stacktrace:
# 	GetHandleVerifier [0x008FB8E3+45827]
# 	(No symbol) [0x0088DCC4]
# 	(No symbol) [0x0078150F]
# 	(No symbol) [0x007C20BC]
# 	(No symbol) [0x007C216B]
# 	(No symbol) [0x007FE0F2]
# 	(No symbol) [0x007E2E44]
# 	(No symbol) [0x007FC034]
# 	(No symbol) [0x007E2B96]
# 	(No symbol) [0x007B6998]
# 	(No symbol) [0x007B751D]
# 	GetHandleVerifier [0x00BB4513+2899763]
# 	GetHandleVerifier [0x00C0793D+3240797]
# 	GetHandleVerifier [0x009813B4+593364]
# 	GetHandleVerifier [0x009882DC+621820]
# 	(No symbol) [0x008970A4]
# 	(No symbol) [0x008937A8]
# 	(No symbol) [0x00893947]
# 	(No symbol) [0x008859FE]
# 	BaseThreadInitThunk [0x76D8FCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77CB80CE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77CB809E+238]
#
# 정보 탭을 찾지 못하였습니다 for id: 92
# div.input_box > input.input_search 태그를 찾지 못하였습니다. Message:
# Stacktrace:
# 	GetHandleVerifier [0x008FB8E3+45827]
# 	(No symbol) [0x0088DCC4]
# 	(No symbol) [0x0078150F]
# 	(No symbol) [0x007C20BC]
# 	(No symbol) [0x007C216B]
# 	(No symbol) [0x007FE0F2]
# 	(No symbol) [0x007E2E44]
# 	(No symbol) [0x007FC034]
# 	(No symbol) [0x007E2B96]
# 	(No symbol) [0x007B6998]
# 	(No symbol) [0x007B751D]
# 	GetHandleVerifier [0x00BB4513+2899763]
# 	GetHandleVerifier [0x00C0793D+3240797]
# 	GetHandleVerifier [0x009813B4+593364]
# 	GetHandleVerifier [0x009882DC+621820]
# 	(No symbol) [0x008970A4]
# 	(No symbol) [0x008937A8]
# 	(No symbol) [0x00893947]
# 	(No symbol) [0x008859FE]
# 	BaseThreadInitThunk [0x76D8FCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77CB80CE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77CB809E+238]
#
# ID 95: Extracted info and hash tags
# Info: 우리의 삶에서 제로웨이스트를 꿈꾸는 상점
# Instagram.com/eunyoung_store
# Hash Tags: #제로웨이스트, #무포장가게, #리필샵, #환경보호, #친환경
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 95 in the database
# ID 96: Extracted info and hash tags
# Info: - 천안 최초 제로웨이스트샵입니다. 쓰레기를 줄이는 소비를 지향합니다.
# - 사람 몸에도 안전하고 환경에도 피해를 최소화 할 수 있는 생활용품을 모아 놓은 편집샵입니다.
# - 프라스틱 용기를 줄일 수 있도록 주방, 세탁 세제 리필스테이션을 운영합니다.
# - 50년~100년을 사용 하면서 안전을 검증 받은 생활 용품을 판매합니다.
# - 대나무 칫솔, 고체 치약, 비누 등 매일 사용하는 용품만 바꿔도 환경을 위한 변화에 함께 동참 하실 수 있습니다.
# - 질 좋은 친환경 공정무역 제품을 만날 수 있습니다.
# - 천연 삼베, 유기농 면, 천연 밀랍으로 만든 다양한 친환경 제품들을 경험하고 구입하실 수 있습니다.
# Hash Tags: #천안제로웨이스트샵, #친환경살림, #삼베실수세미, #천연밀랍제품, #공정무역
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 96 in the database
# ID 99: Extracted info and hash tags
# Info: 청주 비하동에 있는 제로웨이스트샵! 기후위기에 대처하는 생활밀착형 소비문화 정착에 나섭니다.
# 보이차을 마시는 품격있는 여러분들의 생활소비 문화 개선을 돕겠습니다~^^
# Hash Tags: #
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 99 in the database
# ID 100: Extracted info and hash tags
# Info: [환경부 지정 녹색특화매장]
# 싱글룸 제로웨이스트 마켓
# Singleroom zero-waste market
#
# 싱글룸 제로웨이스트 마켓은 2021년 7월 1일 오픈한
# 친환경 잡화점이자 리필스테이션입니다.
#
# '꼭 필요한 곳에, 꼭 필요한 것만'이라는 메시지로
# 그린 미니멀 라이프에 맞는 친환경 생활용품, 친환경 선물세트, 환경체험 키트를 판매하고 있습니다.
#
# 생활에 필요한 친환경 생활용품과 새로운 플라스틱 구입을 줄일 수 있도록
# 여러가지 리필스테이션을 운영하고 있습니다.
#
# 기존에 가정에서 사용하시고 계시는 용기, 빈 용기를 지참하여 오시면
# 주방세제/세탁세제/섬유유연제/디퓨저/향수/화장품 등
# 다양한 제품을 내용물만 저렴하게 리필하여 구매하실 수 있습니다.
#
# 나와 가족, 우리 아이들을 위해 이제는 환경문제를 외면할 수 없습니다.
# 조금은 번거롭고 불편하더라도 실천할 때입니다!
# 여러분의 제로웨이스트, 환경을 지키는 삶이 조금은 편리하고
# 쉬워질 수 있도록 싱글룸이 열심히 돕겠습니다!
#
# [청주기념품][청주답례품][청주친환경]
# Hash Tags: #제로웨이스트, #제로웨이스트샵, #리필스테이션, #친환경선물세트, #녹색특화매장
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 100 in the database
# ID 101: Extracted info and hash tags
# Info: 안녕하세요. 맛좋고 신선한 과일을 파는 불편한zip입니다. 우리의 사소한 불편함이 세상을 바꾼다. 일회용품 사용을 최소화하고, 자연을 사랑하는 과일가게가 되려고 합니다.
# Hash Tags: #과일, #야채, #과일선물, #당진과일, #복숭아
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 101 in the database
# ID 102: Extracted info and hash tags
# Info: 함께 살아가는 생태적 삶의 실천을
# 꿈꾸는 예비사회적협동조합 숲을입니다
#
# :> 쓰레기를 줍습니다
# :> 무포장 알맹이 지향가게
# :> 자원순환(우유팩/브리타필터 등)
# :> 플라스틱No 일회용품No
# Hash Tags: #경주제로웨이스트, #경주환경교육, #제로웨이스트, #경주제로웨이스트여행, #숲을
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 102 in the database
# ID 103: Extracted info and hash tags
# Info: 구미최초제로웨이스트샵입니다.
# 예비사회적기업 (주)에코썸코리아의 제로웨이스트브랜드 초록별상점 본점으로
# 직영 수세미농장을 구미, 칠곡, 김천에 운영하고 있습니다.
# 세제리필스테이션, 플라스틱베이킹, 자원순환, 다양한환경교육이 이루어집니다.
# Hash Tags: #구미제로웨이스트샵, #구미세제리필스테이션, #구미자원순환가게, #구미수세미농장, #구미업사이클
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 103 in the database
# ID 106: Extracted info and hash tags
# Info: 쓰레기를 줄이는 가게예요.
# 천연수세미, 고체치약, 대나무칫솔과
# 비건 제품을 만날 수 있어요.
# 종이팩, 브리타필터,색연필과크레파스
# 양파망, 쓰지않는 충전선과 멀티탭수거
# 자원을순환합니다.
# 함께 해 주세요^^
# Hash Tags: #안녕지구야, #장유제로웨이스트, #esg키트, #친환경선물, #업사이클링
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 106 in the database
# ID 107: Extracted info and hash tags
# Info: 카페그린그루브는 건강한 음료와 제로웨이스트 상품을 판매중이며 사람과 환경이 지속가능한 삶을 공유할 수 있도록 함께 노력합니다. 우리의 초록물결에 많은 격려와 관심 부탁드립니다.
# Hash Tags: #
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 107 in the database
# ID 108: Extracted info and hash tags
# Info: food, cafe, and lifestyle shop 우리와 지구에게 조금 더 다정한 하루!
#
# 더커먼은 기후위기의 열쇠가 인류의 다정함에 있다고 믿으며, <MANKIND IS KIND : 우리는 조금 더 다정할 수 있어요> 라는 슬로건을 중심으로, 당신의 삶이 우리와 지구에게 조금 더 다정할 수 있도록 돕습니다.
#
# 음식과 제로웨이스트 숍, 그리고 커뮤니티와 문화예술이 함께 하는 복합문화공간입니다.
# *음료만 시키셔도 언제든지 환영합니다! 커먼이 엄선한 플레이리스트와 함께 다정하고 편안한 시간을 보내세요 :)
# *그냥 들러서 구경만 하셔도 됩니다. 다양한 상품과 콘텐츠가 마련되어 있으니 지나가실 일이 있다면 언제든 놀러 오세요!
#
# FOOD 음식
# 식물성 재료를 기반으로 나와 지구에게 다정한 한끼를 제공합니다. 언제나 맛있게 즐길 수 있는 채소 기반의 메뉴와 계절에 따라 로컬푸드를 활용한 팝업 메뉴를 선보입니다.
#
# SHOP 가치소비
# 어제보다 오늘 더 다정한 일상을 보낼 수 있도록 도와주는 물건들을 큐레이션하여 판매합니다. 그리고 포장 없이 생필품과 식재료를 구매할 수 있는 리필숍을 통해 쓰레기 없는 장보기 문화를 제안합니다.
#
# COMMUNITY 커뮤니티
# 나와 지구에게 조금 더 다정한 삶이 앞으로도 지속될 수 있도록, 그리고 다정한 라이프스타일이 조금 더 즐겁고 신나는 일이 될 수 있도록, 사람들이 모이는 플랫폼을 제공합니다.
# Hash Tags: #
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 108 in the database
# ID 110: Extracted info and hash tags
# Info: 천연화장품 / 천연비누 / 캔들 / 디퓨저 / 친환경생활용품 제작 및 원데이클래스 / 취미반 / 자격증반 운영합니다.(*모든 클래스 예약제)
# 영업시간 변동있습니다. 방문 전 전화(070-7788-7772)로 확인해주시면 감사하겠습니다!
# Hash Tags: #천연화장품, #천연비누, #제로웨이스트, #소품, #리필스테이션
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 110 in the database
# ID 112: Extracted info and hash tags
# Info: 둥근지구를 위한 네모의 실천
# 연제구 제로웨이스트샵 둥근네모입니다.
# (네모상점이 둥근네모로 변경되었어요~~)
# Hash Tags: #부산제로웨이스트샵, #리필스테이션, #무포장가게, #제로웨이스트샵, #친환경제품
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 112 in the database
# ID 113: Extracted info and hash tags
# Info: 지구와 나를 지키는 습관
# 자연으로부터 얻은 신선하고 정직한 재료를 사용하여 모든 제품을 손으로 직접 만듭니다
# Hash Tags: #부산기장정관비누공방, #부산키즈원데이클래스, #잼스톤보석비누원데이클래스, #천연비누자격증반, #천연비누성인원데이클래스
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 113 in the database
# ID 114: Extracted info and hash tags
# Info: 부산 제로웨이스트샵 마플상회는 <덜수록 가치가 더해집니다>라는 모토로 리필스테이션.친환경용품.자원순환 수거거점으로 운영중입니다.
#
# 마이너스(-) : 쓰레기, 썩지 않는 플라스틱
# 플 러 스(+) : 지속 가능한 미래
#
# @minus_plus_store
# Hash Tags: #제로웨이스트샵, #친환경용품, #통수세미, #리필스테이션, #자원순환센터
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 114 in the database
# 정보 탭을 찾지 못하였습니다 for id: 115
# div.input_box > input.input_search 태그를 찾지 못하였습니다. Message:
# Stacktrace:
# 	GetHandleVerifier [0x008FB8E3+45827]
# 	(No symbol) [0x0088DCC4]
# 	(No symbol) [0x0078150F]
# 	(No symbol) [0x007C20BC]
# 	(No symbol) [0x007C216B]
# 	(No symbol) [0x007FE0F2]
# 	(No symbol) [0x007E2E44]
# 	(No symbol) [0x007FC034]
# 	(No symbol) [0x007E2B96]
# 	(No symbol) [0x007B6998]
# 	(No symbol) [0x007B751D]
# 	GetHandleVerifier [0x00BB4513+2899763]
# 	GetHandleVerifier [0x00C0793D+3240797]
# 	GetHandleVerifier [0x009813B4+593364]
# 	GetHandleVerifier [0x009882DC+621820]
# 	(No symbol) [0x008970A4]
# 	(No symbol) [0x008937A8]
# 	(No symbol) [0x00893947]
# 	(No symbol) [0x008859FE]
# 	BaseThreadInitThunk [0x76D8FCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77CB80CE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77CB809E+238]
#
# ID 118: Extracted info and hash tags
# Info: 환경오염을 줄이는 제품, 세제소분, 부산 최초 제로웨이스트샵
#
# - 매장 바로 옆 작은 주차장에 1대 주차 가능합니다.
# 다른 고객님이 주차하신 경우 매장 근처 유료주차장을 이용을 부탁드립니다 :D
# Hash Tags: #제로웨이스트샵, #세제소분샵, #친환경제품, #세제리필스테이션, #부산제로웨이스트샵
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 118 in the database
# ID 119: Extracted info and hash tags
# Info: 제로웨이스트 상점으로 친환경 물품을 둘러보실 수 있고 더불어 환경수업, 업사이클 등 친환경 체험을 할 수 있습니다.
# Hash Tags: #
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 119 in the database
# ID 120: Extracted info and hash tags
# Info: 아름다운 문경새재길을 걷고 잠시 쉬어가는 곳~문경 종합온천 옆 간단한 음료를 마시며 반려식물 다육이를 심어가시고 친환경생활용품 라탄 우드 제품들 구경도 하세요
# Hash Tags: #제로웨이스트샵, #카페, #다육, #친환경생활용품, #문경소품샵
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 120 in the database
# ID 123: Extracted info and hash tags
# Info: 제로웨이스트
# 더 나은 방향으로 더 적게 사용하고 조금은 불편한것을 즐겁게 할때 지속가능한 공정한 세상이 될거라고 믿어요
# Hash Tags: #샴푸바, #린스바, #고체치약, #캐슈넛, #대나무칫솔
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 123 in the database
# ID 125: Extracted info and hash tags
# Info: - ZEROWASTE SHOP(제로웨이스트샵)
# - Soap studio(비누공방)
# - Refill station(리필스테이션)
# - Eco-friendly goods(친환경용품)
# Hash Tags: #제로웨이스트샵, #리필스테이션, #천연비누, #소분, #원데이클래스
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 125 in the database
# ID 126: Extracted info and hash tags
# Info:
# Hash Tags: #제로웨이스트, #친환경, #리필스테이션, #호주영양제, #건강기능식품
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 126 in the database
# ID 127: Extracted info and hash tags
# Info: 매장 방문 및 업사이어티 예약만 가능
#
# *거제 최초 업사이어티 교환 매장*
# PP, PE, PS 교환 가능
#
# 거제 에코유의 두 번째 이야기
# 방역&제로웨이스트 에코유샵입니다 :)
# 환경에 관심을 가져주셔서 감사해요
# 앞으로 새로워진 에코유에서
# 좀 더 다양한 환경 교육과 자원 순환의 역할로
# 편하게 다가갈 수 있는 공간이 되어보려고 해요
# 많은 관심 부탁 드립니다
#
# -업사이어티
# -자원순환소
# -환경관련교육
# -제로웨이스트
# -플라스틱프리
# -리필스테이션
# Hash Tags: #플라스틱프리, #리필스테이션, #환경관련교육, #업사이어티, #제로웨이스트
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 127 in the database
# Error occurred while processing search_name '제로웨이스트 흥분색' with id '129': Message: entryIframe
#
# ID 130: Extracted info and hash tags
# Info: 전시관에서는 군산시민들의 자유로운 전시참여가 가능하고, 매달 새로운전시가 시작됩니다.
#
# 본관에서는 환경보호캠페인과 체험활동을 할수있는 제로웨이스트샵 이 운영됩니다
# Hash Tags: #전시관, #제로웨이스트, #비누, #소품샵, #공예체험
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 130 in the database
# ID 131: Extracted info and hash tags
# Info: 지구의 온도를 낮추는 주방, 선선한 주방입니다.
# 정성이 담긴 핸드메이드 제로웨이스트 주방용품을 판매합니다.
# Hash Tags: #제로웨이스트, #주방용품, #키친, #환경, #나주
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 131 in the database
# ID 133: Extracted info and hash tags
# Info: 제로웨이스트 리필샵& 편집샵
# 더 나은 지구를 위한 살림과 선물. 비건 간식과 식재료
#
# 친환경 문구류, 플라스틱 대신 뜨개 놀잇감.
# 빈용기를 가지고 오시면 주방, 세탁세제와 베이킹소다, 과탄산 구연산 등 가루세제를 리필구매하실 수 있습니다.
#
# 비건스테이크와 비건치킨 냉동반조리제품, 비건젤리와 마시맬로 등 비건 간식을 구매하실 수 있습니다.
#
# 플라스틱을 최소화한 살림도구들. 천연솔과 수세미, 패브릭 제품들. 살림과 선물들을 만나보세요.
# Hash Tags: #제로웨이스트, #담양소품샵, #세제리필샵, #친환경문구, #선물샵
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 133 in the database
# ID 134: Extracted info and hash tags
# Info: 노플라스틱 카페는 플라스틱을 전혀 사용하지 않는 카페로 개인 텀블러 사용을 지향하는 카페입니다. 개인컵을 가지고 카페에 오시면 모든 음료가 1,000원 할인되며 세제 소분샵, 텀블러 세척소, 재활용 놀이터, 제로웨이스트샵 등이 운영되고 있습니다. '마을에서 지구를 지킵니다'라는 슬로건을 몸소 실천하고 있답니다. 지구를 살리는 일에 함께 동참해주세요 :-)
# Hash Tags: #
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 134 in the database
# ID 135: Extracted info and hash tags
# Info: Oh!! What a Wonderful Soap!!!
# (오! 정말 얼마나 멋진 비누인가!!!!
# 비누 사용만으로도 내피부도, 우리가족도, 친구와 이웃도...
# 그리고 지구와 바다까지
# 환경도 지키는 멋진 친구이니!!!! )
#
# 가족이 직접 농사지은 진도울금으로
# 2013년 부터 내 아이를 위해 만들기 시작한 울금비누를 시작으로 머릿비누, 주방비누, 향수비누, 세탁 등 다목적 비누를... 매장에서 직접 냄새맡고, 씻어보고... 내가 꼭 필요한 만큼 잘라서(최소 10g부터 ) 가지고 가실 수 있습니다.
#
# 지구와 모든 생명을 사랑하고 아끼고 환경을 보호하기 위해 노력하는 일환으로 부득이하게 플라스틱(비닐)을 사용할 경우를 제외하고는 최소한을 사용하는 무포장가게를 지향하고 있으며 ,
#
# 리필스테이션(액체형주방.세탁용세제, 가루세제에 한하여)이 준비 되어있고, 시골에서 직접 농사지은 제철 농식품(쌀, 귀리,견과류 등등)들을 필요한 만큼 덜어서 구매 하실 수 있습니다. 유리빨대, 옻칠수저,천연통수세미 열매, 대나무칫솔, 고체치약, 오가닉(유기농) 천 원단으로 만든 유아용 턱받이를 비롯하여 천기저귀, 소창가방, 소창행주,소창 차 거름망,소창다시백,소창베게 커버, 면야채주머니, 순면장바구니,순면비누망, 도시락가방 이나 선물용으로도 좋은 보자기, 천생리대 등등 다회용으로 사용할 수 있는 여러가지 생활용품들을 판매하고 있는 제로웨이스트를 실천하고자하는 가게입니다.
#
# 우리 목포지역에서 우유종이팩, 작은 플라스틱 음료병 뚜껑,두유나 쥬스 등 은박코팅 된 종이팩 등 재활용품을 수집하여 환원할 수 있는 곳으로 보내는 거점이 될 수 있도록, 앞으로 더 많이 배워가며 하나씩 준비 해 놓도록 하겠습니다.
#
# 화장비누를 제조하는 소리맘코스메틱은 소리맘씨 제로웨이스트샵 매장내에 있으며 식약처에 등록된 화장품제조,책임판매업체 입니다.
# Hash Tags: #목포제로웨이스트, #소리맘울금비누, #소리맘울금, #울금디자인비누, #목포천연비누
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 135 in the database
# ID 136: Extracted info and hash tags
# Info: [전주 최초 제로 웨이스트샵 X 자원순환 공간 늘미곡 Neulmigok]
# 전라북도 호남 평야에서 생산된 신선한 잡곡 리필스테이션을 포함하여
# 식품, 차, 세제 등 필요한 만큼 소분할 수 있습니다.
# 다양한 친환경 대안용품을 만나볼 수 있으며 지구와의 따뜻한 우정을 꿈 꿉니다.
# 언제나 환영합니다 :)
# Hash Tags: #제로웨이스트, #전주제로웨이스트샵, #전주늘미곡, #제로웨이스트샵, #리필스테이션
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 136 in the database
# ID 138: Extracted info and hash tags
# Info: 제주에서 직접 제조한 친환경 세제를 용기 배출 없이 내용물만 담아갈 수 있는 세제 전문 리필스테이션입니다
# Hash Tags: #천연비누, #친환경세제, #제로웨이스트, #리필스테이션, #천연세제
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 138 in the database
# ID 139: Extracted info and hash tags
# Info: 제로 웨이스트와 노 플라스틱을 지향하는 친환경 라이프 스타일을 소개합니다.
# Hash Tags: #친환경제품, #제로웨이스트, #플라스틱프리, #제로웨이스트샵, #대나무칫솔
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 139 in the database
# ID 140: Extracted info and hash tags
# Info: 제주 천연비누 화장품, 양초공예, 디퓨저, 천연 아로마에센셜 향수, 유명브랜드 따라 만들기 향수 외 만들기 체험 가능
# 자격증반, 취미반 수시모집, 외부출강 강의  가능 , 창업 상담 가능.
# 비누 & 화장품 만들기 재료 판매,
# 인터넷 스마트스토어 유니제로웨이스트 생활용품 쇼핑몰 운영 중
# Hash Tags: #제로웨이스트샵, #출장강의, #자격증반수시모집, #비누만들기체험, #통신판매
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 140 in the database
# ID 141: Extracted info and hash tags
# Info: 제로웨이스트 리빙랩, 지구별가게
# 내 몸과 지구를 살리는 소소한 즐거움, 소락
#
# 제로웨이스트를 위한 다회용 생활용품과 유기농 원단으로 직접 제작하는 소락 브랜드 제품을 만나볼 수 있습니다.
# Hash Tags: #제로웨이스트샵, #제로웨이스트스토어, #리필스테이션, #다회용품점, #면생리대
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 141 in the database
# ID 144: Extracted info and hash tags
# Info: 제주 서귀포 대정읍에 위치한 제로웨이스트 샵입니다.
# * 오래 사용할수 있는 좋은 물건을 만들고
# 더 적게 소비하는 삶의 방식을 연구하고
# 함께만들어 가는 곳 입니다.
#
# ** 제로웨이스트 상품 판매
# ** 세제 소분 리필 판매 (리필 스테이션)
# ** 천연재료를 이용한 원데이클래스
# (체험 클래스 소요시간: 1시간이내/ 2인이상 신청가능)
#
# -
# Hash Tags: #원데이클래스, #제로웨이스트, #파우더치약, #리필스테이션, #대정읍
# Binding variables for SQL query:
# Successfully stored info and hash tags for ID 144 in the database
