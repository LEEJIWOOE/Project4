# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.support.ui import WebDriverWait

import time
from datetime import datetime
from bs4 import BeautifulSoup

import cx_Oracle

# 데이터베이스 연결 설정
connection = cx_Oracle.connect('kyb/1111@localhost:1521/xe')
cursor = connection.cursor()

# 웹드라이버 설정
options = Options()
options.add_experimental_option("detach", True)
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=options)
driver.get("https://map.naver.com/v5/search")
time.sleep(3)  # 페이지 로딩 대기

# 검색어 목록 가져오기
cursor.execute('SELECT id, search_name FROM zero') 
data_list = [(row[0], row[1]) for row in cursor.fetchall()]

# frame 변경 메소드
def switch_frame(frame):
    driver.switch_to.default_content()  # frame 초기화
    driver.switch_to.frame(frame)  # frame 변경

# 현재 스크래핑된 HTML 요소 스냅샷 만드는 함수
def save_html_snapshot(page_str, file_prefix):
    current_date = datetime.now().strftime('%y%m%d_%H%M%S')
    file_path = f'{file_prefix}_{current_date}.html'
    with open(file_path, 'w', encoding='utf-8') as file:
        file.write(page_str)

# 해당 요소 찾을 때까지 10초 대기
def time_wait(num, code):
    try:
        wait = WebDriverWait(driver, num).until(
            EC.presence_of_element_located((By.CSS_SELECTOR, code)))
        return wait
    except Exception as e:
        print(f"{code} 태그를 찾지 못하였습니다. {e}")
        return None

# 각 검색어에 대해 작업 수행
for id, search_name in data_list:
    try:
        # 검색창 찾기 및 검색어 입력
        search_box = time_wait(10, 'div.input_box > input.input_search')
        if search_box:
            search_box.clear()
            search_box.send_keys(search_name)
            search_box.send_keys(Keys.ENTER)
            time.sleep(3)  # 검색 결과 로딩 대기

            # 검색 결과 프레임으로 전환 및 스냅샷 저장
            switch_frame('searchIframe')
            save_html_snapshot(driver.page_source, f"search_result_{id}")

            # 리뷰 탭 클릭 및 프레임으로 전환
            switch_frame('entryIframe')
            reviews_tab_found = False
            for i in range(2, 7):
                try:
                    reviews_tab = WebDriverWait(driver, 10).until(
                        EC.element_to_be_clickable((By.XPATH, f'//*[@id="app-root"]/div/div/div/div[4]/div/div/div/div/a[{i}]/span'))
                    )
                    if "리뷰" in reviews_tab.text:
                        reviews_tab.click()
                        reviews_tab_found = True
                        break
                except Exception as e:
                    print(f"리뷰 탭을 찾지 못하였습니다: {e}")
                    continue
            
            if not reviews_tab_found:
                print(f"리뷰 탭을 찾지 못하였습니다 for id: {id}")
                continue

            time.sleep(3)  # 리뷰 탭 로딩 대기
            save_html_snapshot(driver.page_source, f"review_{id}")

            # "내용 더보기" 버튼 클릭
            more_buttons = driver.find_elements(By.CLASS_NAME, 'rvCSr')
            for btn in more_buttons:
                try:
                    btn.click()
                    time.sleep(1)  # 버튼 클릭 후 로딩 대기
                except Exception as e:
                    print(f"Failed to click '내용 더보기' for ID {id}: {e}")

            # 업데이트된 페이지 소스 가져오기
            updated_page_source = driver.page_source
            save_html_snapshot(updated_page_source, f"updated_review_{id}")

            # 리뷰 텍스트 추출 및 데이터베이스 저장
            soup = BeautifulSoup(updated_page_source, 'html.parser')
            reviews = []
            review_elements = soup.find_all("span", class_="zPfVt")
            if not review_elements:
                review_elements = soup.find_all("div", class_="zPfVt")
            if not review_elements:
                print(f"No review elements found for ID {id}")

            for review in review_elements:
                review_text = review.get_text(separator=' ').strip()
                if review_text:
                    reviews.append(review_text)
                if len(reviews) >= 10:
                    break  # 최대 10개의 리뷰 텍스트만 추출

            # 디버깅: 추출된 리뷰 텍스트 출력
            print(f"ID {id}: Extracted {len(reviews)} reviews")
            for i, review in enumerate(reviews):
                print(f"Review {i+1}: {review}")

            # 데이터베이스에 리뷰 저장
            try:
                print("Binding variables for SQL query:")
                for i, review in enumerate(reviews):
                    print(f"review{i+1}: {review[:100] if review else None}")

                # 리뷰 텍스트 데이터베이스에 저장
                cursor.execute("""
                    INSERT INTO zero_re (id, re_num, review, review2, review3, review4, review5, review6, review7, review8, review9, review10)
                    VALUES (:id, zero_re_seq.NEXTVAL, :review, :review2, :review3, :review4, :review5, :review6, :review7, :review8, :review9, :review10)
                """, {
                    'id': id,
                    'review': reviews[0] if len(reviews) > 0 else None,
                    'review2': reviews[1] if len(reviews) > 1 else None,
                    'review3': reviews[2] if len(reviews) > 2 else None,
                    'review4': reviews[3] if len(reviews) > 3 else None,
                    'review5': reviews[4] if len(reviews) > 4 else None,
                    'review6': reviews[5] if len(reviews) > 5 else None,
                    'review7': reviews[6] if len(reviews) > 6 else None,
                    'review8': reviews[7] if len(reviews) > 7 else None,
                    'review9': reviews[8] if len(reviews) > 8 else None,
                    'review10': reviews[9] if len(reviews) > 9 else None
                })
                connection.commit()
                print(f"Successfully stored reviews for ID {id} in the database")  # 데이터베이스 저장 성공 로그
            except cx_Oracle.DatabaseError as db_e:
                error, = db_e.args
                print(f"Database error occurred while storing reviews for ID {id}: {error.message}")
                print(f"SQL Query: {cursor.statement}")
                print(f"Bound Variables: {cursor.bindvars()}")
            except Exception as e:
                print(f"Unexpected error occurred while storing reviews for ID {id}: {e}")
    except Exception as e:
        print(f"Error occurred while processing search_name '{search_name}' with id '{id}': {e}")

    # 검색어 처리 후 브라우저 새로 고침
    driver.get("https://map.naver.com/v5/search")
    time.sleep(3)

# 드라이버 종료 및 연결 종료
driver.quit()
cursor.close()
connection.close()
# Out:
# ID 1: Extracted 10 reviews
# Review 1: 오랜만에 수세미 구매하고 갑니다❤️
# Review 2: 디자인너무 이뻐요🌸
# Review 3: 배러얼스 행사때마다 가는데
# 너무 좋은시간 보내고 왔어요!
# 아이들도 좋아하는 공간이에요
# Review 4: 온라인에서 구매하려다가 가까운 곳에 위치한걸 보고 방문했어요~
# 매장이 작은데 솔이랑 바 종류가 알차게 여러가지 있어서 방문해서 이것저것 보기 좋았어요~
# Review 5: 친환경, 비건 제품들이 다 모여있어요.
# 용기를 가져가면
# 필요한 양만큼 세제를 구입할 수 있어서 애용할 듯 합니다 ^^
# 샴푸바랑 목욕솔 구입해서  잘 쓰고 있답니다.
# 오며가며 들러도 늘 친절하세요.
# Review 6: 친환경 제품 ♡
# 가격이 싼편은 아니지만 환경을 생각해서
# 또 건강한 삶을 위해서 가치있는 쇼핑을 했어요.
# 헤드가 교체되는 솔이 유용할듯하여 구매했고 두종류가 있는데 너무 강력한 솔은 후라이팬 🍳 코팅이 다 벗겨질수있다고하여
# 연한모질로 구매.
# 샤워그립이 참 좋네요. 오션타올만 쓰다 55브랜드에서 친환경 제품을 접하게된 이후부터 가급적이면 마, 수세미, 면제품을 선호하게되었어요.
#
# 실리콘 빨대 조립이 귀찮아서 👄 입에 닿는 느낌이 더 부드러운 유리빨대도 하나 구입.
# 수세미에서 씨앗 두개건짐.  이거 심으면 날까요?
# Review 7: 다회용 지퍼백 사용해보고싶어서 실리콘지퍼백 샀어요.
# 가격이 좀 세지만 환경보호 차원에서 코엑스 행사중에 구입.
# Review 8: 몇달만에 와서 수세미 사갖고 갑니다!
# 수세미 품질 최고
# Review 9: 좋아요 좋아요
# Review 10: 항상 믿고 구매합니다 ㅎ
# Binding variables for SQL query:
# review1: 오랜만에 수세미 구매하고 갑니다❤️
# review2: 디자인너무 이뻐요🌸
# review3: 배러얼스 행사때마다 가는데
# 너무 좋은시간 보내고 왔어요!
# 아이들도 좋아하는 공간이에요
# review4: 온라인에서 구매하려다가 가까운 곳에 위치한걸 보고 방문했어요~
# 매장이 작은데 솔이랑 바 종류가 알차게 여러가지 있어서 방문해서 이것저것 보기 좋았어요~
# review5: 친환경, 비건 제품들이 다 모여있어요.
# 용기를 가져가면
# 필요한 양만큼 세제를 구입할 수 있어서 애용할 듯 합니다 ^^
# 샴푸바랑 목욕솔 구입해서  잘 쓰고 있답니다.
# 오며가며 들러
# review6: 친환경 제품 ♡
# 가격이 싼편은 아니지만 환경을 생각해서
# 또 건강한 삶을 위해서 가치있는 쇼핑을 했어요.
# 헤드가 교체되는 솔이 유용할듯하여 구매했고 두종류가 있는데 너무 강력한 솔
# review7: 다회용 지퍼백 사용해보고싶어서 실리콘지퍼백 샀어요.
# 가격이 좀 세지만 환경보호 차원에서 코엑스 행사중에 구입.
# review8: 몇달만에 와서 수세미 사갖고 갑니다!
# 수세미 품질 최고
# review9: 좋아요 좋아요
# review10: 항상 믿고 구매합니다 ㅎ
# Successfully stored reviews for ID 1 in the database
# ID 3: Extracted 10 reviews
# Review 1: 해피해빗에서 주는 리필스테이션 20%할인 쿠폰으로 샴푸를 사려고 처음 방문했어요.
# 평소 제로웨이스트에 관심이 있어 가본 여러 가게 중 공간을 가장 정감있게 꾸며둔 곳이었습니다. 품목별로 나뉘어 있어 원하는 물건을 찾기 편했고, 다른 곳에서도 판매하는 회사의 물건이어도 취급하는 종류가 더 다양해서 천천히 구경하는 재미도 있었습니다.
# 텀블러 이용하면 음료 1,000원 할인혜택이 있어서 챙겨 가서 마셨는데 깔끔하고 맛있어요☕️
#
# 무엇보다도 사장님께서 무척 친절하시고 제로웨이스트에 진심이신 게 느껴졌습니다. 플라스틱 칫솔 가져와서 새 칫솔로 교환하기, 정기적으로 열리는 장터 등 행사도 안내해주셨어요.
# 종종 들를게요☺️🌱
# Review 2: 병뚜껑도 재활용할 수 있고, 다양한 제로웨이스트 제품이 있어서 좋아요😁 아기자기한 물건들도 많고 가게가 예뻐서 구경만 가기에도 좋아요! 친절하신 사장님 번창하세요!!
# Review 3: 아기세제 구매했는데 좋아요
# Review 4: 바닐라라떼 진짜 맛있어요
# Review 5: 제로웨이스트샵
# Review 6: 친환경 관련 제품들을 판매한다길래 구경갔다가 살림생활하는데 친환경 실천하고싶기도 해도 천연 수세미도 구매했네요ㅎㅎ 직원분께서 제품에 대해 친절하게 설명해주세요 기억에 남는건 수제 파스타면 판매랑 공병을 들고가서 담아야하는 친환경 세제들도 판매하고있어요~
# Review 7: 이런곳 너무 좋아요 ♥️
# Review 8: 이런 가게가 집과 멀지 않은 곳에 있다는 사실에 동네애정도가 +10% 정도 상승했어요~
# 아기자기한 제품들 디피 구경하는 즐거움부터 소분샵이지만 좋은 제품들 쇼핑하는 재미와 쓰레기배출없는 쇼핑을 했다는 기쁨까지!
#
# 정말 좋은 가게예요~ 흥하셨으면 좋겠습니다! 또 갈께요~
# Review 9: 친절해요
# Review 10: 항상 친절하세요~^^
# 좋은 상품 합리적으로 구매할 수 있고 지구에도 보탬이 되는 것 같아 좋아요!
# Binding variables for SQL query:
# review1: 해피해빗에서 주는 리필스테이션 20%할인 쿠폰으로 샴푸를 사려고 처음 방문했어요.
# 평소 제로웨이스트에 관심이 있어 가본 여러 가게 중 공간을 가장 정감있게 꾸며둔 곳이었습니다. 품
# review2: 병뚜껑도 재활용할 수 있고, 다양한 제로웨이스트 제품이 있어서 좋아요😁 아기자기한 물건들도 많고 가게가 예뻐서 구경만 가기에도 좋아요! 친절하신 사장님 번창하세요!!
# review3: 아기세제 구매했는데 좋아요
# review4: 바닐라라떼 진짜 맛있어요
# review5: 제로웨이스트샵
# review6: 친환경 관련 제품들을 판매한다길래 구경갔다가 살림생활하는데 친환경 실천하고싶기도 해도 천연 수세미도 구매했네요ㅎㅎ 직원분께서 제품에 대해 친절하게 설명해주세요 기억에 남는건 수제
# review7: 이런곳 너무 좋아요 ♥️
# review8: 이런 가게가 집과 멀지 않은 곳에 있다는 사실에 동네애정도가 +10% 정도 상승했어요~
# 아기자기한 제품들 디피 구경하는 즐거움부터 소분샵이지만 좋은 제품들 쇼핑하는 재미와 쓰레기배
# review9: 친절해요
# review10: 항상 친절하세요~^^
# 좋은 상품 합리적으로 구매할 수 있고 지구에도 보탬이 되는 것 같아 좋아요!
# Successfully stored reviews for ID 3 in the database
# ID 4: Extracted 9 reviews
# Review 1: ㅡ
# Review 2: 굿
# Review 3: 굿
# Review 4: 좋아요
# Review 5: 맛있게 간단히 먹기 좋은 곳
# Review 6: 굿
# Review 7: 굿
# Review 8: 솜사탕
# Review 9: 좋아요
# Binding variables for SQL query:
# review1: ㅡ
# review2: 굿
# review3: 굿
# review4: 좋아요
# review5: 맛있게 간단히 먹기 좋은 곳
# review6: 굿
# review7: 굿
# review8: 솜사탕
# review9: 좋아요
# Successfully stored reviews for ID 4 in the database
# ID 5: Extracted 10 reviews
# Review 1: 우리 동네 착한가게, 세제랑 칫솔 규매했어요.
# Review 2: 정말 상세하게 설명해주셔서 좋았구 어떻게 시간가는지 모를정도로 몰입해서 만들수 있었어요 결과물도 넘 맘에들었구 어버이날 선물로 딱인거 같아요! 다시한번 환경에 대해 생각할수있는 시간이였고, 작은거라도 실천을 해야겠다 느꼈어요 :) 뜻깊은 시간이였습니다
# Review 3: 원데이 클래스 듣고 맘에드는 물건있어서 구매해요!
# 가격도 합리적이고 친환경적이라 너무 좋아요^^
# Review 4: 비누 공방은 처음이었는데 초보도 하기쉽게 친절하게 설명해주시고 향, 색 개인취향에 맞게 골라서 만들어서 너무 좋았어요!!
# Review 5: 우리 동네에 보물 같은 곳이에요 🙂
# 오늘은 주방세제 리필하고, 칫솔 구매했어요
# Review 6: 오랜만에 들려서 칫솔이랑 필요한 것들 구매했어요. 필요할때 마다 구매하니 낭비하지 않아서 좋고
# 포장지가 없어서 지구를 살리는 기분이 들어 좋네요 많이들 오셔서 지구 살리기 동참해요
# Review 7: 두피케어 원데이 클래스 들었는데 선생님이 친절하시면서 전문성도 있으셔서 수업을 잘 따라갈 수 있게 상세히 설명을 잘해주세요~!
# 좋은 원료 엄선해서 아낌없이 사용해 샴푸바와 허브린스 향이 너무너무 좋아요!
#
# 두피 상태에 맞는 샴푸바도 만들고 관리방법까지 알려주셔서 너무 알찬 수업이었어요! 기존에 쓰던 샴푸도 간김에 리필도 해보고 이런 샵과 공방이 있어서 너무 좋아요👍🏻👍🏻
# Review 8: 샴푸바 원데이클래스 처음해봤는데 어렵지않고 넘 재밌네요😊 원장님 친절하시고 샴푸바 퀄리티도 높게 나옵니다👍👍👍
# Review 9: 주방세제 리필하고 브리타 정수기 재활용 했습니다 다음엔 우유팩을 모아가야겠어요!
# Review 10: 주방세제, 세탁세제 리필해왔어요, 마음이 든든해요
# Binding variables for SQL query:
# review1: 우리 동네 착한가게, 세제랑 칫솔 규매했어요.
# review2: 정말 상세하게 설명해주셔서 좋았구 어떻게 시간가는지 모를정도로 몰입해서 만들수 있었어요 결과물도 넘 맘에들었구 어버이날 선물로 딱인거 같아요! 다시한번 환경에 대해 생각할수있는 시
# review3: 원데이 클래스 듣고 맘에드는 물건있어서 구매해요!
# 가격도 합리적이고 친환경적이라 너무 좋아요^^
# review4: 비누 공방은 처음이었는데 초보도 하기쉽게 친절하게 설명해주시고 향, 색 개인취향에 맞게 골라서 만들어서 너무 좋았어요!!
# review5: 우리 동네에 보물 같은 곳이에요 🙂
# 오늘은 주방세제 리필하고, 칫솔 구매했어요
# review6: 오랜만에 들려서 칫솔이랑 필요한 것들 구매했어요. 필요할때 마다 구매하니 낭비하지 않아서 좋고
# 포장지가 없어서 지구를 살리는 기분이 들어 좋네요 많이들 오셔서 지구 살리기 동참해
# review7: 두피케어 원데이 클래스 들었는데 선생님이 친절하시면서 전문성도 있으셔서 수업을 잘 따라갈 수 있게 상세히 설명을 잘해주세요~!
# 좋은 원료 엄선해서 아낌없이 사용해 샴푸바와 허브린스
# review8: 샴푸바 원데이클래스 처음해봤는데 어렵지않고 넘 재밌네요😊 원장님 친절하시고 샴푸바 퀄리티도 높게 나옵니다👍👍👍
# review9: 주방세제 리필하고 브리타 정수기 재활용 했습니다 다음엔 우유팩을 모아가야겠어요!
# review10: 주방세제, 세탁세제 리필해왔어요, 마음이 든든해요
# Successfully stored reviews for ID 5 in the database
# ID 6: Extracted 10 reviews
# Review 1: 공간이 매우 편안하고 따듯해요. 제로웨이스트관련 다양한제품 볼수있어서 좋았고 직원분들이 굉장히 친절하시고 잘 설명해주셔서 감사했어요. 올해말까지 20프로 세일이라니 가까운분들 들려보시면 좋을듯요. 생필품들 쟁이러 한번 더 방문해야겠어요 :)
# Review 2: 친환경 제품들 좋아요! 친절하게 설명해주셔서 고맙습니다~!
# Review 3: 제로웨이스트숍! 세제리필존부터 여러 제품들이 많아요! 작두콩차도 소분해서 팝니다!
# Review 4: 제로웨이스트샵이 많지않은데 멀지않은곳에있네요. 제품이 다양하진않지만 알짜배기 상품들로만 채워져있어요. 매장도 아기자기 이뻐요. 좋은뜻을 가지신분들이 번창하셔야합니다. 자주갈께요~~
# Review 5: 좋아요
# Review 6: 암사역 근처 제로웨이스트샵
# 작은 플라스틱 병뚜껑이나 종이팩 등 수거도 여러가지 하고 판매 품목도 다양하고 좋아요
# Review 7: 좋아요
# Review 8: .
# Review 9: 가까운데에 있어서 너무 감사하구요, 이것저것 많이 알려주시고 친절하세요:-) 다음엔 다른 것들도 도전해볼까봐요
# Review 10: 자주 이용하려고요
# Binding variables for SQL query:
# review1: 공간이 매우 편안하고 따듯해요. 제로웨이스트관련 다양한제품 볼수있어서 좋았고 직원분들이 굉장히 친절하시고 잘 설명해주셔서 감사했어요. 올해말까지 20프로 세일이라니 가까운분들 들려
# review2: 친환경 제품들 좋아요! 친절하게 설명해주셔서 고맙습니다~!
# review3: 제로웨이스트숍! 세제리필존부터 여러 제품들이 많아요! 작두콩차도 소분해서 팝니다!
# review4: 제로웨이스트샵이 많지않은데 멀지않은곳에있네요. 제품이 다양하진않지만 알짜배기 상품들로만 채워져있어요. 매장도 아기자기 이뻐요. 좋은뜻을 가지신분들이 번창하셔야합니다. 자주갈께요~~
# review5: 좋아요
# review6: 암사역 근처 제로웨이스트샵
# 작은 플라스틱 병뚜껑이나 종이팩 등 수거도 여러가지 하고 판매 품목도 다양하고 좋아요
# review7: 좋아요
# review8: .
# review9: 가까운데에 있어서 너무 감사하구요, 이것저것 많이 알려주시고 친절하세요:-) 다음엔 다른 것들도 도전해볼까봐요
# review10: 자주 이용하려고요
# Successfully stored reviews for ID 6 in the database
# ID 7: Extracted 10 reviews
# Review 1: 세제 리필을 위해 방문했는데 어느 브랜드의 제품인지 명시되어 있으면 좋겠습니다.
# Review 2: 더피커 너무 가보고싶었는데 드디어 방문했어요!! 꼭 필요한것만 샀는데도 왠지 모르게 기분이 좋고 뿌듯했어요٩(ˊᗜˋ)و 집에 사용하는 용품들 하나씩 하나씩 제로웨이스트로 바꾸는중이라 주기적으로 들를거같아요☺🫶🏻🫶🏻
# Review 3: 너무 좋아하는 곳! 식재료를 쓰레기 없이 구매할 수 있습니다 공간도 예뻐서 구경할 만해요
# Review 4: 구경하는것만으로도 재밌어요
# Review 5: 선물용으로 스테인레스 빨대와 빨대설거지용 솔을 구매했습니다.
# 빨대의 경우 구부러진 빨대와 일자용 빨대로 나뉘어져 있어 선택할 수 있어서 좋았습니다.
# 사장님이 너무 친절하셔서 질문하기도 편했고 환경에 대해 생각해보는 시간이었습니다!
# Review 6: 종류가 다양해요
# Review 7: 다양한 진환경제품 판매하는곳
# Review 8: 용기를 가져가면 할인도 되고 합리적으로 내가
# 필요한 물품만 사게 되서 너무 좋습니다.
# 조금씩 자주 사서 1인가구인 저에겐 매우 편리합니다.
# Review 9: 좋아하는 제로웨이스트 가게예요. 종이팩이나 병뚜껑, 종이완충재, 쇼핑백, 브리타 필터, 아이스팩, 유리병 등 자원순환하러 방문하는데 항상 친절하게 맞아주십니다! 시기별로 자원순환 품목은 달라질 수 있으니 전화로 문의 후에 방문하세요
# Review 10: 자원순환하러 주기적으로 방문합니다! 이날은 멸균팩, 유리병 6개, 에코백 가지고 방문했습니다. 물건 사면 가끔 유통기한 (유통기한=/=소비기한) 지났지만 사용하는 데엔 문제 없는 물건들 나눠주셔서 잘 쓰고 있습니다. 오래오래 있어주세요 🍀
# Binding variables for SQL query:
# review1: 세제 리필을 위해 방문했는데 어느 브랜드의 제품인지 명시되어 있으면 좋겠습니다.
# review2: 더피커 너무 가보고싶었는데 드디어 방문했어요!! 꼭 필요한것만 샀는데도 왠지 모르게 기분이 좋고 뿌듯했어요٩(ˊᗜˋ)و 집에 사용하는 용품들 하나씩 하나씩 제로웨이스트로 바꾸는중이
# review3: 너무 좋아하는 곳! 식재료를 쓰레기 없이 구매할 수 있습니다 공간도 예뻐서 구경할 만해요
# review4: 구경하는것만으로도 재밌어요
# review5: 선물용으로 스테인레스 빨대와 빨대설거지용 솔을 구매했습니다.
# 빨대의 경우 구부러진 빨대와 일자용 빨대로 나뉘어져 있어 선택할 수 있어서 좋았습니다.
# 사장님이 너무 친절하셔서 질문하
# review6: 종류가 다양해요
# review7: 다양한 진환경제품 판매하는곳
# review8: 용기를 가져가면 할인도 되고 합리적으로 내가
# 필요한 물품만 사게 되서 너무 좋습니다.
# 조금씩 자주 사서 1인가구인 저에겐 매우 편리합니다.
# review9: 좋아하는 제로웨이스트 가게예요. 종이팩이나 병뚜껑, 종이완충재, 쇼핑백, 브리타 필터, 아이스팩, 유리병 등 자원순환하러 방문하는데 항상 친절하게 맞아주십니다! 시기별로 자원순환
# review10: 자원순환하러 주기적으로 방문합니다! 이날은 멸균팩, 유리병 6개, 에코백 가지고 방문했습니다. 물건 사면 가끔 유통기한 (유통기한=/=소비기한) 지났지만 사용하는 데엔 문제 없는
# Successfully stored reviews for ID 7 in the database
# ID 8: Extracted 9 reviews
# Review 1: 좋아요
# Review 2: 자원순환(병뚜껑)하러 갔는데 사장님이 친절하게 맞아주셨어요! 그리고 비요뜨 초코링을 리필스테이션으로 이용할 수 있어서 정말 좋았습니다 ㅜㅜ 강남역 근처 갈 때 또 이용하고 싶어요 오래오래 있어주세여!
# Review 3: 상품들이 많고, 분위기가 좋아요. 그리고 직원분도 친절해서 좋았어요
# Review 4: 제로 웨이스트 샵 덕분愛🫶🏻🩷
# Review 5: 생활용품이 아주 잘 되어있어요.
# 그리고 아주 멋져요.
# Review 6: 😃
# Review 7: 덕분애 덕분에 제로웨이스트 제품과 리필스테이션 모두 잘 이용하고 있습니다 ♻️
# Review 8: 애견인, 녹색생활 실천하는 에코피플에게 선물하려고 방문했다가 너무 잘해놓아서 깜짝 놀랐어요. 지구를 생각하는 진심이 느껴지는 브랜드였고 널리널리 확장하셔서 제주도에도 매장 만들어주세요ㅠㅠㅠ 너무 좋았어요…다음엔 선물이 아니라 우리집에 놓을 친환경제품들 사러 갈게요 !
# Review 9: 공병 가져가서 세제 리필 완료입니다~!
# Binding variables for SQL query:
# review1: 좋아요
# review2: 자원순환(병뚜껑)하러 갔는데 사장님이 친절하게 맞아주셨어요! 그리고 비요뜨 초코링을 리필스테이션으로 이용할 수 있어서 정말 좋았습니다 ㅜㅜ 강남역 근처 갈 때 또 이용하고 싶어요
# review3: 상품들이 많고, 분위기가 좋아요. 그리고 직원분도 친절해서 좋았어요
# review4: 제로 웨이스트 샵 덕분愛🫶🏻🩷
# review5: 생활용품이 아주 잘 되어있어요.
# 그리고 아주 멋져요.
# review6: 😃
# review7: 덕분애 덕분에 제로웨이스트 제품과 리필스테이션 모두 잘 이용하고 있습니다 ♻️
# review8: 애견인, 녹색생활 실천하는 에코피플에게 선물하려고 방문했다가 너무 잘해놓아서 깜짝 놀랐어요. 지구를 생각하는 진심이 느껴지는 브랜드였고 널리널리 확장하셔서 제주도에도 매장 만들어주
# review9: 공병 가져가서 세제 리필 완료입니다~!
# Successfully stored reviews for ID 8 in the database
# No review elements found for ID 9
# ID 9: Extracted 0 reviews
# Binding variables for SQL query:
# Successfully stored reviews for ID 9 in the database
# ID 10: Extracted 9 reviews
# Review 1: 와 계속 인터넷 또는 연남동만 이용하다가
# 시흥에 이런곳이 있다니 너무 기뻐요
# 대표님도 친절하시고 자주 찾아뵐게요💚
# 시흥에서 계속 있어 주세요 🙏
# Review 2: 제로웨이스트 제품이 총 망라된 곳이네요! 선물하기 좋은 아이템도 많고요. 세제류 리필도 가능해서 좋아요.
# Review 3: 다양한 제로웨이스트 물품들을 두루 갖추고 있는 곳이네요! 멸균팩과 브리타필터 수거도 해주셔서 너무 좋았습니다. 필요한 물품을 구매하러 종종 들러야겠어요. 오늘은 주방세제를 리필해왔네요.
# Review 4: 우리동네 제로웨이스트샵 도돌이상점 ☺️🎶
# 이전부터 사용하던 예고은 제품들과 리얼수세미 구매해봤어요 :) 제로웨이스트로의 삶은 쉽지않지만 그래도 지구를 생각하는 마음을 가지고 환경을 생각한 제품들 사용하면서 조금씩 삶속에서 친환경을 실천해보려합니다 ✨
# 샵 구경하면서 모르던것도 알게되고 많이 배우는 시간 가졌어요! 좋은 취지를 가진 좋은 가게가 동네에 있으니 동기부여가 되네요 ☺️👍
# Review 5: 좋은 제품들이 많아요!
# Review 6: 오늘까지 20% 할인 한다고 해서 필요한 물품 구입 했어요~ 일회용 빨대 사용은 이제 그만 하려공
# 실리콘 빨대도 구입 했답니당!!^^ ㅋ 쪼아용
# Review 7: 자주 애용하는 친환경 상점
# 새재를 바꾸고 나서 가려움증이
# 사라졌어요~~ ㅎㅎ
# 환경도 생각하고 좋은 제품
# 사용해서 너무 좋아요
# 옷에 남아 있을 미세프라스틱
# 이제 걱정 안해서 더욱 조아용!!♡♡
# 사장님이 제품 하나하나 설명도
# 잘해 주셔서 더욱 신뢰가 간답니당
# 용기를 가져오시면 요렇게 중량을
# 체크해서 금액 책정이 되어요
# 집에서 새재통이 안생겨서
# 너무 좋아요 부피큰 세제통이라
# 쓰레기 버릴때마다 불편했는뎅 ㅋㄱ
# 늠 쪼아요 다음에 또 리필 하러 갈께용
# Review 8: 늘 항상 이용하는 곳이랍니다
# 생필품은 여기서 거의 구입을
# 하고 있답니다.,
# 샴푸,반려묘비누,주방세재,세탁세재
# ㅋㅋ  가지각색에 제품들이 많아
# 갈때마다 눈을 뗄수가 없어요
#
# 이번에는 고무장갑에 구멍이 나서
# 고무장갑을 사러 갔는데 🌈   색들의
# 장갑들이 있어서 신기방기~~
# 전 노랑,주황 두개를 샀어요 ㅎㅎ
# 예뻐서 하기 싫은 설거지 할때
# 기분 좋게 할수 있을듯이요~~
# Review 9: 와 썬크림!! 정말 감명받았어요~!!
# 올 여름 우리집 썬크림은 비건썬크림 입니당♡
# Binding variables for SQL query:
# review1: 와 계속 인터넷 또는 연남동만 이용하다가
# 시흥에 이런곳이 있다니 너무 기뻐요
# 대표님도 친절하시고 자주 찾아뵐게요💚
# 시흥에서 계속 있어 주세요 🙏
# review2: 제로웨이스트 제품이 총 망라된 곳이네요! 선물하기 좋은 아이템도 많고요. 세제류 리필도 가능해서 좋아요.
# review3: 다양한 제로웨이스트 물품들을 두루 갖추고 있는 곳이네요! 멸균팩과 브리타필터 수거도 해주셔서 너무 좋았습니다. 필요한 물품을 구매하러 종종 들러야겠어요. 오늘은 주방세제를 리필해왔
# review4: 우리동네 제로웨이스트샵 도돌이상점 ☺️🎶
# 이전부터 사용하던 예고은 제품들과 리얼수세미 구매해봤어요 :) 제로웨이스트로의 삶은 쉽지않지만 그래도 지구를 생각하는 마음을 가지고 환경을
# review5: 좋은 제품들이 많아요!
# review6: 오늘까지 20% 할인 한다고 해서 필요한 물품 구입 했어요~ 일회용 빨대 사용은 이제 그만 하려공
# 실리콘 빨대도 구입 했답니당!!^^ ㅋ 쪼아용
# review7: 자주 애용하는 친환경 상점
# 새재를 바꾸고 나서 가려움증이
# 사라졌어요~~ ㅎㅎ
# 환경도 생각하고 좋은 제품
# 사용해서 너무 좋아요
# 옷에 남아 있을 미세프라스틱
# 이제 걱정 안해서 더욱 조
# review8: 늘 항상 이용하는 곳이랍니다
# 생필품은 여기서 거의 구입을
# 하고 있답니다.,
# 샴푸,반려묘비누,주방세재,세탁세재
# ㅋㅋ  가지각색에 제품들이 많아
# 갈때마다 눈을 뗄수가 없어요
#
# 이번에
# review9: 와 썬크림!! 정말 감명받았어요~!!
# 올 여름 우리집 썬크림은 비건썬크림 입니당♡
# Successfully stored reviews for ID 10 in the database
# No review elements found for ID 11
# ID 11: Extracted 0 reviews
# Binding variables for SQL query:
# Successfully stored reviews for ID 11 in the database
# ID 12: Extracted 10 reviews
# Review 1: 굿
# Review 2: 좋아요~
# Review 3: 득템했어요
# Review 4: 노원가면 항상들리게되요
# Review 5: 좋아요
# Review 6: 자주
# Review 7: 종류가 많지 않아 아쉽지만 바지하나 맘에드는거 샀어요
# Review 8: ㅇㅋ
# Review 9: 좋아요
# Review 10: 그저
# Binding variables for SQL query:
# review1: 굿
# review2: 좋아요~
# review3: 득템했어요
# review4: 노원가면 항상들리게되요
# review5: 좋아요
# review6: 자주
# review7: 종류가 많지 않아 아쉽지만 바지하나 맘에드는거 샀어요
# review8: ㅇㅋ
# review9: 좋아요
# review10: 그저
# Successfully stored reviews for ID 12 in the database
# ID 14: Extracted 9 reviews
# Review 1: 예쁜거 많이 팔아요
# Review 2: 잠시 들른 것만으로도 기분이 좋아지는 독립서점이에요. 다음에는 좋아하는 친구 데리고 또 방문해야겠어요.
# Review 3: 아기자기하고 포근한 공간이예요ㅎㅎ
# 책도 많고 지구작가님이 직접 그린 포스터도 다 이쁘네요🩵
# Review 4: 사장님의 드립커피 최고! 책과 커피향기의 조화는 그저 우와아아아!
# Review 5: 지구불시착 첫방문인데 분위기 따뜻하고 좋아요🤎🤎
# Review 6: 포근한 분위기의 서점입니다. 주인되시는 작가분이 큐레이션한 책들이 좋고 책 읽기 좋은 분위기예요. 커피도 맛있고요. 조만간 근처의 장소로 이전한다고 하네요. 종종 방문하고 싶어지는 장소입니다.
# Review 7: 조용히 책읽기 좋아요. 다들 친절하셔서 마음까지 포근포근해지는 곳.
# 다른 서점에서는 보기 힘든 책들도 많았어요!!!
# Review 8: 너무 재미난책들도 많고 커피가격도 착하지만 커피도 진하고 맛있었었어요 책제목들이 신박해서 즐겁고 신나게 구경했습니다 쥔장도 친절하시고 설명도 잘해주시고
# Review 9: 노원! 기억할께요
# Binding variables for SQL query:
# review1: 예쁜거 많이 팔아요
# review2: 잠시 들른 것만으로도 기분이 좋아지는 독립서점이에요. 다음에는 좋아하는 친구 데리고 또 방문해야겠어요.
# review3: 아기자기하고 포근한 공간이예요ㅎㅎ
# 책도 많고 지구작가님이 직접 그린 포스터도 다 이쁘네요🩵
# review4: 사장님의 드립커피 최고! 책과 커피향기의 조화는 그저 우와아아아!
# review5: 지구불시착 첫방문인데 분위기 따뜻하고 좋아요🤎🤎
# review6: 포근한 분위기의 서점입니다. 주인되시는 작가분이 큐레이션한 책들이 좋고 책 읽기 좋은 분위기예요. 커피도 맛있고요. 조만간 근처의 장소로 이전한다고 하네요. 종종 방문하고 싶어지는
# review7: 조용히 책읽기 좋아요. 다들 친절하셔서 마음까지 포근포근해지는 곳.
# 다른 서점에서는 보기 힘든 책들도 많았어요!!!
# review8: 너무 재미난책들도 많고 커피가격도 착하지만 커피도 진하고 맛있었었어요 책제목들이 신박해서 즐겁고 신나게 구경했습니다 쥔장도 친절하시고 설명도 잘해주시고
# review9: 노원! 기억할께요
# Successfully stored reviews for ID 14 in the database
# ID 15: Extracted 10 reviews
# Review 1: 향상 친절하고 물건이 신선하고 좋아요
# Review 2: 좋아요
# Review 3: 굿
# Review 4: 굿
# Review 5: 굿
# Review 6: 굿
# Review 7: 신선하고 유기농이라 안심하고 먹기 좋아요
# Review 8: 굿굿
# Review 9: 할인제품 잘샀어요
# Review 10: 굿
# Binding variables for SQL query:
# review1: 향상 친절하고 물건이 신선하고 좋아요
# review2: 좋아요
# review3: 굿
# review4: 굿
# review5: 굿
# review6: 굿
# review7: 신선하고 유기농이라 안심하고 먹기 좋아요
# review8: 굿굿
# review9: 할인제품 잘샀어요
# review10: 굿
# Successfully stored reviews for ID 15 in the database
# ID 16: Extracted 10 reviews
# Review 1: 좋아요
# Review 2: ~♡
# Review 3: 🥰
# Review 4: 굿
# Review 5: 가까운곳에 있어서좋아요~^^
# Review 6: 맛있어요.
# Review 7: 좋아요
# Review 8: 좋아요
# Review 9: 좋아요
# Review 10: 좋아요
# Binding variables for SQL query:
# review1: 좋아요
# review2: ~♡
# review3: 🥰
# review4: 굿
# review5: 가까운곳에 있어서좋아요~^^
# review6: 맛있어요.
# review7: 좋아요
# review8: 좋아요
# review9: 좋아요
# review10: 좋아요
# Successfully stored reviews for ID 16 in the database
# ID 17: Extracted 10 reviews
# Review 1: 첫 방문때보다 물품도 늘어나고
# 공간도 더 쾌적해진 것 같아요 ❣️
# 그동안 사용했던 브리타 필터 쌓여있어서
# 여기 있는 수거함에 배출도 하고
# 용품 살것 있나 둘러봤는데 마침 정수 필터 리필 제품있어서 한번 써보려고 구매했어요 🐳
# Review 2: 섬유유연제, 구연산, 과탄산소다 리필했어요! 리필스테이션이 가까이있어서 좋네요~
# Review 3: 동네에 있어서 좋아요
# Review 4: 샴푸리필하러갔어요 상점이 많지않고 멀어도 가치있는 걸음이라 생각합니다~
# 제로웨이스트샵 응원합니다!
# Review 5: 동네에 이런곳이 있어서 좋아요
# Review 6: 친절
# Review 7: 부모님이랑 자주갑니다
# Review 8: 좋아요
# Review 9: 👍🏼  좋아요
# Review 10: 👍
# Binding variables for SQL query:
# review1: 첫 방문때보다 물품도 늘어나고
# 공간도 더 쾌적해진 것 같아요 ❣️
# 그동안 사용했던 브리타 필터 쌓여있어서
# 여기 있는 수거함에 배출도 하고
# 용품 살것 있나 둘러봤는데 마침 정수
# review2: 섬유유연제, 구연산, 과탄산소다 리필했어요! 리필스테이션이 가까이있어서 좋네요~
# review3: 동네에 있어서 좋아요
# review4: 샴푸리필하러갔어요 상점이 많지않고 멀어도 가치있는 걸음이라 생각합니다~
# 제로웨이스트샵 응원합니다!
# review5: 동네에 이런곳이 있어서 좋아요
# review6: 친절
# review7: 부모님이랑 자주갑니다
# review8: 좋아요
# review9: 👍🏼  좋아요
# review10: 👍
# Successfully stored reviews for ID 17 in the database
# ID 18: Extracted 10 reviews
# Review 1: 미숫가루. 짱 맛있당. 흑미 팝콘도 올려주심 🤍🖤
# Review 2: 재방문 의사 100프로.....
# Review 3: 리필스테이션 이용하고 탄소중립포인트 받았어요 ㅎㅎ 다음에 가면 브런치 먹고 싶어요!
# Review 4: 얘기는 정말 많이 했었는데 연희동 올일이 그동안 많이 없어서 처음으로 방문했어요. 장소가 일단 매우 코지하고 커피와 디저트도 맛있어서 좋았어요. 리필스테이션도 있고 다양한 아이템을 살 수 있고 그러한 것들이 잘 조화를 이루는 곳인 것 같아요. 근처에 살면 매일매일 가고싶네요!
# Review 5: 커피가 맛있는 제로 웨이스트샵
# Review 6: 비건 카페인데 많이 안 비싸고 분위기가 아늑해요
# Review 7: 연희동에 살고 싶어요 보틀라운지 때문에☺️
# Review 8: 두유스콘 하나 포장해서 먹었는데 너무 맛있네요오 🩷🩷 기름기는 살짝 있지만 담백하고 입 안에서 치덕거리는 식감이라 딱 취향 저격이었어요!!!🩷 두유 향이 은은하게 솔솔 나고 ... ! 매장에서는 비건 플레이트나 샐러드도 팔아서 담에 함 방문해서 먹어보려구요 😝 여러 식료품도 많이 팔고 조용한 분위기에 작업하기도 좋아 추천드립니닷
# Review 9: 굿
# Review 10: 예전에도 몇번 방문했는데 노 일회용품 카페라서 좋아요
# Binding variables for SQL query:
# review1: 미숫가루. 짱 맛있당. 흑미 팝콘도 올려주심 🤍🖤
# review2: 재방문 의사 100프로.....
# review3: 리필스테이션 이용하고 탄소중립포인트 받았어요 ㅎㅎ 다음에 가면 브런치 먹고 싶어요!
# review4: 얘기는 정말 많이 했었는데 연희동 올일이 그동안 많이 없어서 처음으로 방문했어요. 장소가 일단 매우 코지하고 커피와 디저트도 맛있어서 좋았어요. 리필스테이션도 있고 다양한 아이템을
# review5: 커피가 맛있는 제로 웨이스트샵
# review6: 비건 카페인데 많이 안 비싸고 분위기가 아늑해요
# review7: 연희동에 살고 싶어요 보틀라운지 때문에☺️
# review8: 두유스콘 하나 포장해서 먹었는데 너무 맛있네요오 🩷🩷 기름기는 살짝 있지만 담백하고 입 안에서 치덕거리는 식감이라 딱 취향 저격이었어요!!!🩷 두유 향이 은은하게 솔솔 나고 ...
# review9: 굿
# review10: 예전에도 몇번 방문했는데 노 일회용품 카페라서 좋아요
# Successfully stored reviews for ID 18 in the database
# ID 20: Extracted 10 reviews
# Review 1: 친구 꼬셔서 비건음식 처음 도전했습니다! 비건고기 처음먹어보는데 너무 놀랐어요! 이렇게 부드럽고 맛있다고? 고기보다 좋은데?하면서요
# 너무너무 맛있고 즐거운 식사했습니다! 샌드위치 둘이서 먹으며 맛있는 칭찬의말만 입에서 계속 나왔습니다! 까르보나라 파스타도 처음에 놀랐어요! 제가알던 크림의 하얀색이아니라 붉은기 있는 소스라서요! 넓적한 면은 씹을때 식감이 좋고 맛은 카레맛처럼 느껴졌는데 맞는지는 모르겠네요 ㅎㅎ 파스타도 간장불구이 샌드위치도 모두모두 빈접시가 되었습니다. 후식도 정말좋았는데 두유아이스크림이 특히 맛있네요 ㅎㅎ 브라우니랑 잘어우러져요!
# 이런 비건메뉴라면 비건식 문제없겠다 생각들었어요!
# 첫비건인데 첫인상을 아주 좋게 만들어주셔서 넘 감사합니다😋
# Review 2: 귀여운 로고와 인테리어, 건강한 기분으로 즐길 수 있는 비건 메뉴까지🌿! 커리는 향신료 맛이 강한 하얀 커리였는데 다른 곳에서 맛볼 수 없는 달냥만의 맛이라 좋았어요👍 두유 아이스크림은 고소하고 녹차 티라미수도 많이 달지 않아서 단 걸 크게 안 좋아하는 사람 입맛에 딱이었습니다😆 메뉴도 맛있고 사장님들께서도 친절하셔서 기분 좋은 한끼 먹을 수 있어요.
# Review 3: 항상 오고싶었던곳인데 드뎌와보내요
# 아이와함께오기도 좋은거같고.너무 맛있어서 또와보자구 하네요
# 동네에 이런곳이 있다니 너무 좋아요^^♡♡
# Review 4: 달냥 두번째 방문이고 친구랑 같이 평일 들렀는데 여전히 맛있게 잘 먹고가요! 비건이라 더 맛나고 좋은 곳
# Review 5: 음식부터 디저트까지 다 너무 맛있어요! 다음에 혜화에 오게되면 또 방문하고 싶어요.
# Review 6: 비건카페입니다. 조용하고 얘기하기 좋아요.
# 우리딸은 여기 파는 식사 메뉴 다 먹었봤다구. 하네요
# 비건 지향 작은딸 둔 덕에 혜화동에서 밥 먹고 추운 바람 맞으면 800 미터 걸어왔어요.
# 궁시렁대는 아부지와 큰딸 끌고ㅋㅋ
# 음료도. 굿! 식사도 가능해요~
# Review 7: 고기를 안먹는데 이런 경험 좋네요~ 청양마요치킨인가? 랑 샌드위치 먹었는데 전 너무 맛있게 먹었어요!! 오랜만에 그런 식감을 느껴보기도 했고요~ 가격도 괜찮고 메뉴도 많아서 담에 또 다른메뉴 먹으러 가볼거예요~ 그리고 다들 동물친화적이라서 개데리고 가기도 좋습니다! 물론 매너는 지켜야겠죠!
# Review 8: 커피 디저트
# 다 맛있었어요
# 분위기도 좋고 친절하시고 몸에도 좋을것 같어요
# 자주 올게요
# Review 9: 잘 먹었습니다!!
# Review 10: 분위기도 좋고 커피도 너무너무 맛있어요!! 디저트 사진은 없지만 전에 녹차 머핀 추천해주셔서 먹어봤는데 커피랑 잘 어울리더라구요 추천합니다🧡
# Binding variables for SQL query:
# review1: 친구 꼬셔서 비건음식 처음 도전했습니다! 비건고기 처음먹어보는데 너무 놀랐어요! 이렇게 부드럽고 맛있다고? 고기보다 좋은데?하면서요
# 너무너무 맛있고 즐거운 식사했습니다! 샌드위치
# review2: 귀여운 로고와 인테리어, 건강한 기분으로 즐길 수 있는 비건 메뉴까지🌿! 커리는 향신료 맛이 강한 하얀 커리였는데 다른 곳에서 맛볼 수 없는 달냥만의 맛이라 좋았어요👍 두유 아이스
# review3: 항상 오고싶었던곳인데 드뎌와보내요
# 아이와함께오기도 좋은거같고.너무 맛있어서 또와보자구 하네요
# 동네에 이런곳이 있다니 너무 좋아요^^♡♡
# review4: 달냥 두번째 방문이고 친구랑 같이 평일 들렀는데 여전히 맛있게 잘 먹고가요! 비건이라 더 맛나고 좋은 곳
# review5: 음식부터 디저트까지 다 너무 맛있어요! 다음에 혜화에 오게되면 또 방문하고 싶어요.
# review6: 비건카페입니다. 조용하고 얘기하기 좋아요.
# 우리딸은 여기 파는 식사 메뉴 다 먹었봤다구. 하네요
# 비건 지향 작은딸 둔 덕에 혜화동에서 밥 먹고 추운 바람 맞으면 800 미터 걸어왔
# review7: 고기를 안먹는데 이런 경험 좋네요~ 청양마요치킨인가? 랑 샌드위치 먹었는데 전 너무 맛있게 먹었어요!! 오랜만에 그런 식감을 느껴보기도 했고요~ 가격도 괜찮고 메뉴도 많아서 담에
# review8: 커피 디저트
# 다 맛있었어요
# 분위기도 좋고 친절하시고 몸에도 좋을것 같어요
# 자주 올게요
# review9: 잘 먹었습니다!!
# review10: 분위기도 좋고 커피도 너무너무 맛있어요!! 디저트 사진은 없지만 전에 녹차 머핀 추천해주셔서 먹어봤는데 커피랑 잘 어울리더라구요 추천합니다🧡
# Successfully stored reviews for ID 20 in the database
# No review elements found for ID 21
# ID 21: Extracted 0 reviews
# Binding variables for SQL query:
# Successfully stored reviews for ID 21 in the database
# No review elements found for ID 22
# ID 22: Extracted 0 reviews
# Binding variables for SQL query:
# Successfully stored reviews for ID 22 in the database
# ID 23: Extracted 10 reviews
# Review 1: 특색있는 선물 사기 좋아요
# Review 2: 환경을 지켜요
# Review 3: 수가 얼마없어 귀한 리필스테이션입니다.
# 재활용 자원수거도 해주고 필요한 만큼 물건도 살수 있어서 좋아요.
# Review 4: 자주가요 환경보호 같이해요
# Review 5: 사장님 친절하시고 가게 분위기도 아늑하니 좋아요
# 이번엔 그린블리스 운동양말과 S22멘톨+와사비 바디클렌져 구매했어요! 자주 갔더니 기억해 주시더라고요ㅎㅎ 감사합니다~
# Review 6: 굿
# Review 7: 좋아요
# Review 8: 집 근처 가까이 제로웨이스트샵이 있다는 사실이 매우 행복합니다💚 여기 유기농 혼합잡곡이 넘 맛있어서 통들고 가서 소분해와요~ 1, 2인 가구이신 분들이나 쌍 소비 많지 않으신 자취러분들은 순환지구로 통 들고 오셔요! 서울페이결제도 가능합니다.
# Review 9: 가까운 곳에 #템페가 팔고있었다니ㅜㅠ좋아요
# 처음 사보는 수세미 설명도 해주셨어요
# Review 10: 💬 페스코테리언이 꼭 와보고 싶었던 곳! 집 근처에 있다면 자주 방문했을 거예요 🥹
#    🎁 팔로산토 1.8 (180원/g) / 삼베화장솜 0.25 / 대나무화장솜 0.1
#   👥  남자친구랑
#   ⭐️ 5.0 - 주관적 별점 : 지구를 지켜라 🌏
# Binding variables for SQL query:
# review1: 특색있는 선물 사기 좋아요
# review2: 환경을 지켜요
# review3: 수가 얼마없어 귀한 리필스테이션입니다.
# 재활용 자원수거도 해주고 필요한 만큼 물건도 살수 있어서 좋아요.
# review4: 자주가요 환경보호 같이해요
# review5: 사장님 친절하시고 가게 분위기도 아늑하니 좋아요
# 이번엔 그린블리스 운동양말과 S22멘톨+와사비 바디클렌져 구매했어요! 자주 갔더니 기억해 주시더라고요ㅎㅎ 감사합니다~
# review6: 굿
# review7: 좋아요
# review8: 집 근처 가까이 제로웨이스트샵이 있다는 사실이 매우 행복합니다💚 여기 유기농 혼합잡곡이 넘 맛있어서 통들고 가서 소분해와요~ 1, 2인 가구이신 분들이나 쌍 소비 많지 않으신 자취
# review9: 가까운 곳에 #템페가 팔고있었다니ㅜㅠ좋아요
# 처음 사보는 수세미 설명도 해주셨어요
# review10: 💬 페스코테리언이 꼭 와보고 싶었던 곳! 집 근처에 있다면 자주 방문했을 거예요 🥹
#    🎁 팔로산토 1.8 (180원/g) / 삼베화장솜 0.25 / 대나무화장솜 0.1
#
# Successfully stored reviews for ID 23 in the database
# ID 24: Extracted 10 reviews
# Review 1: 친구 생일선물 사러 갔는데 추천도 잘해주시고 좋았어요~ 사오고 카톡 선물하기에서 한 번 봤는데 선물하기가 더 저렴하긴 하네욤ㅠㅠ 그치만 선물포장, 샘플 챙겨주신거 생각하면 비슷한거같긴 합니당
# Review 2: 친절하고 프로페셔널한 직원들, 청결하고 고급스러운 매장과 퀄리티 높은 제품들.
# (+)영어로 소통 가능한 직원이 있는 것도 장점이네요
# Review 3: 매장 아기자기 하게 예쁘고 하나하나 친절하게 설명 잘 해주셔서 좋았습니다
# 라벤더 라인 3월달까지 할인 들어간다해서 다른 제품하고 같이 좋은 가격에 구입 했습니다
# 라벤더 향기 포근해서 다 쓰면 재방문 하려구요💜
# Review 4: 아로마티카 리필스테이션 최고에요 ♻️ 새로 옮긴 매장도 쾌적하고, 직원분들도 모두 친절하셔서 갈 때마다 기분 좋습니다! (제가 폐장시간 다 되서 갔는데도 서두르지 않고 차분히 서비스해주셔서 정말 감사했어요! 죄송한 마음에 쿠키를 조금 준비해가서 드렸는데, 작게나마 기분전환 하셨길 바랍니다!)
# Review 5: 아무 생각 없이 방문했다가 너무 너무 친절하신게 기억에 남아서 리뷰 남겨요 ! 직접 하나 하나 다 설명해주시고 테스트도 도와주시고요, 고객에게 맞는 제품을 잘 추천해주세요 ㅎㅎ 최고입니다 ! 제품 퀄리티도 좋고, 향도 정말 좋아요 🥰
# Review 6: 카카오톡 선물하기만 하다가 매장은 처음 가봤는데 설명도 추천도 잘해주셔서 좋은 선물 구매했습니다 장한별직원님 너무너무 친절하시고 전문성있는
# 응대에 감동받았어요 감사해요!
# 제품도 좋고 매장 분위기도 아주 좋았습니다
# Review 7: 원데이 클래스 들었는데 무척 유익한 시간이었습니다~!!
# Review 8: 매장 건물이 너무 예쁘고 직원들이 친절해요
# Review 9: 다양한 에센셜오일 친절하게 설명해주셔용!!!
# 연말에 선물하기 좋은 세트들이 많습니당
# Review 10: 굿
# Binding variables for SQL query:
# review1: 친구 생일선물 사러 갔는데 추천도 잘해주시고 좋았어요~ 사오고 카톡 선물하기에서 한 번 봤는데 선물하기가 더 저렴하긴 하네욤ㅠㅠ 그치만 선물포장, 샘플 챙겨주신거 생각하면 비슷한거
# review2: 친절하고 프로페셔널한 직원들, 청결하고 고급스러운 매장과 퀄리티 높은 제품들.
# (+)영어로 소통 가능한 직원이 있는 것도 장점이네요
# review3: 매장 아기자기 하게 예쁘고 하나하나 친절하게 설명 잘 해주셔서 좋았습니다
# 라벤더 라인 3월달까지 할인 들어간다해서 다른 제품하고 같이 좋은 가격에 구입 했습니다
# 라벤더 향기 포근해
# review4: 아로마티카 리필스테이션 최고에요 ♻️ 새로 옮긴 매장도 쾌적하고, 직원분들도 모두 친절하셔서 갈 때마다 기분 좋습니다! (제가 폐장시간 다 되서 갔는데도 서두르지 않고 차분히 서비
# review5: 아무 생각 없이 방문했다가 너무 너무 친절하신게 기억에 남아서 리뷰 남겨요 ! 직접 하나 하나 다 설명해주시고 테스트도 도와주시고요, 고객에게 맞는 제품을 잘 추천해주세요 ㅎㅎ 최
# review6: 카카오톡 선물하기만 하다가 매장은 처음 가봤는데 설명도 추천도 잘해주셔서 좋은 선물 구매했습니다 장한별직원님 너무너무 친절하시고 전문성있는
# 응대에 감동받았어요 감사해요!
# 제품도
# review7: 원데이 클래스 들었는데 무척 유익한 시간이었습니다~!!
# review8: 매장 건물이 너무 예쁘고 직원들이 친절해요
# review9: 다양한 에센셜오일 친절하게 설명해주셔용!!!
# 연말에 선물하기 좋은 세트들이 많습니당
# review10: 굿
# Successfully stored reviews for ID 24 in the database
# ID 25: Extracted 10 reviews
# Review 1: 세탁양모볼 구입했어요
# 제로웨이스트 실천을 위해 더 번창하시길요
# Review 2: 리필 좋아요
# Review 3: 제로웨이스트 페스티벌에서 고체치약을 구매했습니다. 알맹상점만 보통 방문해서 안녕상점은 처음이었어요. 좋은 제품 잘 사용했어요 ^^
# Review 4: 꽃송이 세안비누로 세수하면 뽀드득해져서 좋아용🤍
# 오늘은 늦게 가서 그런지 샘플 비누가 없어서 아쉬웠어용 😭
# Review 5: 친환경. 원목 제품
# Review 6: 대나무 칫솔이랑 고체치약, 샴푸바 필요해서 갔어요~ 친환경 제품들 다양하고, 자원 순환 코너도 깔끔하게 잘 되어있어서 넘 좋아요~!!
# Review 7: 사용하기 넘 편해요
# Review 8: 애용하기 편해요
# Review 9: 대관이 간편해요
# Review 10: 숨겨진 보물같은 제웨샵 발견!ㅎㅎ
# 근처 갈일 있어서 지나가다가, 계획에 없던 급방문이었어서 리필용기가 없었는데 사탕수수 리필용기도 함께 팔고 계셔서 세탁세제 리필 구매했어요~
# 제품도 다양하고 사장님도 친절하셔요!
# 재방문 의사 100%입니당ㅎㅎ
#
# 자원순환코너도 종류별로 잘 되어있어서 다음에 방문할땐 깨끗하게 씻어말린 멸균팩이랑 병뚜껑들 가져가려구요~
# 대나무 칫솔도 교체할때 일반쓰레기로 버려야하나 했는데 자원 순환 된다니까 더 좋네용!
# Binding variables for SQL query:
# review1: 세탁양모볼 구입했어요
# 제로웨이스트 실천을 위해 더 번창하시길요
# review2: 리필 좋아요
# review3: 제로웨이스트 페스티벌에서 고체치약을 구매했습니다. 알맹상점만 보통 방문해서 안녕상점은 처음이었어요. 좋은 제품 잘 사용했어요 ^^
# review4: 꽃송이 세안비누로 세수하면 뽀드득해져서 좋아용🤍
# 오늘은 늦게 가서 그런지 샘플 비누가 없어서 아쉬웠어용 😭
# review5: 친환경. 원목 제품
# review6: 대나무 칫솔이랑 고체치약, 샴푸바 필요해서 갔어요~ 친환경 제품들 다양하고, 자원 순환 코너도 깔끔하게 잘 되어있어서 넘 좋아요~!!
# review7: 사용하기 넘 편해요
# review8: 애용하기 편해요
# review9: 대관이 간편해요
# review10: 숨겨진 보물같은 제웨샵 발견!ㅎㅎ
# 근처 갈일 있어서 지나가다가, 계획에 없던 급방문이었어서 리필용기가 없었는데 사탕수수 리필용기도 함께 팔고 계셔서 세탁세제 리필 구매했어요~
# 제품
# Successfully stored reviews for ID 25 in the database
# ID 26: Extracted 9 reviews
# Review 1: 제로웨이스트 성지🌱 다양하고 저렴한 제품군이 준비되있어서 입문하기 좋아요👍  제로웨이스트 워크샵 중에 들렸는데 방문하기 너무 잘한듯🥰
# Review 2: 리필스테이션에서 헤어토닉 구매했습니다. 필요한 알맹이만 산다는 것이 좋네요. 제품품질은 사용 후 공유할 수 있을것 같아요
# Review 3: 굳
# Review 4: 알맹이맘 살 수 있는 알맹상점!
# 코코넛 청크도 원하는 만큼만 구입 가능해서 소량구입으로 자주 가요~
# Review 5: 지나가다가 구경해벌까 하고 들어오기는 어려울것 같지만 매장이 3층에 있는점. 매장입구에 나눔식으로 물품이 놓여져 있는점, 제품을 재활용 용기에 담아 그람대비 스스로 계산해서 상품을 구매하는것 사실 다 한국에서는 굉장히 생소한 스토어인데 취지가 너무 좋고, 또 나한 사람이 무슨 큰 영향을 주겠어 하지만 이런 상품도 선택할수 있다는 다양성에 응원하고싶어요. 상품이야 당연히 마트같은 시판 상품이 더 편하고 좋을?수도 있겠지만 불필요한것 또 다시 쓸수 있는것 등 생각해봐야 하는 질문을 던지는 곳이기도 한것 같습니다. 음식재료들도 소량으로 판매하는 것 넘 아이디어♡
# Review 6: 요즘 제로웨이스트에 관심이 많은데
# 망원 들렸다가 제로웨이스트 샵 있어서 방문했어요
# 다양한 제품이 많았고
# 리필스테이션도 신기했어요 주변에 생활하는 1인가구에게 너무 좋아보여요
# 망원 올때마다 들릴거 같아요
# Review 7: 직원분이 너무 친절하시고 독서링 만드는 것도 너무 재밌었어요! 다음에 또 올게요~
# Review 8: 고장난 우산 기증하고!
# 모아둔 멸균팩 플라스틱 뚜껑 등등 가져가서 적립받구
# 가져간 용기랑 봉투에 필요한 것들 쇼핑해왔어요~~
# 착한 제품들 감사합니다💚
# Review 9: 많은 것을 배우고 느낄 수 있었던 좋은 시간이었습니다..! 그리고 사장님의 선한 에너지를 느껴서 방문 내내 기분도 정말 좋았네요~ 다음엔 마포점도 방문해 더 다양한 제품들을 보고싶어요ㅎㅎ
#
# 참고로 제가 밀크티를 정말 좋아하는데 사장님께서 (제로웨이스트로 판매하시는) 밀크티 원액을 사용해 즉석에서 밀크티를 만들어주셨거든요! 어떤 카페에서 마시는 것보다도 더 맛있었네요! 다음엔 빈용기 들고가서 원액 구매해야겠습니다~ 넘 감사했고 앞으로 좋은 일만 가득하시길 바래요!
# Binding variables for SQL query:
# review1: 제로웨이스트 성지🌱 다양하고 저렴한 제품군이 준비되있어서 입문하기 좋아요👍  제로웨이스트 워크샵 중에 들렸는데 방문하기 너무 잘한듯🥰
# review2: 리필스테이션에서 헤어토닉 구매했습니다. 필요한 알맹이만 산다는 것이 좋네요. 제품품질은 사용 후 공유할 수 있을것 같아요
# review3: 굳
# review4: 알맹이맘 살 수 있는 알맹상점!
# 코코넛 청크도 원하는 만큼만 구입 가능해서 소량구입으로 자주 가요~
# review5: 지나가다가 구경해벌까 하고 들어오기는 어려울것 같지만 매장이 3층에 있는점. 매장입구에 나눔식으로 물품이 놓여져 있는점, 제품을 재활용 용기에 담아 그람대비 스스로 계산해서 상품을
# review6: 요즘 제로웨이스트에 관심이 많은데
# 망원 들렸다가 제로웨이스트 샵 있어서 방문했어요
# 다양한 제품이 많았고
# 리필스테이션도 신기했어요 주변에 생활하는 1인가구에게 너무 좋아보여요
# 망원
# review7: 직원분이 너무 친절하시고 독서링 만드는 것도 너무 재밌었어요! 다음에 또 올게요~
# review8: 고장난 우산 기증하고!
# 모아둔 멸균팩 플라스틱 뚜껑 등등 가져가서 적립받구
# 가져간 용기랑 봉투에 필요한 것들 쇼핑해왔어요~~
# 착한 제품들 감사합니다💚
# review9: 많은 것을 배우고 느낄 수 있었던 좋은 시간이었습니다..! 그리고 사장님의 선한 에너지를 느껴서 방문 내내 기분도 정말 좋았네요~ 다음엔 마포점도 방문해 더 다양한 제품들을 보고싶
# Successfully stored reviews for ID 26 in the database
# ID 27: Extracted 8 reviews
# Review 1: 서울역 옥상, 서울시내를 한눈에 바라보는 푸릇한 공간에 자리잡은 카페 겸 친환경 의미있는 소비 가게
# 진정한 샴푸 두피브러쉬는 여기서만 살 수 있다.
# Review 2: 나무 미니 국자, 실리콘 휴대용 접이식 컵 추천!
# Review 3: 기분좋은곳
# Review 4: 굿
# Review 5: 진짜 리사이클링 제품이 가득가득한곳🙆🏻‍♀️
#
# 아쉬운건 가게를 찾기 힘든 위치라는거..요것만 보완이 되면 좋을듯해용
# Review 6: 1회용품이 정말 없어서 커피 주문했는데 테이크아웃 못하고 마시고 컵 반납하고 갔어요
# 취지에 공감합니다만 급할 때는 안 마실 거 같긴 해요
# Review 7: 최고
# Review 8: 여기가 핫플!
# 강추해요
# Binding variables for SQL query:
# review1: 서울역 옥상, 서울시내를 한눈에 바라보는 푸릇한 공간에 자리잡은 카페 겸 친환경 의미있는 소비 가게
# 진정한 샴푸 두피브러쉬는 여기서만 살 수 있다.
# review2: 나무 미니 국자, 실리콘 휴대용 접이식 컵 추천!
# review3: 기분좋은곳
# review4: 굿
# review5: 진짜 리사이클링 제품이 가득가득한곳🙆🏻‍♀️
#
# 아쉬운건 가게를 찾기 힘든 위치라는거..요것만 보완이 되면 좋을듯해용
# review6: 1회용품이 정말 없어서 커피 주문했는데 테이크아웃 못하고 마시고 컵 반납하고 갔어요
# 취지에 공감합니다만 급할 때는 안 마실 거 같긴 해요
# review7: 최고
# review8: 여기가 핫플!
# 강추해요
# Successfully stored reviews for ID 27 in the database
# ID 30: Extracted 10 reviews
# Review 1: 제로웨이스트 매장이에요. 여러 샤워 비누와 다양한 친환경 제품이 있어요. 구경하기 좋더라구요~
# Review 2: 친구 선물, 제가 쓸 물건들 구매했습니다!
# 이 날 이후로 꾸준히 쓰고 있어요!!
# 지구에도 좋은 제품 팔아주셔서 감사합니당
#
# 마무리 포장까지 넘 감사합니당
# Review 3: ^^
# Review 4: 생각보다 엄청 낡앗움 ㅠㅠ
# Review 5: 특색있는 소품들, 생활용품들이 많더라고요.
# 에코백 사서 잘 사용중이에요^^
# Review 6: 필요한 물품들이 있어서 들렀는데 환경을 생각한 제로웨이스트 제품들을 살 수 있어서 기분이 더 좋았어요☺️
# Review 7: 포장도 섬세하고
# 플라스틱 재활용 체험도 재밌었어요!!
#
# 폰케이스도 제작요청했는데 이뻐요!!
# Review 8: 인스타로만 보다가 매장은 처음 방문했습니다 협소하긴 하지만 있을만한 건 다 있습니다 게다가 플라스틱 업사이클링 가구도 있어서 구경하는 재미가 있었습니다! 시계와 핸드폰 케이스가 참 탐나더군요
#
# 긴가민가 했는데 핸드폰 케이스는 인스타로 예약받고 매장에 픽업만 가능하다고 하니 참고하시면 좋을 것 같습니다
# Review 9: 똑똑하고 이쁜제품 많아서bb 구경하는것도재밌고 신선해요 성수에 이런곳있는줄 몰랐어요
# Review 10: 굿굿 너무 좋은 추억 만들었습니다! 재활용 열심히 해야겠어요!!!
# Binding variables for SQL query:
# review1: 제로웨이스트 매장이에요. 여러 샤워 비누와 다양한 친환경 제품이 있어요. 구경하기 좋더라구요~
# review2: 친구 선물, 제가 쓸 물건들 구매했습니다!
# 이 날 이후로 꾸준히 쓰고 있어요!!
# 지구에도 좋은 제품 팔아주셔서 감사합니당
#
# 마무리 포장까지 넘 감사합니당
# review3: ^^
# review4: 생각보다 엄청 낡앗움 ㅠㅠ
# review5: 특색있는 소품들, 생활용품들이 많더라고요.
# 에코백 사서 잘 사용중이에요^^
# review6: 필요한 물품들이 있어서 들렀는데 환경을 생각한 제로웨이스트 제품들을 살 수 있어서 기분이 더 좋았어요☺️
# review7: 포장도 섬세하고
# 플라스틱 재활용 체험도 재밌었어요!!
#
# 폰케이스도 제작요청했는데 이뻐요!!
# review8: 인스타로만 보다가 매장은 처음 방문했습니다 협소하긴 하지만 있을만한 건 다 있습니다 게다가 플라스틱 업사이클링 가구도 있어서 구경하는 재미가 있었습니다! 시계와 핸드폰 케이스가 참
# review9: 똑똑하고 이쁜제품 많아서bb 구경하는것도재밌고 신선해요 성수에 이런곳있는줄 몰랐어요
# review10: 굿굿 너무 좋은 추억 만들었습니다! 재활용 열심히 해야겠어요!!!
# Successfully stored reviews for ID 30 in the database
# ID 32: Extracted 9 reviews
# Review 1: 제로웨이스트 소품샵~
# 가격 부담스럽지 않아서 어쩌다 보니 하나 겟~
# Review 2: 식빵수세미 귀여워요
# Review 3: 계단이 가파르긴하지만,, 위층 아래층 꼼꼼히 잘 둘러봤어요, 예쁜게 많아여
# Review 4: 트리트먼트바 구매했는데 잘 쓰고 있어요~~
# 조용히 구경하기 좋아요
# Review 5: 상품이 많고 환경을 아끼는 물건들이 많아요!
# Review 6: 다양한 상품 중에 맘에 드는 가방이 있어서 바로 샀어요ㅋㅋㅋ 아주 만족스럽습니다
# Review 7: 재밌는 제로웨이스트 소품들이 많아서 구경하는 재미도 있고 구매도 했습니다! 낱개로 구매할 수 있어서 좋은 거 같아요 :)
# Review 8: 을지 소품숍
# Review 9: 친환경으로 만든 생활용품 소품샵이어서 색다른 경험이었어요!! 자취하고 싶은 생각이 물씬 나더라구요ㅋㅋㅋ 그리고 과자들도 팔았는데 홍차비스킷이랑 우유팝콘 진짜 맛있어요.. 본연의 재료 맛이 잘 느껴지고 국산제품이라서 더 믿음이 갔습니다!!
# Binding variables for SQL query:
# review1: 제로웨이스트 소품샵~
# 가격 부담스럽지 않아서 어쩌다 보니 하나 겟~
# review2: 식빵수세미 귀여워요
# review3: 계단이 가파르긴하지만,, 위층 아래층 꼼꼼히 잘 둘러봤어요, 예쁜게 많아여
# review4: 트리트먼트바 구매했는데 잘 쓰고 있어요~~
# 조용히 구경하기 좋아요
# review5: 상품이 많고 환경을 아끼는 물건들이 많아요!
# review6: 다양한 상품 중에 맘에 드는 가방이 있어서 바로 샀어요ㅋㅋㅋ 아주 만족스럽습니다
# review7: 재밌는 제로웨이스트 소품들이 많아서 구경하는 재미도 있고 구매도 했습니다! 낱개로 구매할 수 있어서 좋은 거 같아요 :)
# review8: 을지 소품숍
# review9: 친환경으로 만든 생활용품 소품샵이어서 색다른 경험이었어요!! 자취하고 싶은 생각이 물씬 나더라구요ㅋㅋㅋ 그리고 과자들도 팔았는데 홍차비스킷이랑 우유팝콘 진짜 맛있어요.. 본연의 재
# Successfully stored reviews for ID 32 in the database
# ID 34: Extracted 10 reviews
# Review 1: 제로웨이스트, 친환경 제품 등등 다양한 물품이 가득한곳. 특히 차(옥수수, 작두콩)가 너무 맛있어요!
# Review 2: 지구도살리고~~~다양한  수거함도 있어요~~~
# Review 3: 고무장갑이 좋아요.
# Review 4: 좋은상퓸들이 많아요
# Review 5: 좋아요👍🏼
# Review 6: 자연을 살리는 지구마을이에요
# Review 7: 굿
# Review 8: 주방세제 구매했어요
# Review 9: 지구도 살리면서 좋은 물건들이 너무 많아요! 동네에 이런 곳이 더 많아졌으면 좋겠어요~
# Review 10: 좋아요~
# Binding variables for SQL query:
# review1: 제로웨이스트, 친환경 제품 등등 다양한 물품이 가득한곳. 특히 차(옥수수, 작두콩)가 너무 맛있어요!
# review2: 지구도살리고~~~다양한  수거함도 있어요~~~
# review3: 고무장갑이 좋아요.
# review4: 좋은상퓸들이 많아요
# review5: 좋아요👍🏼
# review6: 자연을 살리는 지구마을이에요
# review7: 굿
# review8: 주방세제 구매했어요
# review9: 지구도 살리면서 좋은 물건들이 너무 많아요! 동네에 이런 곳이 더 많아졌으면 좋겠어요~
# review10: 좋아요~
# Successfully stored reviews for ID 34 in the database
# ID 36: Extracted 10 reviews
# Review 1: 인테리어 예뻐서 들어갔다가 쇼핑하고 온 곳
# 샴푸바 샀어요~!
# 사면서도 지구 돕는일이라고 생각들어서 좋았던 것 같아요^^! 플라스틱 사용을 줄이겠다는 다짐과 함께 나왔답니당...총총..
# Review 2: 귀여운 당근 양말과 초콜렛 구입했어요 🧑‍🌾🥕
# 키링이랑 다양한 실용적인 물건들이 많아요!
# Review 3: 바오밥나무 퍼퓸 샴푸바, 현무암 비누받침 샀어요. 친환경 제품이 굉장히 다양해서 좋아요!!♡ +종이백 기부하실 수 있어요!!
# Review 4: 리필스테이션 이용하는게 참 지구를 위해 좋은 아이디어라구 생각이들었고 낭비 없이 살아가는 법에 대해 많이 생각하게 되는 좋은 공간입니다
# Review 5: 제로웨이스트 제품이많아요
# Review 6: 튜브짜개 노랑노랑
# 온몸비누 자몽향킁킁
# Review 7: 지구를 위한 선물, 쓰레기 없는 선물이라는 취지가 너무 좋은것 같아요! 귀여운 물건들도 있고 구경하다 지갑이 열리게 되네요😂
# Review 8: 고체치약 사러 다녀왔어요.
# 어떤지 사용해보고 계속 이용하고 싶네요.
# 세제도 담아 팔고 친환경  물건들이 많아 좋으네요~  친절하셔서 또 방문각♡
# Review 9: 물건이 다양해서 좋아요.
# Review 10: 굿굿
# Binding variables for SQL query:
# review1: 인테리어 예뻐서 들어갔다가 쇼핑하고 온 곳
# 샴푸바 샀어요~!
# 사면서도 지구 돕는일이라고 생각들어서 좋았던 것 같아요^^! 플라스틱 사용을 줄이겠다는 다짐과 함께 나왔답니당...
# review2: 귀여운 당근 양말과 초콜렛 구입했어요 🧑‍🌾🥕
# 키링이랑 다양한 실용적인 물건들이 많아요!
# review3: 바오밥나무 퍼퓸 샴푸바, 현무암 비누받침 샀어요. 친환경 제품이 굉장히 다양해서 좋아요!!♡ +종이백 기부하실 수 있어요!!
# review4: 리필스테이션 이용하는게 참 지구를 위해 좋은 아이디어라구 생각이들었고 낭비 없이 살아가는 법에 대해 많이 생각하게 되는 좋은 공간입니다
# review5: 제로웨이스트 제품이많아요
# review6: 튜브짜개 노랑노랑
# 온몸비누 자몽향킁킁
# review7: 지구를 위한 선물, 쓰레기 없는 선물이라는 취지가 너무 좋은것 같아요! 귀여운 물건들도 있고 구경하다 지갑이 열리게 되네요😂
# review8: 고체치약 사러 다녀왔어요.
# 어떤지 사용해보고 계속 이용하고 싶네요.
# 세제도 담아 팔고 친환경  물건들이 많아 좋으네요~  친절하셔서 또 방문각♡
# review9: 물건이 다양해서 좋아요.
# review10: 굿굿
# Successfully stored reviews for ID 36 in the database
# 리뷰 탭을 찾지 못하였습니다: Message:
# Stacktrace:
# 	GetHandleVerifier [0x008FB8E3+45827]
# 	(No symbol) [0x0088DCC4]
# 	(No symbol) [0x0078150F]
# 	(No symbol) [0x007C20BC]
# 	(No symbol) [0x007C216B]
# 	(No symbol) [0x007FE0F2]
# 	(No symbol) [0x007E2E44]
# 	(No symbol) [0x007FC034]
# 	(No symbol) [0x007E2B96]
# 	(No symbol) [0x007B6998]
# 	(No symbol) [0x007B751D]
# 	GetHandleVerifier [0x00BB4513+2899763]
# 	GetHandleVerifier [0x00C0793D+3240797]
# 	GetHandleVerifier [0x009813B4+593364]
# 	GetHandleVerifier [0x009882DC+621820]
# 	(No symbol) [0x008970A4]
# 	(No symbol) [0x008937A8]
# 	(No symbol) [0x00893947]
# 	(No symbol) [0x008859FE]
# 	BaseThreadInitThunk [0x76D8FCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77CB80CE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77CB809E+238]
#
# 리뷰 탭을 찾지 못하였습니다: Message:
# Stacktrace:
# 	GetHandleVerifier [0x008FB8E3+45827]
# 	(No symbol) [0x0088DCC4]
# 	(No symbol) [0x0078150F]
# 	(No symbol) [0x007C20BC]
# 	(No symbol) [0x007C216B]
# 	(No symbol) [0x007FE0F2]
# 	(No symbol) [0x007E2E44]
# 	(No symbol) [0x007FC034]
# 	(No symbol) [0x007E2B96]
# 	(No symbol) [0x007B6998]
# 	(No symbol) [0x007B751D]
# 	GetHandleVerifier [0x00BB4513+2899763]
# 	GetHandleVerifier [0x00C0793D+3240797]
# 	GetHandleVerifier [0x009813B4+593364]
# 	GetHandleVerifier [0x009882DC+621820]
# 	(No symbol) [0x008970A4]
# 	(No symbol) [0x008937A8]
# 	(No symbol) [0x00893947]
# 	(No symbol) [0x008859FE]
# 	BaseThreadInitThunk [0x76D8FCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77CB80CE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77CB809E+238]
#
# 리뷰 탭을 찾지 못하였습니다 for id: 37
# div.input_box > input.input_search 태그를 찾지 못하였습니다. Message:
# Stacktrace:
# 	GetHandleVerifier [0x008FB8E3+45827]
# 	(No symbol) [0x0088DCC4]
# 	(No symbol) [0x0078150F]
# 	(No symbol) [0x007C20BC]
# 	(No symbol) [0x007C216B]
# 	(No symbol) [0x007FE0F2]
# 	(No symbol) [0x007E2E44]
# 	(No symbol) [0x007FC034]
# 	(No symbol) [0x007E2B96]
# 	(No symbol) [0x007B6998]
# 	(No symbol) [0x007B751D]
# 	GetHandleVerifier [0x00BB4513+2899763]
# 	GetHandleVerifier [0x00C0793D+3240797]
# 	GetHandleVerifier [0x009813B4+593364]
# 	GetHandleVerifier [0x009882DC+621820]
# 	(No symbol) [0x008970A4]
# 	(No symbol) [0x008937A8]
# 	(No symbol) [0x00893947]
# 	(No symbol) [0x008859FE]
# 	BaseThreadInitThunk [0x76D8FCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77CB80CE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77CB809E+238]
#
# ID 40: Extracted 5 reviews
# Review 1: 친절하세요
# Review 2: 가까운ㄷ ㅔ에 리필샾 있어서 좋아요 물건도 다양하고 친절하게 하나하나 절명해주시고욤 도또 갈게용
# Review 3: 걸어서 갈 수 있는 거리에 있어서 좋아요. 물건들 질도 좋고 매니저님도 친절하세요. 단골이 되었어요. 😃😄
# Review 4: 집 근처에 제로웨이스트샵이 생겨서 좋아요 👍
# Review 5: 친절하시고 물건도 좋아요. 꼭 재방문할게요!
# Binding variables for SQL query:
# review1: 친절하세요
# review2: 가까운ㄷ ㅔ에 리필샾 있어서 좋아요 물건도 다양하고 친절하게 하나하나 절명해주시고욤 도또 갈게용
# review3: 걸어서 갈 수 있는 거리에 있어서 좋아요. 물건들 질도 좋고 매니저님도 친절하세요. 단골이 되었어요. 😃😄
# review4: 집 근처에 제로웨이스트샵이 생겨서 좋아요 👍
# review5: 친절하시고 물건도 좋아요. 꼭 재방문할게요!
# Successfully stored reviews for ID 40 in the database
# Error occurred while processing search_name '허그어웨일' with id '41': Message: entryIframe
#
# ID 44: Extracted 10 reviews
# Review 1: 동네 제웨샵을 찾다가 알게되었어요!
#
# 이전에 친구에게 한 번 선물받고 알고만 있던 디어얼스!
#
# 가보니 너무 아늑하고 친절하셔서 구경하려다 고르고 골라 사왔습니다 ㅎㅎ
#
# 한달에 한번씩 제품 구성도 다르게한다고 들었는데 자주 찾아갈거같아요!
# Review 2: 좋아요
# Review 3: 지나가다 항상 궁금했는데 다른 제로웨이스트 샵들과 다르게 요란하지 않은 느낌(?) 이여서 좋았어요
# 소품샵 같기도 하고 아기자기 귀여워요😍
# 생각보다 필요했던 물건들도 많아서
# 다음에 또 방문 예정 입니다~
# 오늘도 텅장 될 뻔한거 참고 정말 필요한 제품들만 구매했어요😉
# Review 4: 제로웨이스트샵 다니는 거 좋아하는데 근처오면 또 들르고싶은 곳이었어요💛
# 깔끔하고 우디한 분위기가 너무 좋더라고요! 제품들도 흔치 않아서 구경하는 재미가 쏠쏠했습니다.
# 직원분도 엄청 친절하셔서 천천히 구경하기 좋았어요:)
# Review 5: 팔로산토와 고체치약을 구매했습니다. 매장이 깨끗하고 다른 제웨샵과 제품을 비교해서 좋았던 점은 품질이 좋은 수건 종류가 다양해서 보는 즐거움이 있었습니다.
# Review 6: 디어얼스!!!
#
# 집에 들어가는길 우연히 발견!!!
#
# 혁신파크에서 쓸어담장 행사!!!
#
# 둘러보다가 발견한 디어얼스!!!
#
# 다양한 유기농 물건들…
#
# 손수건 많이 사용하는 나!!!
#
# 유기농 면손수건이라~~~ 한번 사용해봐야지!!!
#
# 손수건 2개 구입!!! 아직 미사용!!!
#
# 조만간 사용해봐야지!!!
#
# 이쁜거 많이 있었는데…
#
# 매장도 길 건너편 녹번에 있네요…
#
# 기회가 되면 매장에서 더 많은 물건 구경하러 가야지!!!
# Review 7: 좋아요
# Review 8: 굿
# Review 9: 너무 아담하고 예쁜공간이에요. 수목금토만 영업해서 시간을 잘 맞춰오시면 지구를 살리는 제품들을 만날 수 있답니다.  제로웨이스트를 실천하시는분들 놀러가보세요^^
# Review 10: 굿
# Binding variables for SQL query:
# review1: 동네 제웨샵을 찾다가 알게되었어요!
#
# 이전에 친구에게 한 번 선물받고 알고만 있던 디어얼스!
#
# 가보니 너무 아늑하고 친절하셔서 구경하려다 고르고 골라 사왔습니다 ㅎㅎ
#
# 한달에
# review2: 좋아요
# review3: 지나가다 항상 궁금했는데 다른 제로웨이스트 샵들과 다르게 요란하지 않은 느낌(?) 이여서 좋았어요
# 소품샵 같기도 하고 아기자기 귀여워요😍
# 생각보다 필요했던 물건들도 많아서
# 다음에
# review4: 제로웨이스트샵 다니는 거 좋아하는데 근처오면 또 들르고싶은 곳이었어요💛
# 깔끔하고 우디한 분위기가 너무 좋더라고요! 제품들도 흔치 않아서 구경하는 재미가 쏠쏠했습니다.
# 직원분도 엄청
# review5: 팔로산토와 고체치약을 구매했습니다. 매장이 깨끗하고 다른 제웨샵과 제품을 비교해서 좋았던 점은 품질이 좋은 수건 종류가 다양해서 보는 즐거움이 있었습니다.
# review6: 디어얼스!!!
#
# 집에 들어가는길 우연히 발견!!!
#
# 혁신파크에서 쓸어담장 행사!!!
#
# 둘러보다가 발견한 디어얼스!!!
#
# 다양한 유기농 물건들…
#
# 손수건 많이 사용하는 나!!!
#
# 유
# review7: 좋아요
# review8: 굿
# review9: 너무 아담하고 예쁜공간이에요. 수목금토만 영업해서 시간을 잘 맞춰오시면 지구를 살리는 제품들을 만날 수 있답니다.  제로웨이스트를 실천하시는분들 놀러가보세요^^
# review10: 굿
# Successfully stored reviews for ID 44 in the database
# 리뷰 탭을 찾지 못하였습니다: Message:
# Stacktrace:
# 	GetHandleVerifier [0x008FB8E3+45827]
# 	(No symbol) [0x0088DCC4]
# 	(No symbol) [0x0078150F]
# 	(No symbol) [0x007C20BC]
# 	(No symbol) [0x007C216B]
# 	(No symbol) [0x007FE0F2]
# 	(No symbol) [0x007E2E44]
# 	(No symbol) [0x007FC034]
# 	(No symbol) [0x007E2B96]
# 	(No symbol) [0x007B6998]
# 	(No symbol) [0x007B751D]
# 	GetHandleVerifier [0x00BB4513+2899763]
# 	GetHandleVerifier [0x00C0793D+3240797]
# 	GetHandleVerifier [0x009813B4+593364]
# 	GetHandleVerifier [0x009882DC+621820]
# 	(No symbol) [0x008970A4]
# 	(No symbol) [0x008937A8]
# 	(No symbol) [0x00893947]
# 	(No symbol) [0x008859FE]
# 	BaseThreadInitThunk [0x76D8FCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77CB80CE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77CB809E+238]
#
# 리뷰 탭을 찾지 못하였습니다: Message:
# Stacktrace:
# 	GetHandleVerifier [0x008FB8E3+45827]
# 	(No symbol) [0x0088DCC4]
# 	(No symbol) [0x0078150F]
# 	(No symbol) [0x007C20BC]
# 	(No symbol) [0x007C216B]
# 	(No symbol) [0x007FE0F2]
# 	(No symbol) [0x007E2E44]
# 	(No symbol) [0x007FC034]
# 	(No symbol) [0x007E2B96]
# 	(No symbol) [0x007B6998]
# 	(No symbol) [0x007B751D]
# 	GetHandleVerifier [0x00BB4513+2899763]
# 	GetHandleVerifier [0x00C0793D+3240797]
# 	GetHandleVerifier [0x009813B4+593364]
# 	GetHandleVerifier [0x009882DC+621820]
# 	(No symbol) [0x008970A4]
# 	(No symbol) [0x008937A8]
# 	(No symbol) [0x00893947]
# 	(No symbol) [0x008859FE]
# 	BaseThreadInitThunk [0x76D8FCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77CB80CE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77CB809E+238]
#
# 리뷰 탭을 찾지 못하였습니다: Message:
# Stacktrace:
# 	GetHandleVerifier [0x008FB8E3+45827]
# 	(No symbol) [0x0088DCC4]
# 	(No symbol) [0x0078150F]
# 	(No symbol) [0x007C20BC]
# 	(No symbol) [0x007C216B]
# 	(No symbol) [0x007FE0F2]
# 	(No symbol) [0x007E2E44]
# 	(No symbol) [0x007FC034]
# 	(No symbol) [0x007E2B96]
# 	(No symbol) [0x007B6998]
# 	(No symbol) [0x007B751D]
# 	GetHandleVerifier [0x00BB4513+2899763]
# 	GetHandleVerifier [0x00C0793D+3240797]
# 	GetHandleVerifier [0x009813B4+593364]
# 	GetHandleVerifier [0x009882DC+621820]
# 	(No symbol) [0x008970A4]
# 	(No symbol) [0x008937A8]
# 	(No symbol) [0x00893947]
# 	(No symbol) [0x008859FE]
# 	BaseThreadInitThunk [0x76D8FCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77CB80CE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77CB809E+238]
#
# 리뷰 탭을 찾지 못하였습니다 for id: 47
# div.input_box > input.input_search 태그를 찾지 못하였습니다. Message:
# Stacktrace:
# 	GetHandleVerifier [0x008FB8E3+45827]
# 	(No symbol) [0x0088DCC4]
# 	(No symbol) [0x0078150F]
# 	(No symbol) [0x007C20BC]
# 	(No symbol) [0x007C216B]
# 	(No symbol) [0x007FE0F2]
# 	(No symbol) [0x007E2E44]
# 	(No symbol) [0x007FC034]
# 	(No symbol) [0x007E2B96]
# 	(No symbol) [0x007B6998]
# 	(No symbol) [0x007B751D]
# 	GetHandleVerifier [0x00BB4513+2899763]
# 	GetHandleVerifier [0x00C0793D+3240797]
# 	GetHandleVerifier [0x009813B4+593364]
# 	GetHandleVerifier [0x009882DC+621820]
# 	(No symbol) [0x008970A4]
# 	(No symbol) [0x008937A8]
# 	(No symbol) [0x00893947]
# 	(No symbol) [0x008859FE]
# 	BaseThreadInitThunk [0x76D8FCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77CB80CE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77CB809E+238]
#
# ID 49: Extracted 10 reviews
# Review 1: 맛있어요
# Review 2: 좋아 요
# Review 3: 좋아요
# Review 4: 굿
# Review 5: 저렴하게 잘 구매했어요~
# Review 6: 원하는 장소로 찾아와주시니 편리해서 좋네요 트럭에서 세제리필만 할 수 있는게 아니라 물건도 살 수있어 좋아요
# 세탁비누 필요했는데 ~ 다쓰고 또 예약하겠습니다 번창하세요.
# Review 7: 이벤트 응모해서 받는건데도 집앞까지 와줬어요~~~ 진짜 최고!!!!!
# 사실 친환경재료로만든 세제라 거품이 잘 안날 줄 알았는데.. 거품도 완전 잘나고 뽀독뽀독 기분좋아요~~^^
# 포레슈 고체치약도 엄청 잘쓰고있는데 앞으로 포레슈 리필트럭도 자주자주 애용할 것 같아요~~^^
# Review 8: 플로깅을 시작하면서 버려지는 쓰레기를 보고 많은것들을 되돌아보게 되었어요. 우리 생활에 플라스틱 없이는 안되는걸까요.. 매번 세탁세제나 주방세제,섬유유연제 구매할때마다 어마어마하게 쌓이는 프라스틱 용기들. 매일 사용하는 것들이라 소비도 많죠. 그만큼 플라스틱도 많이 버려지게 되구요. 그래서 친환경에 관심이 생기더라구요. 작은것부터 실천하려구요.그러다 리필해주는 포레슈 리필트럭을 알게 되었어요. 버려지는 플라스틱을 줄이고자 리필을 택했습니다. 필요할때마다 예약해서 리필하면 되니 편하고 좋네요! 앞으로 자주 애용하게 될것같아요. 번창하세요^^
# 많은 사람들이 리필트럭을 알았으면 좋겠어요!!!!
# 우리모두 지구를 위해 작은것부터 실천해봐요.
# Review 9: 집 앞까지 직접 와주셔서 원하는 세제를 바로 살 수 있어서 너무나 편했습니다! 게다가 전용 용기 덕분에 매번 다 쓸 때마다 버려야 하는 플라스틱 세제 용기를 줄일 수 있어서 좋았습니다. 최근 들어서 환경 오염에 관심이 많았는데, 리필 트럭을 통해서 직접 환경 오염을 줄이는 실천을 할 수 있어 뿌듯하네요! 세제 뿐만 아니라 비누, 샴푸바도 판매를 하고 있다고 하시니 앞으로도 자주 이용하도록 하겠습니다!
# Review 10: 좋아요
# Binding variables for SQL query:
# review1: 맛있어요
# review2: 좋아 요
# review3: 좋아요
# review4: 굿
# review5: 저렴하게 잘 구매했어요~
# review6: 원하는 장소로 찾아와주시니 편리해서 좋네요 트럭에서 세제리필만 할 수 있는게 아니라 물건도 살 수있어 좋아요
# 세탁비누 필요했는데 ~ 다쓰고 또 예약하겠습니다 번창하세요.
# review7: 이벤트 응모해서 받는건데도 집앞까지 와줬어요~~~ 진짜 최고!!!!!
# 사실 친환경재료로만든 세제라 거품이 잘 안날 줄 알았는데.. 거품도 완전 잘나고 뽀독뽀독 기분좋아요~~^^
# 포
# review8: 플로깅을 시작하면서 버려지는 쓰레기를 보고 많은것들을 되돌아보게 되었어요. 우리 생활에 플라스틱 없이는 안되는걸까요.. 매번 세탁세제나 주방세제,섬유유연제 구매할때마다 어마어마하게
# review9: 집 앞까지 직접 와주셔서 원하는 세제를 바로 살 수 있어서 너무나 편했습니다! 게다가 전용 용기 덕분에 매번 다 쓸 때마다 버려야 하는 플라스틱 세제 용기를 줄일 수 있어서 좋았습
# review10: 좋아요
# Successfully stored reviews for ID 49 in the database
# ID 51: Extracted 9 reviews
# Review 1: 커피가 맛있어요.
# Review 2: 친환경 용기 효율적임
# Review 3: 좋아요
# Review 4: 여러가지 예쁜 물건들이 있어요
# 커피는 텀블러가져가면 1000원이나 할인해줍니다
# 오늘은 바닐라빈라떼가 없어서 헤이즐럿라떼로 마셨습니다
# 아이스도 가격은 같은것 같아요
# Review 5: 좋아요~
# Review 6: 너무 예쁜 화분이 있어서 물어봤더니,
# 흙으로 만든 화분이라고 하더라구여!! 그래서 구매했는데 상추모종도 서비스로 주셨어요 ㅋㅋ 이벤트중이라고 하시네요~
# Review 7: 샴푸랑 바디워시 리필하고 세안비누도 사왔어요~^^
# Review 8: 남양주제로웨이스트샵 중엔 상품이 가장 많은것 같네요~ 화장품 종류도 있고 필요한 만큼 리필할 수 있어서 경제적이에요ㅎ
# Review 9: 하남에서 제일 가까워서 찾아왔어요~!
# 환경을 생각하는 이런 제로웨이스트샵은 너무 좋은거같아요♡
# Binding variables for SQL query:
# review1: 커피가 맛있어요.
# review2: 친환경 용기 효율적임
# review3: 좋아요
# review4: 여러가지 예쁜 물건들이 있어요
# 커피는 텀블러가져가면 1000원이나 할인해줍니다
# 오늘은 바닐라빈라떼가 없어서 헤이즐럿라떼로 마셨습니다
# 아이스도 가격은 같은것 같아요
# review5: 좋아요~
# review6: 너무 예쁜 화분이 있어서 물어봤더니,
# 흙으로 만든 화분이라고 하더라구여!! 그래서 구매했는데 상추모종도 서비스로 주셨어요 ㅋㅋ 이벤트중이라고 하시네요~
# review7: 샴푸랑 바디워시 리필하고 세안비누도 사왔어요~^^
# review8: 남양주제로웨이스트샵 중엔 상품이 가장 많은것 같네요~ 화장품 종류도 있고 필요한 만큼 리필할 수 있어서 경제적이에요ㅎ
# review9: 하남에서 제일 가까워서 찾아왔어요~!
# 환경을 생각하는 이런 제로웨이스트샵은 너무 좋은거같아요♡
# Successfully stored reviews for ID 51 in the database
# ID 52: Extracted 10 reviews
# Review 1: 좋아요.
# Review 2: 차 정비 맡기는동안 옆의 카페 왔는데 초록초록하니 식물도 많고 메뉴 주문하니 코스터도 빨대도 나무라 친환경적이고 좋았어요
# 친환경용품도 다양하게 팔고있어서 구경하기도 좋아요 날이 좋아서 바깥 테이블에서 음악들으면서 느긋하게 잘 있다가 갑니당!
# Review 3: 😗
# Review 4: 넘 맛있어요 커피~^^
# Review 5: 굿
# Review 6: .
# Review 7: 굳
# Review 8: 좋은 물건이 많아요😺
# Review 9: 친절하고 환경에 도움되는 곳이라
# 자주 이용하려구요
# Review 10: 좋아요환경같이 지켜요
# Binding variables for SQL query:
# review1: 좋아요.
# review2: 차 정비 맡기는동안 옆의 카페 왔는데 초록초록하니 식물도 많고 메뉴 주문하니 코스터도 빨대도 나무라 친환경적이고 좋았어요
# 친환경용품도 다양하게 팔고있어서 구경하기도 좋아요 날이 좋
# review3: 😗
# review4: 넘 맛있어요 커피~^^
# review5: 굿
# review6: .
# review7: 굳
# review8: 좋은 물건이 많아요😺
# review9: 친절하고 환경에 도움되는 곳이라
# 자주 이용하려구요
# review10: 좋아요환경같이 지켜요
# Successfully stored reviews for ID 52 in the database
# ID 53: Extracted 10 reviews
# Review 1: 환경 생각하는 좋은제품들이 많네요. 세제리필도 가능하고 앞으로 자주 가야겠어요.
# Review 2: 지구를 살리는 바람
# Review 3: 다양한 제로웨이스트 상품들을 팔고있고
# 플라스틱 방앗간, 우유팩, 멸균팩 모으기 등 판매와 환경적 실천을 함께하는 가게!
# 너무 분위기가 좋아 또 가고 싶었고
# 다양한 활동들도 흥미로웠던!!
# 추천합니다!!!👍👍👍
# Review 4: 좋아요
# Review 5: 좋아요
# Review 6: 좋아요
# Review 7: 환경 보호에 관심이 생겨서 세제류 리필하러 방문했어요^^
# Review 8: 좋아요
# Review 9: 좋아요
# Review 10: 좋아요
# Binding variables for SQL query:
# review1: 환경 생각하는 좋은제품들이 많네요. 세제리필도 가능하고 앞으로 자주 가야겠어요.
# review2: 지구를 살리는 바람
# review3: 다양한 제로웨이스트 상품들을 팔고있고
# 플라스틱 방앗간, 우유팩, 멸균팩 모으기 등 판매와 환경적 실천을 함께하는 가게!
# 너무 분위기가 좋아 또 가고 싶었고
# 다양한 활동들도 흥미로
# review4: 좋아요
# review5: 좋아요
# review6: 좋아요
# review7: 환경 보호에 관심이 생겨서 세제류 리필하러 방문했어요^^
# review8: 좋아요
# review9: 좋아요
# review10: 좋아요
# Successfully stored reviews for ID 53 in the database
# ID 54: Extracted 10 reviews
# Review 1: 다시 방문한 산제로상점
# 오늘은 꽃마리세탁세제 리필하러 왔네요.
# 1등급 세탁세제, 섬유유연제 그리고 주방세제를 필요한만큼 덜어서 살수 있어 좋네요.
# 리필세제로 플라스틱도 줄이고 해피해빗 포인트까지 적립까지 받을수 있으니 1석 2조~
# Review 2: 송내동 성주산 근처에 위치한 작고 아담한 제로웨이스트샵~~
# 리필세제, 각종 면제품, 비누, 위생용품, 주방용품 등등, 다양한 물건들이 있어 보는 재미가 있었던곳~
# 재방문 의사 200%
# 번창하세요~~
# Review 3: 편안한 분위기에 친환경상품이 다양하게 있어서 좋아요.
# 세제도 비치된공병에 사고싶은 무게만살수있어서 좋네요
# Review 4: 제로웨이스트
# Review 5: 제로웨이스트를 실천하기
# Review 6: 굿
# Review 7: 자원재활용을 할 수 있는 공간입니다
# Review 8: 굿
# Review 9: 제로웨스트 물건 좋아요!!
# Review 10: 친환경제품이라 사용해 보려고 구매했어요.
# Binding variables for SQL query:
# review1: 다시 방문한 산제로상점
# 오늘은 꽃마리세탁세제 리필하러 왔네요.
# 1등급 세탁세제, 섬유유연제 그리고 주방세제를 필요한만큼 덜어서 살수 있어 좋네요.
# 리필세제로 플라스틱도 줄이고 해
# review2: 송내동 성주산 근처에 위치한 작고 아담한 제로웨이스트샵~~
# 리필세제, 각종 면제품, 비누, 위생용품, 주방용품 등등, 다양한 물건들이 있어 보는 재미가 있었던곳~
# 재방문 의사 2
# review3: 편안한 분위기에 친환경상품이 다양하게 있어서 좋아요.
# 세제도 비치된공병에 사고싶은 무게만살수있어서 좋네요
# review4: 제로웨이스트
# review5: 제로웨이스트를 실천하기
# review6: 굿
# review7: 자원재활용을 할 수 있는 공간입니다
# review8: 굿
# review9: 제로웨스트 물건 좋아요!!
# review10: 친환경제품이라 사용해 보려고 구매했어요.
# Successfully stored reviews for ID 54 in the database
# ID 58: Extracted 10 reviews
# Review 1: 자주이용할게요
# Review 2: 사장님께서 틈틈이 신제품도 들여오시고 가게에 꾸준히 변화를 주시기 때문에 주기적으로 방문하는 재미가 있습니다
# Review 3: 리필스테이션 검색해서 강남에서 찾아갔는데 친절하시고 종류도 다양해서 종종 찾아갈 예정입니다~! 채광 좋은 날 가서 영상도 담았는데 혼자 구경하기도 즐거웠어요:)
# Review 4: 빈 용기를 가져가면 세제 등 여러용품을 소분구입 가능합니다. 아기자기 소품들도 많습니다. 가게 소식은 인스타에서 볼 수 있네요.
# Review 5: 환경을 생각하는 가게들은 언제나 반갑습니다. 각종 식재료와 먹거리, 문구, 소품이 있어요. 깨끗한 용기를 가져 오면 대용량 제품들을 소분해서 구입할 수 있기에 챙겨 오시면 좋습니다.
# Review 6: 사장님 블로그 이웃으로 오랜시간 혼자 조용히 포스팅글 읽으며 찐팬이 되었는데 그동안 넘 방문하고 싶었던 슬기로운 생활샵 오늘 드디어 다녀왔어요:) 천천히 둘러보면서 궁금한 거 여쭈면 친절하게 설명해주셔서 좋았고 매장 물품 곳곳에 다정하게 설명이 쓰여 있어서 역시 무척 좋았습니다!  꼼꼼하고 친절하신 사장님의 성격이 보이는듯했어요:) 다정하고 따뜻한 슬기로운 생활 넘 좋아요 이런 좋은 취지의 샵 널리널리 유명해져서 우리 지구에 조금이라도 도움이 되었으면 좋겠어요 샵나오면서 샵 건너편 무인 아이스크림 집에서 아수크림 사면서 사장님 것도 넘 사드리고 싶었는데 취향도 모르겠고 안 좋아하실까봐 고민만 하다가 그냥 갔어요ㅎㅎㅎ 신랑이 텀블러 요청해서 커피 사드리라고 했는데 소심쟁이라서ㅜ 또 올게요!!감사합니다♡
# Review 7: 재밌어요! 소소하게 사기 좋아요!
# Review 8: 한달에 한번은 꼭 들르는 곳. 샴푸바 바디바 사고 가끔 양말도 사고 될수 있음 여기서 많이 사려고 한다 우리동네에서 없어지지 않길 바라니까 여기서 사면 그래도 지구보존에 1은 보탬이 됐겠지 생각한다
# Review 9: 야탑에 있는 제로웨이스트가게  갈때마다 기분 좋은곳 가격도 가격이고 뭔가 지구를 위해 조금한 일이라도 한다는 기분 쥔장님도 너무 친절하시고 설명도 너무 좋다
# Review 10: 제로웨이스트샵 답게 리필용도 많이 구비되어 있어서 좋았습니다.
# Binding variables for SQL query:
# review1: 자주이용할게요
# review2: 사장님께서 틈틈이 신제품도 들여오시고 가게에 꾸준히 변화를 주시기 때문에 주기적으로 방문하는 재미가 있습니다
# review3: 리필스테이션 검색해서 강남에서 찾아갔는데 친절하시고 종류도 다양해서 종종 찾아갈 예정입니다~! 채광 좋은 날 가서 영상도 담았는데 혼자 구경하기도 즐거웠어요:)
# review4: 빈 용기를 가져가면 세제 등 여러용품을 소분구입 가능합니다. 아기자기 소품들도 많습니다. 가게 소식은 인스타에서 볼 수 있네요.
# review5: 환경을 생각하는 가게들은 언제나 반갑습니다. 각종 식재료와 먹거리, 문구, 소품이 있어요. 깨끗한 용기를 가져 오면 대용량 제품들을 소분해서 구입할 수 있기에 챙겨 오시면 좋습니다
# review6: 사장님 블로그 이웃으로 오랜시간 혼자 조용히 포스팅글 읽으며 찐팬이 되었는데 그동안 넘 방문하고 싶었던 슬기로운 생활샵 오늘 드디어 다녀왔어요:) 천천히 둘러보면서 궁금한 거 여쭈
# review7: 재밌어요! 소소하게 사기 좋아요!
# review8: 한달에 한번은 꼭 들르는 곳. 샴푸바 바디바 사고 가끔 양말도 사고 될수 있음 여기서 많이 사려고 한다 우리동네에서 없어지지 않길 바라니까 여기서 사면 그래도 지구보존에 1은 보탬
# review9: 야탑에 있는 제로웨이스트가게  갈때마다 기분 좋은곳 가격도 가격이고 뭔가 지구를 위해 조금한 일이라도 한다는 기분 쥔장님도 너무 친절하시고 설명도 너무 좋다
# review10: 제로웨이스트샵 답게 리필용도 많이 구비되어 있어서 좋았습니다.
# Successfully stored reviews for ID 58 in the database
# ID 59: Extracted 10 reviews
# Review 1: 멋진 곳이에요
# Review 2: 천연수세미 사려고 방문했습니다. 첫방문이라고 하니 친절하게 여러가지 설명해주셨어요~ 나중에 추가로 필요한 물건 있으면 방문하려구요.^^
# Review 3: 상품도 다양하고 공간도 널찍하니 좋아요♡ 알바분도 귀여우심. 근데 옆에 펫샵이 있어서 심기가 불편했음 ㅠ
# Review 4: 굿
# Review 5: 넘 맛있어요 강추요
# Review 6: 굿
# Review 7: 굿
# Review 8: 좋아요
# Review 9: 친절해요
# Review 10: 친구 집들이 선물로 제로웨이스트 시작 세트 만들어줬어요. 준비해 간 재활용 공병들에다 베이킹소다,구연산, 과탄산, 고체치약, 소프넛 담아오고, 대나무칫솔, 천연수세미, 소프넛 샀어요.
# Binding variables for SQL query:
# review1: 멋진 곳이에요
# review2: 천연수세미 사려고 방문했습니다. 첫방문이라고 하니 친절하게 여러가지 설명해주셨어요~ 나중에 추가로 필요한 물건 있으면 방문하려구요.^^
# review3: 상품도 다양하고 공간도 널찍하니 좋아요♡ 알바분도 귀여우심. 근데 옆에 펫샵이 있어서 심기가 불편했음 ㅠ
# review4: 굿
# review5: 넘 맛있어요 강추요
# review6: 굿
# review7: 굿
# review8: 좋아요
# review9: 친절해요
# review10: 친구 집들이 선물로 제로웨이스트 시작 세트 만들어줬어요. 준비해 간 재활용 공병들에다 베이킹소다,구연산, 과탄산, 고체치약, 소프넛 담아오고, 대나무칫솔, 천연수세미, 소프넛 샀어
# Successfully stored reviews for ID 59 in the database
# ID 61: Extracted 10 reviews
# Review 1: 책 다양해서 좋음
# 제로웨이스트 굿
# Review 2: 제로 웨이스 샵이 있어사 좋아요
# 책도 다양해서 잘 둘러보고 갑니다
# Review 3: 천연수세미를 구입했는데 친절하게 쓰는 방법을 알려주시고 편안한 내부 분위기가 매력있습니다!
# 제 용기를 가져가면 리필할수있는 각종 생활 세제들이 매력적이에요! 수원페이로 결제하면 5프로 추가할인도 받을 수 있어 더욱 좋더라구요~
# 책도 흥미로운 종류가 가득이라 시간 가는 줄 모르고 구경했습니다~
# Review 4: 동네라 지나다니면서도 서점인 줄 몰랐어요 ㄷㄷ 진짜 여관인줄 ㅋㅋㅋㅋㅋ 이웃이 이야기해줘서 작은책방이라는 거 알고 뒤늦게 찾아갔는데 넘 보물같은 공간이 있네요!! 지구를 위해 제로 웨이스트를 실천하며, 친절한 사장님과 취향 저격 책들이 많은 곳이에요! 환경친화 제품들도 살 수 있어서 넘 좋았어요 :) 종종 들르게 될 것 같아요! 부디 이 곳에서 오래 오래 자리를 지켜주세요 ♡
# Review 5: 사장님께서 넘 친절하시고 독립서점다운 책들이 가득해요. 앞으로 책 사고 싶을때 종종 갈것 같아요🩷
# Review 6: 책도 많고 사장님이 잘 꾸며놓으셨어요~
# 사장님 친절하시고 너무 귀여우셔요. 보고있음 기분이 좋아지게 만드는 친절함을 가지셧🩷
# Review 7: 낯설여관 서점은 몇번 방문했는데 갈 때마다 독립서점다운 책들이 가득한 곳🩷
# 소녀소녀스러움의 사장님과 따뜻한 책방❤️
# 잠시 여유를 갖고 쉼을 얻고 싶을 때 찾는 곳이랍니다.😊
# 아 그리고... 말린망고 맛집인건 안 비밀입니다🤫
# Review 8: 제가너무나애정하는 낯설여관..^^
# Review 9: 예쁘고 특이한 책들이 많아요.
# 책 이외에 소품을 판매하는데
# 제로웨이스트 샵도 있답니다.  ^_^
# Review 10: 사장님이 친절하시고 따뜻한 공간이에요.
# Binding variables for SQL query:
# review1: 책 다양해서 좋음
# 제로웨이스트 굿
# review2: 제로 웨이스 샵이 있어사 좋아요
# 책도 다양해서 잘 둘러보고 갑니다
# review3: 천연수세미를 구입했는데 친절하게 쓰는 방법을 알려주시고 편안한 내부 분위기가 매력있습니다!
# 제 용기를 가져가면 리필할수있는 각종 생활 세제들이 매력적이에요! 수원페이로 결제하면
# review4: 동네라 지나다니면서도 서점인 줄 몰랐어요 ㄷㄷ 진짜 여관인줄 ㅋㅋㅋㅋㅋ 이웃이 이야기해줘서 작은책방이라는 거 알고 뒤늦게 찾아갔는데 넘 보물같은 공간이 있네요!! 지구를 위해 제로
# review5: 사장님께서 넘 친절하시고 독립서점다운 책들이 가득해요. 앞으로 책 사고 싶을때 종종 갈것 같아요🩷
# review6: 책도 많고 사장님이 잘 꾸며놓으셨어요~
# 사장님 친절하시고 너무 귀여우셔요. 보고있음 기분이 좋아지게 만드는 친절함을 가지셧🩷
# review7: 낯설여관 서점은 몇번 방문했는데 갈 때마다 독립서점다운 책들이 가득한 곳🩷
# 소녀소녀스러움의 사장님과 따뜻한 책방❤️
# 잠시 여유를 갖고 쉼을 얻고 싶을 때 찾는 곳이랍니다.😊
# 아 그
# review8: 제가너무나애정하는 낯설여관..^^
# review9: 예쁘고 특이한 책들이 많아요.
# 책 이외에 소품을 판매하는데
# 제로웨이스트 샵도 있답니다.  ^_^
# review10: 사장님이 친절하시고 따뜻한 공간이에요.
# Successfully stored reviews for ID 61 in the database
# ID 64: Extracted 10 reviews
# Review 1: 제로웨이스트를 실천할 수 있는 곳!
# Review 2: 제로웨이스트 굿
# Review 3: 제로웨이스트를 함께 할 수 있는 공간 너무 좋아요
# Review 4: 좋아요
# Review 5: 좋은 제품 많이 구매했어요!
# Review 6: 제품 설명 상세히 해주시고, 합리적인 가격에 제품 구매할 수 있어서 좋아요!
# Review 7: 굿
# Review 8: 채험 많고 아이들이 좋아해요
# Review 9: 좋아요
# Review 10: 좋아요
# Binding variables for SQL query:
# review1: 제로웨이스트를 실천할 수 있는 곳!
# review2: 제로웨이스트 굿
# review3: 제로웨이스트를 함께 할 수 있는 공간 너무 좋아요
# review4: 좋아요
# review5: 좋은 제품 많이 구매했어요!
# review6: 제품 설명 상세히 해주시고, 합리적인 가격에 제품 구매할 수 있어서 좋아요!
# review7: 굿
# review8: 채험 많고 아이들이 좋아해요
# review9: 좋아요
# review10: 좋아요
# Successfully stored reviews for ID 64 in the database
# ID 65: Extracted 10 reviews
# Review 1: 행궁동 이쁜 소품샵❤️
# ...
# review2: 신기한 소품들도 많고 처음보는 소재로 있어서 넘 좋았습니다. 친구랑 가려다가 혼자가게되었는데 그래도 너무 재미있었어요! 저는 필통만들기를 했는데 간단한 과정으로 너무 귀여운 결과물
# review3: 브리타 필터 수거하러 갔다가 수세미 사서 왔네용 사장님 엄청 친절하시고 설명 엄청 잘 해주십니당!
# review4: 요즘 리필스테이션에 관심이 많아 여기저기 다녀보는 중. 몇일 전부터 가봐야지 했던 심플리파이X2, 사장님의 과하지도 않고 모자라지도 않는 적당한 친절함이 마음을 편안하게 만들어 주
# review5: 제로 웨이스트 샵으로 좋아요🫶
# review6: 여기오면 마치 친한단골매장에온듯한 따뜻하고포근함
#
# 아름다운  사장님께서 환한 미소로 늘 맞이해주신다 또오고싶게
#
# 오늘은 9.7  부산CPBC 다정다감다섯시(101.1MHz)
# review7: 실리콘빨대를 구입했는데 실용적이라
# 특히 프렌차이즈 카페에가면종이빨대가 커피맛을변질시켜 별로좋지않아구입
#
#
# 사장님이 친절하고너무좋아요^^환경도 깨끗 지구도 살리는 소비생활
# review8: 부산에서 비전력라이프스타일 커뮤니티를 운영하는 내일공작소 재욱님을 통해서 알게 되었어요  :)  제로웨이트샵을 부산에서 만나 반가웠습니다.  다양한 제품들이 있고, 평소 사용하는
# review9: 비누받침이랑 샴푸바 항상 잘사용하고잇어용♥️
# review10: 용기 가져가서 잇츠베러 초코시나몬 크래커 소분해와서 먹는데 완전 맛있네요ㅜㅜ👍👍 1인 가구라 구연산, 베이킹소다 등등 소량만 필요할 때가 많은데 여기서 저렴하게 소분해올 수 있어서
# Successfully stored reviews for ID 119 in the database
# ID 120: Extracted 10 reviews
# Review 1: ㅎ
# Review 2: 카페를 겸한 작은 소품점으로, 작은 생활용품 주방용품 다육이 등을 전시 판매하고 있는 제로웨이스트 카페입니다.
# 커피류, 수제차, 수제청, 스무디, 디저트 등이 있고, 보이차 아포차 등도 있답니다.
# 조용해서 대화하기 좋아요.
# Review 3: 여기 분위기도 있고 제로웨이스트 매장입니다.
# 커피. 라떼 맛있습니다.
# 편집샵으로 친환경 제품 목제품 판매하고 있어요
# Review 4: 예쁜 소품과 커피를 함께할 수 있는 곳이라 구경하는 재미도 있었고 조용히 차 마시기도 좋더라고요.
# 제로웨이스트샵이라 물건을 고르면서도 구매하면서도 사용하면서도 좋은 곳이었습니다.
# Review 5: 문경 소품샵 오롯이🤩
# 사장님 정말 친절하세요😀
# 문경제로웨이스트샵 소품들이 많아요. 구경하는 재미도 있고 편안하게 쉬고 갈 수 있는 공간입니다💓
# Review 6: 환경에 도움이 되는 물건들을 구매할 수 있어 좋았어요 가격도 합리적이고 품질도 전부 좋습니다
# Review 7: 문경소품샵 오롯이~^^
# 제로웨이스트샵 첫 방문이었는데 구경할 것이 정말 많았어요~신기한 것과 자연을 생각하는 생활용품들 다양해서 고르기 힘들었네요~
# 재방문 꼭 하고 싶은 곳입니다~
# Review 8: 문경새재가는길에 있어서 방문했는데 카페겸소품샵이었어요
# 제로웨이스트제품많아서 신기했어요!!
# 생각보다 저렴하고 가성비좋은제품들 많았고 사장님이 친절히 안내해주셔서 좋은제품 득템했네요ㅎ
# Review 9: 친환경 제품이 다양하게 있어서 보기 좋았어요
# 옆에 식물원에 다육이도 있어서 화분 구입하기 좋아요 💛
# Review 10: 사장님 친절하시고 볼게 많아요~ 커피도 맛있네요^^~
# Binding variables for SQL query:
# review1: ㅎ
# review2: 카페를 겸한 작은 소품점으로, 작은 생활용품 주방용품 다육이 등을 전시 판매하고 있는 제로웨이스트 카페입니다.
# 커피류, 수제차, 수제청, 스무디, 디저트 등이 있고, 보이차 아포차
# review3: 여기 분위기도 있고 제로웨이스트 매장입니다.
# 커피. 라떼 맛있습니다.
# 편집샵으로 친환경 제품 목제품 판매하고 있어요
# review4: 예쁜 소품과 커피를 함께할 수 있는 곳이라 구경하는 재미도 있었고 조용히 차 마시기도 좋더라고요.
# 제로웨이스트샵이라 물건을 고르면서도 구매하면서도 사용하면서도 좋은 곳이었습니다.
# review5: 문경 소품샵 오롯이🤩
# 사장님 정말 친절하세요😀
# 문경제로웨이스트샵 소품들이 많아요. 구경하는 재미도 있고 편안하게 쉬고 갈 수 있는 공간입니다💓
# review6: 환경에 도움이 되는 물건들을 구매할 수 있어 좋았어요 가격도 합리적이고 품질도 전부 좋습니다
# review7: 문경소품샵 오롯이~^^
# 제로웨이스트샵 첫 방문이었는데 구경할 것이 정말 많았어요~신기한 것과 자연을 생각하는 생활용품들 다양해서 고르기 힘들었네요~
# 재방문 꼭 하고 싶은 곳입니다~
# review8: 문경새재가는길에 있어서 방문했는데 카페겸소품샵이었어요
# 제로웨이스트제품많아서 신기했어요!!
# 생각보다 저렴하고 가성비좋은제품들 많았고 사장님이 친절히 안내해주셔서 좋은제품 득템했네요ㅎ
# review9: 친환경 제품이 다양하게 있어서 보기 좋았어요
# 옆에 식물원에 다육이도 있어서 화분 구입하기 좋아요 💛
# review10: 사장님 친절하시고 볼게 많아요~ 커피도 맛있네요^^~
# Successfully stored reviews for ID 120 in the database
# ID 123: Extracted 10 reviews
# Review 1: 🙌🙌
# Review 2: 좋아요
# Review 3: 굿
# Review 4: ㅎ
# Review 5: 친절하게 설명해주시고 상품도 좋아요! 근데 위치 찾기가 조금 힘들어서 팻말 같은거 있음 좋겠어용
# Review 6: 지구맑음
# Review 7: 제품진열이 잘 되어있고 제로웨이스트 관련 책도 판매하고 있었어요. 필요한 물품이 있으면 구매하러 가기 좋네요
# Review 8: 제로웨이스트샵 좋아요!
# Review 9: 종류가 다양하고 필요한 것만 살 수 있어서 좋아여!
# Review 10: 항상 방문하는 제로웨이스트샵입니다^^!!
# Binding variables for SQL query:
# review1: 🙌🙌
# review2: 좋아요
# review3: 굿
# review4: ㅎ
# review5: 친절하게 설명해주시고 상품도 좋아요! 근데 위치 찾기가 조금 힘들어서 팻말 같은거 있음 좋겠어용
# review6: 지구맑음
# review7: 제품진열이 잘 되어있고 제로웨이스트 관련 책도 판매하고 있었어요. 필요한 물품이 있으면 구매하러 가기 좋네요
# review8: 제로웨이스트샵 좋아요!
# review9: 종류가 다양하고 필요한 것만 살 수 있어서 좋아여!
# review10: 항상 방문하는 제로웨이스트샵입니다^^!!
# Successfully stored reviews for ID 123 in the database
# ID 125: Extracted 8 reviews
# Review 1: 좋아요
# Review 2: 일회용품을 줄이고 플라스틱을 줄일 수 있는 곳
# Review 3: 조아요
# Review 4: 사장님도 정말 친절하시고 제로웨이스트를 위한 다양한 용품들이 많았어요 세척한 용기를 들고와 세제리필 원하는 만큼 담아 살 수 있는 용기내 프로젝트 너무 멋집니다
# Review 5: 사장님 짱친절하시고 유쾌하세요!
# Review 6: 친환경제품들이 많아요.
# Review 7: 사장님의 제로웨이스트에 대한 공부와 열정이 느껴지는 곳입니다! 항상 친절하시고, 반겨주세요! 무엇보다 비누 완전 좋아요!!! 자주 애용할께요~
# Review 8: #친환경용품
# 코로나와 기후변화로 인한 환경을 생각하게 되었는데 판매하시는 생활용품들이나 비누가 친환경물품들이라 너무 좋아요
# 사장님도 친절하시고 개인적으로 비누 정말 좋아요 💕
# Binding variables for SQL query:
# review1: 좋아요
# review2: 일회용품을 줄이고 플라스틱을 줄일 수 있는 곳
# review3: 조아요
# review4: 사장님도 정말 친절하시고 제로웨이스트를 위한 다양한 용품들이 많았어요 세척한 용기를 들고와 세제리필 원하는 만큼 담아 살 수 있는 용기내 프로젝트 너무 멋집니다
# review5: 사장님 짱친절하시고 유쾌하세요!
# review6: 친환경제품들이 많아요.
# review7: 사장님의 제로웨이스트에 대한 공부와 열정이 느껴지는 곳입니다! 항상 친절하시고, 반겨주세요! 무엇보다 비누 완전 좋아요!!! 자주 애용할께요~
# review8: #친환경용품
# 코로나와 기후변화로 인한 환경을 생각하게 되었는데 판매하시는 생활용품들이나 비누가 친환경물품들이라 너무 좋아요
# 사장님도 친절하시고 개인적으로 비누 정말 좋아요 💕
# Successfully stored reviews for ID 125 in the database
# ID 126: Extracted 5 reviews
# Review 1: 리필스테이션 처음이라 재미있었어요~
# 공병 갖고 샴푸 사러갔는데 음료수 빈병에 담아둔 바디워시도 사왔어요.
# 근데 바디워시 라벨에 써두신 유통기한이 한참 지났더라고요... 그 부분 빼고는 다 좋았어요.
# Review 2: 제로 웨이스트 가게여서 안심하고 소비할 수 있습니다.
# Review 3: 멸균팩말려서 챙기고 빈통챙겨서 리필샴푸,린스,바디워시 채워 왔어요. 작지만 꼭 필요한 가게라고 생각합니다^^
# 아로마티카 제품들을 리필로 살수있어요!!
# Review 4: 우유팩은 종이가 아니라 분리배출해야한다고 들어서 수거장소를 찾다가 알게되었어요:) 씻어 말린 우유팩 잘 놓아두고, 천연수세미 사왔습니다! 늘 친절하셔서 좋아요.
# Review 5: 괜찮아요
# Binding variables for SQL query:
# review1: 리필스테이션 처음이라 재미있었어요~
# 공병 갖고 샴푸 사러갔는데 음료수 빈병에 담아둔 바디워시도 사왔어요.
# 근데 바디워시 라벨에 써두신 유통기한이 한참 지났더라고요... 그 부분 빼
# review2: 제로 웨이스트 가게여서 안심하고 소비할 수 있습니다.
# review3: 멸균팩말려서 챙기고 빈통챙겨서 리필샴푸,린스,바디워시 채워 왔어요. 작지만 꼭 필요한 가게라고 생각합니다^^
# 아로마티카 제품들을 리필로 살수있어요!!
# review4: 우유팩은 종이가 아니라 분리배출해야한다고 들어서 수거장소를 찾다가 알게되었어요:) 씻어 말린 우유팩 잘 놓아두고, 천연수세미 사왔습니다! 늘 친절하셔서 좋아요.
# review5: 괜찮아요
# Successfully stored reviews for ID 126 in the database
# ID 127: Extracted 9 reviews
# Review 1: 무지개 칫솔 울아이 최애템입니다.
# 언제나 애용하는 제로웨이스트샵 ^^
# 언제나 최고예용~~^^
# Review 2: 에코유 인스타 이벤트 당첨되어서 선물찾으러 방문했다가 필요한 거 더 사왔어요😆
# 원래 환경에 관심이 많이 있는데 제로웨이스트샵이 거제에 생겨서 정말 좋아요!
# 실리콘약병은 정말 필요했는데 선물로 주셨길래 하나 더 구매해서 저희 두 딸 아파서 약국갈때마다 플라스틱 약병은 안받아와도 되겠어요😆
# 고체치약도 써보고 싶었는데 딱 선물로 주셔서 정말 감사해요 ㅎㅎ 칫솔걸이 두개랑 집에 신랑이 수세미 좀 바꾸래서 수세미도 하나 사왔어요 ㅋㅋ
# 즐거운 쇼핑.. 안사야 지구에 더 좋겠지만
# 에코유에서 쇼핑은 제로웨이스트 상품이니 양심에 가책이 덜 해서 좋아요❤️
# 거제분들도 많이 이용하셔서 에코유 오래오래 사랑받으시면 좋겠어요☺️
# Review 3: 친환경 재품들이 다 모여있어여
# 환경을 생각하시는분들
# 친환경제품 써보고싶으신분들
# 요기오시면 좋아하실것같아용
# 저는 고무장갑 겟🙂 가격도 착해서 좋아요
# Review 4: 플라스틱(pp/pe/ps)를 모아 매장에서 업사이어티 적립도 하고천연 고무장갑을 구매했어요~ 사장님도 너무 친절하시고 적극적으로 환경을 생각시는 모습이 너무 멋졌어요👍👍앞으로 저도 한번 더 환경을 생각하고 생활하겠습니다🥰
# Review 5: 자연을생각하는 매장이있어서 좋아요
# Review 6: 구경하는 재미도있고 사장님 넘 친절하세요^^
# 담에 또 방문할게요
# Review 7: 고현을 나오면 항상 들르고 싶은 매장 에코유.
# 친환경 제품들을 관심가지게 되면서 자주 방문하는 매장이에요. 매장도 깔끔하고 종류도 다양한데 사장님도 친절하셔서 여기는 기분 좋아지는 매장이에요^^
# 지구를 생각하며 소비하는 습관에 길잡이가 되어주는 고마운 매장 에코유, 앞으로도 흥하세요!!
# Review 8: 사장님이 너무친절하시고 제품이 다양하고 환경에 대해 다시 한번 생각할수 잇게되는 좋은곳이엿어요♡
# Review 9: 자원도 재활용되고 포인트받아서 필요한 물건도 살수있고 너무좋아요~
# 매장도 넓고 아늑하고 사장님 친절하시고
# 주차도 편해서 더욱좋네요~^^
# Binding variables for SQL query:
# review1: 무지개 칫솔 울아이 최애템입니다.
# 언제나 애용하는 제로웨이스트샵 ^^
# 언제나 최고예용~~^^
# review2: 에코유 인스타 이벤트 당첨되어서 선물찾으러 방문했다가 필요한 거 더 사왔어요😆
# 원래 환경에 관심이 많이 있는데 제로웨이스트샵이 거제에 생겨서 정말 좋아요!
# 실리콘약병은 정말 필요했
# review3: 친환경 재품들이 다 모여있어여
# 환경을 생각하시는분들
# 친환경제품 써보고싶으신분들
# 요기오시면 좋아하실것같아용
# 저는 고무장갑 겟🙂 가격도 착해서 좋아요
# review4: 플라스틱(pp/pe/ps)를 모아 매장에서 업사이어티 적립도 하고천연 고무장갑을 구매했어요~ 사장님도 너무 친절하시고 적극적으로 환경을 생각시는 모습이 너무 멋졌어요👍👍앞으로 저도
# review5: 자연을생각하는 매장이있어서 좋아요
# review6: 구경하는 재미도있고 사장님 넘 친절하세요^^
# 담에 또 방문할게요
# review7: 고현을 나오면 항상 들르고 싶은 매장 에코유.
# 친환경 제품들을 관심가지게 되면서 자주 방문하는 매장이에요. 매장도 깔끔하고 종류도 다양한데 사장님도 친절하셔서 여기는 기분 좋아지는
# review8: 사장님이 너무친절하시고 제품이 다양하고 환경에 대해 다시 한번 생각할수 잇게되는 좋은곳이엿어요♡
# review9: 자원도 재활용되고 포인트받아서 필요한 물건도 살수있고 너무좋아요~
# 매장도 넓고 아늑하고 사장님 친절하시고
# 주차도 편해서 더욱좋네요~^^
# Successfully stored reviews for ID 127 in the database
# Error occurred while processing search_name '제로웨이스트 흥분색' with id '129': Message: entryIframe
#
# ID 130: Extracted 10 reviews
# Review 1: 지나가는 여러 손님 중 한명인 저를 소중한 인연으로 생각해주시는게 짧은 만남에도 느껴졌답니다..ღ
# 사장님 덕분에 군산에 꼭 다시 방문하고 싶어졌는걸요!
# 또 다시 방문할게요 그 자리에 오래 있어주세요 ღ
# Review 2: 아기자기 예쁜 소품가게.. 업사이클링 제품들이라 더 의미있게 구경했어요. 식빵수세미 넘 귀여워서 친구들 선물로 구입했습니다.
# Review 3: 제로웨이스트
# 레스웨이스트
# 코지하고 편안분위기
# 천천히구경하고
# 예쁜양말데꼬가요💜
# 또갈게요😍
# Review 4: 환경을 위한 마켓이 있다는게 넘 좋고 진짜 본격적이였어요!!여행오신분들 여기서 칫솔같은거 사서 쓰시면 좋을것같아요ㅜㅜ
# Review 5: 특색 있고 환경 보호 하는 아이디어 상품이 있어서 보기 좋았어요.
# Review 6: 굿
# Review 7: 마리서사를 가다가 우연히 방문한 자주적 관람! 친환경 제품들이 잔뜩 있어서 너무 좋았어요~덕분에 뜻밖의 소비를..ㅎ 사장님도 너무 친절하셔서 군산의 따스함 다시 한번 느끼고 갑니다:)
# Review 8: 제로웨이스트 용품 저렴하게 구입해습니다
# Review 9: 너무너무 친절하시고
# 제로웨이스트 물건들이 많아서 좋아요
# Review 10: 좋아요!
# Binding variables for SQL query:
# review1: 지나가는 여러 손님 중 한명인 저를 소중한 인연으로 생각해주시는게 짧은 만남에도 느껴졌답니다..ღ
# 사장님 덕분에 군산에 꼭 다시 방문하고 싶어졌는걸요!
# 또 다시 방문할게요 그 자
# review2: 아기자기 예쁜 소품가게.. 업사이클링 제품들이라 더 의미있게 구경했어요. 식빵수세미 넘 귀여워서 친구들 선물로 구입했습니다.
# review3: 제로웨이스트
# 레스웨이스트
# 코지하고 편안분위기
# 천천히구경하고
# 예쁜양말데꼬가요💜
# 또갈게요😍
# review4: 환경을 위한 마켓이 있다는게 넘 좋고 진짜 본격적이였어요!!여행오신분들 여기서 칫솔같은거 사서 쓰시면 좋을것같아요ㅜㅜ
# review5: 특색 있고 환경 보호 하는 아이디어 상품이 있어서 보기 좋았어요.
# review6: 굿
# review7: 마리서사를 가다가 우연히 방문한 자주적 관람! 친환경 제품들이 잔뜩 있어서 너무 좋았어요~덕분에 뜻밖의 소비를..ㅎ 사장님도 너무 친절하셔서 군산의 따스함 다시 한번 느끼고 갑니다
# review8: 제로웨이스트 용품 저렴하게 구입해습니다
# review9: 너무너무 친절하시고
# 제로웨이스트 물건들이 많아서 좋아요
# review10: 좋아요!
# Successfully stored reviews for ID 130 in the database
# No review elements found for ID 131
# ID 131: Extracted 0 reviews
# Binding variables for SQL query:
# Successfully stored reviews for ID 131 in the database
# ID 133: Extracted 10 reviews
# Review 1: 저번에 왔을때는 못 와서 이번엔 꼭 오겠다는 일념으로
# 전화를 했는데 운영중이었다
# 당장 달려갔어요~^
# ㅋㅋ 역시 득템~~^^*
# Review 2: 제로웨이스트 샵인만큼 영수증도 갱지에 수기로, 쇼핑백은 차에 늘 가지고 다니는 장바구니로 대체 했어요 !
# Review 3: 좋아하는 곳이에요 담양 갈 때마다 가야하는 방앗간!
# Review 4: 조아요
# Review 5: 조아요
# Review 6: 가성비 굿
# Review 7: 조아요
# Review 8: 좋아요
# Review 9: 담양올 때마다 들르는 곳이에요 애정합니다 오래오래 있어주세요
# Review 10: 굿
# Binding variables for SQL query:
# review1: 저번에 왔을때는 못 와서 이번엔 꼭 오겠다는 일념으로
# 전화를 했는데 운영중이었다
# 당장 달려갔어요~^
# ㅋㅋ 역시 득템~~^^*
# review2: 제로웨이스트 샵인만큼 영수증도 갱지에 수기로, 쇼핑백은 차에 늘 가지고 다니는 장바구니로 대체 했어요 !
# review3: 좋아하는 곳이에요 담양 갈 때마다 가야하는 방앗간!
# review4: 조아요
# review5: 조아요
# review6: 가성비 굿
# review7: 조아요
# review8: 좋아요
# review9: 담양올 때마다 들르는 곳이에요 애정합니다 오래오래 있어주세요
# review10: 굿
# Successfully stored reviews for ID 133 in the database
# ID 134: Extracted 10 reviews
# Review 1: 환경을 생각하는 좋은 카페
# 지구를 지켜요
# 나는 소금빵이랑 샤인머스캣스무디
#  딸은치즈몰리브 베이글
# 여기 빵도 맛있고 신제품 샤인머스갯
# 달콤하고 시원해요
# ♡♡♡♡♡♡♡
# 다음에 우유팩이랑 생크림팩
# 모아지면 또 뵐께요
# 감사히 잘먹을께요
# Review 2: 샤인머스캣 스무디 새로 나왔다고해서 먹어봤는데 넘나 맛났어융🍇🍇 찐 과일로 만든거라니,, 맨날 먹고픈 맛💚
# Review 3: 자주가요 가면 맛있는소금빵이랑 베이글 꼭 먹어요 빈우유각이랑 생크림 다쓴거
# 갖다주고. 화장지로 바꾸고 와요
# 갖다주기 번거롭더라도 환경을 생각하는
# 노 플라스틱 카페 생각해서 열심히 모으고 있어요
# 지구를 생각하는 카페 애장합니다
# Review 4: 대추생각차 맛있어요.
# Review 5: 분위기도좋아요.
# Review 6: 아이스바닐라라떼 맛집입니당ㅎㅎ 쿠키도 맛있어요
# Review 7: 노플 ! 커피 및 음료 맛있고 제로웨이스트라서 너무 좋아하는 카페예요 :) 빵도 맛있어용 >_<
# Review 8: 노플에서 천연 수세미를 구입했어요.
# 지역에서 농사 지은 국내산 수세미라 너무 좋아요.
# 요즘 저렴한 수입 수세미도 많은데 노플 수세미는 질적으로 아예 다르네요! 탄탄하고 실해요.
# 못난이는 이름만 못난이이지, 실제로는 가격대비 퀄리티가 너무 좋아서 못난이라고 부르기 미안하네요~
#
# 워낙 노플 좋아하는데 수세미 직접 구매하고 보니 더 좋아지네요 :-)
# Review 9: 노플!! 음료 맛있고 저렴하고 직원분들 친절하시고 환경도 생각하고 제로웨이스트 제품도 다양하고 너무 좋아요 🤍
# Review 10: 몇일 전에 구매했는데 퀄리티 좋아서 또 구매했어요🤍
# 직원분들 친절하시고 물건 좋아요
# Binding variables for SQL query:
# review1: 환경을 생각하는 좋은 카페
# 지구를 지켜요
# 나는 소금빵이랑 샤인머스캣스무디
#  딸은치즈몰리브 베이글
# 여기 빵도 맛있고 신제품 샤인머스갯
# 달콤하고 시원해요
# ♡♡♡♡♡♡♡
# 다음에 우유
# review2: 샤인머스캣 스무디 새로 나왔다고해서 먹어봤는데 넘나 맛났어융🍇🍇 찐 과일로 만든거라니,, 맨날 먹고픈 맛💚
# review3: 자주가요 가면 맛있는소금빵이랑 베이글 꼭 먹어요 빈우유각이랑 생크림 다쓴거
# 갖다주고. 화장지로 바꾸고 와요
# 갖다주기 번거롭더라도 환경을 생각하는
# 노 플라스틱 카페 생각해서 열심히
# review4: 대추생각차 맛있어요.
# review5: 분위기도좋아요.
# review6: 아이스바닐라라떼 맛집입니당ㅎㅎ 쿠키도 맛있어요
# review7: 노플 ! 커피 및 음료 맛있고 제로웨이스트라서 너무 좋아하는 카페예요 :) 빵도 맛있어용 >_<
# review8: 노플에서 천연 수세미를 구입했어요.
# 지역에서 농사 지은 국내산 수세미라 너무 좋아요.
# 요즘 저렴한 수입 수세미도 많은데 노플 수세미는 질적으로 아예 다르네요! 탄탄하고 실해요.
# 못
# review9: 노플!! 음료 맛있고 저렴하고 직원분들 친절하시고 환경도 생각하고 제로웨이스트 제품도 다양하고 너무 좋아요 🤍
# review10: 몇일 전에 구매했는데 퀄리티 좋아서 또 구매했어요🤍
# 직원분들 친절하시고 물건 좋아요
# Successfully stored reviews for ID 134 in the database
# No review elements found for ID 135
# ID 135: Extracted 0 reviews
# Binding variables for SQL query:
# Successfully stored reviews for ID 135 in the database
# ID 136: Extracted 10 reviews
# Review 1: 곧 문닫는데서 다녀왔어요 아쉽네요ㅠ
# Review 2: 늘가는 늘미곡입니다 ㅎㅎ
# Review 3: 기름기가 진짜 잘닦여서 좋아요 !
# Review 4: 사장님도 친절하시고, 제품설명도 자세하게 해주셔서 좋았습니다.
# 환경도 생각하는 소비여서 기분이 좋았어요!!
# Review 5: 👍
# Review 6: .
# Review 7: 짱!
# Review 8: 이것저것 구매하고 이벤트로 받은 선물, 감사합니다!
# 추석 잘 보내세요 :)
# Review 9: 병뚜껑드리러 한달 한번정도 방문하는데 갈때마다 신기하고 재밌는 물건이 많네요~ 언제나 친절하고 편한 분위기^^
# Review 10: 회사 근처에 제로웨이스트 매장 생겼다길래 방문했는데 생각보다 물건 종류가 많아서 보는 재미가 있었어요 ㅎㅎㅎ 잘 몰라서 이것저것 여쭤봤는데 직원분이 친절하게 설명해주심! 추천해요!~~
# Binding variables for SQL query:
# review1: 곧 문닫는데서 다녀왔어요 아쉽네요ㅠ
# review2: 늘가는 늘미곡입니다 ㅎㅎ
# review3: 기름기가 진짜 잘닦여서 좋아요 !
# review4: 사장님도 친절하시고, 제품설명도 자세하게 해주셔서 좋았습니다.
# 환경도 생각하는 소비여서 기분이 좋았어요!!
# review5: 👍
# review6: .
# review7: 짱!
# review8: 이것저것 구매하고 이벤트로 받은 선물, 감사합니다!
# 추석 잘 보내세요 :)
# review9: 병뚜껑드리러 한달 한번정도 방문하는데 갈때마다 신기하고 재밌는 물건이 많네요~ 언제나 친절하고 편한 분위기^^
# review10: 회사 근처에 제로웨이스트 매장 생겼다길래 방문했는데 생각보다 물건 종류가 많아서 보는 재미가 있었어요 ㅎㅎㅎ 잘 몰라서 이것저것 여쭤봤는데 직원분이 친절하게 설명해주심! 추천해요!
# Successfully stored reviews for ID 136 in the database
# ID 138: Extracted 10 reviews
# Review 1: 제주도에 리필할 곳이 있다는 게 참 좋아요🫶 샴푸 사봤는데 제품 퀄리티도 좋고 자극이 없어서 그런지 머리카락이 덜 빠지는 느낌이네요 감사합니다
# Review 2: 세안비누 효과가 좋아요
# Review 3: 식기세척기 세제 안심하고 씁니다
# Review 4: 샴푸 100g  3300원
# 액상 세탁세제 5L  42,000원
# 타블릿 2종세트(세탁세제+섬유유연제)    32,000원
#
# 한번에 사서 9만원가량 나왔지만 그만큼 좋은세제라 믿고 씁니다^^
# Review 5: 첫방문에 모르고 모아둔 플라스틱 용기 들고 갔는데 깨끗하게 세척하고 건조한 거 아니면 사용이 불가하다고 하셔서 재사용용기 대여했어요 ! 주방세제는 가격이 너무 비싸서 재구매 어려울 것 같은데 세탁세제나 샴푸는 천연이고 섬유유연제,린스 안써도 되서 재구매할 것 같아요 ! :) 이런 리필 스토어가 많이 생기고 조금 더 저렴해지면 참 좋을 것 같아요 ! ♥️
# Review 6: 제로웨이스트를 위해 처음 구매해봤어요.
# Review 7: 액상 세제 구매!
# Review 8: 지구를 위한 제로웨이스트! 리필샵이 동네에 있어서 정말 행복합니다 🥰
# Review 9: 세제리필하는곳^^
# Review 10: 자연을 생각하며 구입해봤어요^^
# 사용해보고 좋으면 제주가서 또 사와야 겠네요!!
# Binding variables for SQL query:
# review1: 제주도에 리필할 곳이 있다는 게 참 좋아요🫶 샴푸 사봤는데 제품 퀄리티도 좋고 자극이 없어서 그런지 머리카락이 덜 빠지는 느낌이네요 감사합니다
# review2: 세안비누 효과가 좋아요
# review3: 식기세척기 세제 안심하고 씁니다
# review4: 샴푸 100g  3300원
# 액상 세탁세제 5L  42,000원
# 타블릿 2종세트(세탁세제+섬유유연제)    32,000원
#
# 한번에 사서 9만원가량 나왔지만 그만큼 좋은세제라 믿고 씁
# review5: 첫방문에 모르고 모아둔 플라스틱 용기 들고 갔는데 깨끗하게 세척하고 건조한 거 아니면 사용이 불가하다고 하셔서 재사용용기 대여했어요 ! 주방세제는 가격이 너무 비싸서 재구매 어려울
# review6: 제로웨이스트를 위해 처음 구매해봤어요.
# review7: 액상 세제 구매!
# review8: 지구를 위한 제로웨이스트! 리필샵이 동네에 있어서 정말 행복합니다 🥰
# review9: 세제리필하는곳^^
# review10: 자연을 생각하며 구입해봤어요^^
# 사용해보고 좋으면 제주가서 또 사와야 겠네요!!
# Successfully stored reviews for ID 138 in the database
# ID 139: Extracted 2 reviews
# Review 1: 비싸요
# Review 2: 집앞 단골이에요.
# Binding variables for SQL query:
# review1: 비싸요
# review2: 집앞 단골이에요.
# Successfully stored reviews for ID 139 in the database
# No review elements found for ID 140
# ID 140: Extracted 0 reviews
# Binding variables for SQL query:
# Successfully stored reviews for ID 140 in the database
# ID 141: Extracted 10 reviews
# Review 1: 대파행주   구입  소재 참 좋아요
# Review 2: 친환경 제품을 파는 곳이라 궁금해서 방문 해봤어요
# 면 생리대는 관리할 엄두가 안나서 라이너로 구매하고
# 밀랍 랩이라는 것이 특이해서 구매해 봤어요
# 밥 남은 것이나 잔반 남은 것들 비닐 랩으로 덮어 놨었는데 이제 밀랍랩 사용으로 쓰레기를 줄여보려 합니다
# Review 3: 좋은상품이 많아요
# Review 4: 네이버 지도에 제로웨이스트샵 목록을 저장해 뒀었는데 여행 중 근처에 있어서 방문했어요. 사장님이 제품 설명도 해주시고 물건만 보느라 천장은 잘 안봤는데 부표를 재활용한 전등이라고 설명해주시더라구요. 매장 곳곳에 달려있어서 예뻤고 그물같은 바다쓰레기로 만든 제주지도도 설명해주셨어요. 마침 수세미가 필요했는데 삼베실로 만든수세미가 있어서 구매했습니다. 진짜  수세미 건조시킨건 물에 젖을수록 닳아지는데 이건  튼튼할거 같아요. 고리도 있어서 걸어서 건조시킬수 있어서 좋아보입니다. 카톡친구추가하고 칫솔치약세트도 받을 수 있었어요. 고체치약 써보고 싶었는데 좋아요.
# Review 5: 지구를 지키기 위해 저도 텀블러랑 용기내 좋아하는데
# 지켜백이 있는 곳이 있네요! 대박!
# 오늘 2000ml 구입했는데 너무 좋아용
# Review 6: 요즘 제로웨이스트에 관심이 생겨서 찾아보다 발견한 가게인데 친절하시고 넘 좋은거 같아요 👍
# Review 7: 택배로 물건을 주문하는 것도 탄소가 많이 배출된다고 합니다. 제가 사는 곳에 이런 제로웨이스트샵이 있다는게 넘넘 행복하네요^^
# 사장님도 친절하시고 물건도 계속 업데이트되어서 구경하는 재미도 쏠쏠합니다😊
# Review 8: 고체치약이랑 대나무 칫솔 전에 쓰다가 갈아타고 이번에 다시 재구매했는데 너무 좋아요!
# Review 9: 가방구입과  삼다수 뚜껑  재활용품 제출
# Review 10: 여행중에 들려서 이것저것 봤던 것들 구매했어요 ! 🤗 친절하시고 잘 설명해주셔서 좋아요~ 제로웨이스트에 한걸음💕🫶
# Binding variables for SQL query:
# review1: 대파행주   구입  소재 참 좋아요
# review2: 친환경 제품을 파는 곳이라 궁금해서 방문 해봤어요
# 면 생리대는 관리할 엄두가 안나서 라이너로 구매하고
# 밀랍 랩이라는 것이 특이해서 구매해 봤어요
# 밥 남은 것이나 잔반 남은 것들 비
# review3: 좋은상품이 많아요
# review4: 네이버 지도에 제로웨이스트샵 목록을 저장해 뒀었는데 여행 중 근처에 있어서 방문했어요. 사장님이 제품 설명도 해주시고 물건만 보느라 천장은 잘 안봤는데 부표를 재활용한 전등이라고
# review5: 지구를 지키기 위해 저도 텀블러랑 용기내 좋아하는데
# 지켜백이 있는 곳이 있네요! 대박!
# 오늘 2000ml 구입했는데 너무 좋아용
# review6: 요즘 제로웨이스트에 관심이 생겨서 찾아보다 발견한 가게인데 친절하시고 넘 좋은거 같아요 👍
# review7: 택배로 물건을 주문하는 것도 탄소가 많이 배출된다고 합니다. 제가 사는 곳에 이런 제로웨이스트샵이 있다는게 넘넘 행복하네요^^
# 사장님도 친절하시고 물건도 계속 업데이트되어서 구경하
# review8: 고체치약이랑 대나무 칫솔 전에 쓰다가 갈아타고 이번에 다시 재구매했는데 너무 좋아요!
# review9: 가방구입과  삼다수 뚜껑  재활용품 제출
# review10: 여행중에 들려서 이것저것 봤던 것들 구매했어요 ! 🤗 친절하시고 잘 설명해주셔서 좋아요~ 제로웨이스트에 한걸음💕🫶
# Successfully stored reviews for ID 141 in the database
# ID 144: Extracted 4 reviews
# Review 1: 감탄장에서 처음 뵈었어요. 모슬포에 위치하고 있지만 꼭 한번 찾아뵐게요. 지구를 생각하는 제로웨이스트숍 정말 좋아요. 비건 크래커와 젤리 구매할 수 있어서 감사했어요🧡
# Review 2: 리사이클링 샵~
# Review 3: 가정집처럼 되어있어서 찾기는 어려웠지만 들어가보니 넘 좋았어요~! 힐링됨!!
# 사장님 너무 친절하게 사용법과 꿀팁 설명해주셨어요 ㅎㅎ
# 샴푸바 만들기도 하고싶었는데 못해서 아쉽네요ㅠㅠ
# Review 4: 실생활에서 쉽게 제로웨이스트에 접근할 수 있어요. 사장님이 친절하세요. 궁금한거 물어보면 잘 알려주시네요.
# Binding variables for SQL query:
# review1: 감탄장에서 처음 뵈었어요. 모슬포에 위치하고 있지만 꼭 한번 찾아뵐게요. 지구를 생각하는 제로웨이스트숍 정말 좋아요. 비건 크래커와 젤리 구매할 수 있어서 감사했어요🧡
# review2: 리사이클링 샵~
# review3: 가정집처럼 되어있어서 찾기는 어려웠지만 들어가보니 넘 좋았어요~! 힐링됨!!
# 사장님 너무 친절하게 사용법과 꿀팁 설명해주셨어요 ㅎㅎ
# 샴푸바 만들기도 하고싶었는데 못해서 아쉽네요ㅠㅠ
# review4: 실생활에서 쉽게 제로웨이스트에 접근할 수 있어요. 사장님이 친절하세요. 궁금한거 물어보면 잘 알려주시네요.
# Successfully stored reviews for ID 144 in the database
