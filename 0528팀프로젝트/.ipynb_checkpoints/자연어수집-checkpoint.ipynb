# %%
# !pip install Pillow
# ! pip install wordcloud

# %%
import re
import os
import time
import requests
import pandas as pd
import matplotlib.pyplot as plt
from time import sleep
from datetime import datetime
from collections import Counter
from collections import Counter
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.support.ui import WebDriverWait
from konlpy.tag import Okt  # 한글 텍스트 분석을 위해 Konlpy 사용

# %%
options = Options()
options.add_experimental_option("detach", True)
service = Service(ChromeDriverManager().install())
# driver = webdriver.Chrome(service=service, options=options)
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
driver.maximize_window()
# url = "https://search.naver.com/search.naver?ssc=tab.blog.all&sm=tab_jum&query=%EC%9E%AC%ED%99%9C%EC%9A%A9"
url = "https://search.naver.com/search.naver?sm=tab_hty.top&ssc=tab.blog.all&query=%EB%B6%84%EB%A6%AC%EC%88%98%EA%B1%B0&oquery=%EC%9E%AC%ED%99%9C%EC%9A%A9&tqi=iDSZjlqpts0sstjmlBwssssst78-447760"

driver.get(url)
time.sleep(3)

# %%
# 해당 요소 찾을때 까지 10초대기
def time_wait(num, code):
    try:
        wait = WebDriverWait(driver, num).until(
            EC.presence_of_element_located((By.CSS_SELECTOR, code)))
    except:
        print(code, '태그를 찾지 못하였습니다.')
        driver.quit()
    return wait


# frame 변경 메소드
def switch_frame(frame):
    driver.switch_to.default_content()  # frame 초기화
    driver.switch_to.frame(frame)  # frame 변경


# 페이지 다운
def page_down(num):
    body = driver.find_element(By.CSS_SELECTOR, 'body')
    body.click()
    for i in range(num):
        body.send_keys(Keys.PAGE_DOWN)
    # 현재 스크래핑된 HTML 요소 스냅샷 만드는 함수


def save_html_snapshot(page_str, file_prefix):
    current_date = datetime.now().strftime('%y%m%d_%H%M%S')

    # 파일 경로 생성
    file_path = f'{file_prefix}_{current_date}.html'

    if not os.path.exists(file_path):
        # HTML을 문자열로 변환
        # html_string = str(soup.prettify())

        # # 부모-자식 관계에 따라 인덴테이션 적용하여 저장
        # with open(file_path, 'w', encoding='utf-8') as file:
        #    # HTML을 보기 좋게 정리하여 문자열로 변환
        #     pretty_html = soup.prettify()
        soup = BeautifulSoup(page_str, 'html.parser')
        # 파일에 저장
        with open(file_path, 'w', encoding='utf-8') as file:
            file.write(soup.prettify())
            # file.write(html_string)

        print("HTML 파일이 저장되었습니다.")

# %%
save_html_snapshot(driver.page_source,"첫 페이지")
# Out:
# HTML 파일이 저장되었습니다.

# %%
# 해당 요소를 찾을때 까지 10초 대기
time_wait(10, 'div#main_pack > section._prs_blg > div.api_subject_bx > ul')
# (1) 검색창 찾기
search = driver.find_element(By.CSS_SELECTOR, 'div#main_pack > section._prs_blg > div.api_subject_bx > ul')
sleep(3)
# print(search)

# %%
def scroll_and_collect(driver, target_count=800):
    collected_items = []
    last_height = driver.execute_script("return document.body.scrollHeight")

    while len(collected_items) < target_count:
        # 스크롤 다운
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        
        # 새로운 내용이 로드될 때까지 대기
        time.sleep(3)
        
        # 새로 로드된 게시물들을 수집
        items = driver.find_elements(By.CSS_SELECTOR, 'ul.lst_view > li.bx')  # 게시물 선택자
        
        # 중복되지 않는 게시물만 수집 리스트에 추가
        for item in items:
            if item not in collected_items:
                collected_items.append(item)

        # 현재 높이와 마지막 높이를 비교하여 변화가 없으면 멈춤
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            break
        last_height = new_height
    
    return collected_items[:target_count]

collected_items = scroll_and_collect(driver, target_count=100)

# %%
for index, item in enumerate(collected_items):
    print(f"Post {index + 1}: {item.text}")
# Out:
# Post 1: 문서 저장하기
# 블링유에
# 인플루언서
# 3일 전
# 재활용 쓰레기 분리수거함 빨래통 이즈리빙 수납정리함 설치
# 한눈에 쉽게 알아볼 수 있어서 쓰레기 분리 투입할 때 편합니다. 그리고 박스 2개 구매 이상 구매하면 전용 비닐봉지(10장)이 제공되어서 좋았습니다. 물론 비닐봉지 없이 사용해도 되기는 한데요. 저는 비닐봉지에 담아서 를 하기 때문에 맞는 사이즈의 봉투를 구입하려고 알아보고 있었거든요. 그런데 이렇게 챙겨서 보내 주니깐 좋더라고요. 비닐은 내통에 넣고...
# 20
# 재활용 분리수거함 가정용 대용량 비숨 3단으로 정리
# Post 2: 문서 저장하기
# 피노로그
# 인플루언서
# 5일 전
# 아이스팩 버리는법 주민센터 수거함 재활용 분리수거 버리기
# 주민센터 아이스팩 분리수거함 아마 가까운 관할 주민센터, 행정복지센터 방문하시면 입구에 수거함을 비치해둔걸 보신적 있으실거에요. 잘 모아두었다가 외출하실때 한번씩 챙겨가셔서 배출해주시면 됩니다. 보통 건전지, 의약품, 아이스팩 수거함이 주민센터 앞이나 민원실에 위치해있으나, 긴가민가하시다면 미리 전화해보시고 방문하시면 좋으실거에요. 환경을 위한...
# 7
# 피노로그의 #분리수거함
# 콘텐츠 더보기
# Post 3: 문서 저장하기
# BBOBBO's LIFE
# 1주 전
# 음식물분리수거위반 스미싱문자 눈 깜빡할 사이 당할 뻔한 이야기
# #음식물분리수거위반문자 #스미싱주의 #스팸문자 왓씨~아침에 눈뜨자마자 문자 잘 못 클릭했다가 완전 큰일 날뻔했었어요. 지금 생각해도 머릿속이 하얗게 되는 게 식은땀이 흐릅니다. 아침에 문자를 보는데 이런 음식물 위반 문자가 왔더라고요. 평소 같으면 발신번호는 핸드폰 번호이고 web 발신 문자가 무조건 삭제했을 텐데.. 오늘은 눈뜨자마자 정신이...
# 8
# Post 4: 문서 저장하기
# 살림하는미대언니
# 인플루언서
# 1일 전
# 프라이팬 버리기 분리수거 후라이팬 버리는법
# 올바르게 프라이팬 버리기 실천해 보아요~ 금속으로 된 단일 소재 캔 금속으로 분리수거 금속+플라스틱(나무) 복합소재 재질별로 분리수거 재질별로 분리할 수 없는 소재 지역 수거 업체 확인 필요! 대부분 분리 없이 배출해도 고철로 수거해가지만 수거하지 않는다면 종량제 봉투로 배출 (소각 후 자력 선별기로 금속만 추출) 프라이팬을 여러 개 배출한다면 고철들을...
# 14
# Post 5: 문서 저장하기
# 대학내일
# 공식
# 3주 전
# 아이시스 8.0을 분리수거하면 돈을 벌 수 있는 이유
# (대학내일 독자들 말고 교수님 어릴 때) 하지만 놀랍게도 지금, 플라스틱 공병을 모아서 분리수거하면, 껌이나 사탕보다 훨씬 큰 혜택을 주는 서포터즈를 모집하고 있다. 이름하야 아이시스 8.0 업사이클링 서포터즈 ‘플라스틱 캐처’ 국내 생수 브랜드 최초로 과감하게 비닐 라벨을 탈의하고, 맨몸에 양각으로 자랑스런 이름을 새겨넣은 롯데칠성의 그...
# Post 6: 문서 저장하기
# 폐기물 처리 전문 갓클린
# 5일 전
# 의자 분리수거하는 법 환경 보호를 위해 올바르게 버리기
# 사람들은 일반 생활용품을 폐기할 때 이에 맞춰 분리수거를 하여 폐기를 하지만 의자 같은 가구는 전문가가 아닌 일반 사람들은 하나하나 구분하여 배출하는 것에 어려움이 따릅니다.... 아파트의 경우, 장소가 지정되어 있으니 스티커만 잘 부착하여 버리면 됩니다. 아파트 관리사무소에서도 신고를 받는 경우가 종종 있으니 거주하는 단지의 규정을 잘...
# 15
# Post 7: 문서 저장하기
# 데일리
# 공식
# 2023.09.21.
# 10명 중 5명은 잘못 알고 있는 분리수거 방법
# 의약품의 경우에는 약국에서 무료로 수거를 하기 때문에 가까운 약국에 버리는 것이 쉽고 올바른 방법이다. 비닐류 비닐봉지 안에 묻어있는 음식물이나 내용물은 버리고 물로 깨끗이 헹군 뒤 말려서 배출하면 된다. 만약 이물질의 제거가 어렵다면 일반 쓰레기로 분류해서 종량제 봉투에 버리면 된다. 비닐이라 하지만 식품을 포장했던 랩은 비닐류로 가 되지...
# 11
# Post 8: 문서 저장하기
# In My Home
# 3주 전
# 4
# '분리수거' 바로 바로 정리하기
# 추운날에도 분리수거장에서 분류 하시는 각 집의 남편분들을 볼때 마다 '왜 그러는거지? ' 란 생각을 계속 하게 된다. 한번에 모아서 분류하면 일이지만 그때 그때 바로 하면 일이 아니라 그냥 루틴처럼 되는데 말이다.. 대체로 나는 설거지 할때 그날 나온 재활용 쓰레기를 분리한다. 두부통. 음료수병. 김 비닐. 우유팩 등등. 설거지 다하고 남은 물을 활용해 세척하고...
# Post 9: 문서 저장하기
# OnU
# 인플루언서
# 4주 전
# 재활용쓰레기 분리수거 쓰레기통 3단모듈 가정용 분리수거함 비숨 다용도수납함 추천
# 저는 두툼한 겨울옷들과 수건 등을 넣고 꺼내봤는데요. 확실히 투입구가 넓으니까 넣고 꺼내기가 매우 편했구요. 50L 대용량이라 통이 깊고 생각보다 꽤 많이 들어갔습니다. 참고로 두루마리 휴지를 담으면 17롤 ! 300ml 페트병은 41개! 2L 페트병은 7개가 들어가는 크기예요. 1개/ 2개 / 3개 3단 가정용 함 을 옆으로 나열한 모습입니다. 3개나 붙여 놓았는데도 전혀...
# 32
# OnU의 #원룸옷장
# 콘텐츠 더보기
# Post 10: 문서 저장하기
# 알아두면 쓸모있는 일상의 정보들
# 2일 전
# 3
# 금융거래 안심차단 서비스 (feat 음식물분리수거, 법적기준 위반 문자)
# 음식물분리수거 위반이라던지 법적기준 위반이라던지 내가 뭘 위반했지? 라고 생각하며 바로 링크를 누르기 쉽습니다. 결론부터 말씀드리면 아래 문자는 모두 보이스피싱입니다. 절대로 누르시면 안됩니다. 출처 한겨레 정부는 최근 보이스피싱 피해를 막기 위한 정책을 내놓았는데요 바로 금융거래 안심차단 서비스입니다. 금융거래 안심차단 서비스 현재 보이스피싱에...
# Post 11: 문서 저장하기
# 성진산업
# 2주 전
# 8
# 깨진거울 버리는법 안전한 분리수거법 알아보기
# 가능하면 이 작업을 꼭 진행해 주시는 편이 수거자의 안전을 보호하는 방법입니다. 기본적으로 깨진거울 버리는법 분리수거 시에는 조각을 절대 만져서는 안 되며, 아이들이나 반려동물의 접근을 제한해야 합니다. 쉽게 호흡기로 흡입될 수 있을 뿐 아니라 미세한 상처를 입기도 쉽습니다. 처리 후에는 꼭 진공청소기로 바닥 청소를 한 번 더 해주는 것이 좋으며 청소 후에도...
# 멸균팩 분리수거 재활용이 가능할까
# 알루미늄 분리수거 제대로 알고 나부터 실천하기
# Post 12: 문서 저장하기
# 킴여사네집
# 인플루언서
# 4일 전
# 14
# 아이와 함께 하는 우리가족 분리수거 재활용, 코카콜라 원더플 캠페인
# 열심히 분리배출하고 있는데 수거 기간이 되면 QR 코드로 요청하려고요! 순환경제라고 하면 너무나도 멀게만 느껴졌었는데요. 지금은 원더플 캠페인을 통해 분리수거가 매우 중요하고, 올바르게 배출하는 것만으로도 환경에 도움이 될 수 있다는 걸 알게 됐는데요. 덕분에 어렵지 않게 실천할 수 있어 앞으로도 쭉 도전해보려고 해요. https://www.terracycle-kr.com/programs...
# Post 13: 문서 저장하기
# 울수네 신혼집 이야기
# 5일 전
# 18
# 재활용 쓰레기 분리수거 방법 마크 비닐 페트병
# 쓰레기 분리수거 마크 대한민국 환경부에서 관련 내용을 자세히 알아보았는데요 분리배출 표시 가이드북을 만들어서 배포하고 있었어요 책자 안에서 찾은 재활용 쓰레기 분리수거... 찌그러트려서 부피를 줄이고 뚜껑을 닫아 전용 수거함에 버리면 됩니다 2. 플라스틱 / 페트병 아마 배달 음식이나 포장에도 상당히 많이 사용되기 때문에 가정에서 많이 나오는 재활용...
# Post 14: 문서 저장하기
# 미니멀 캐슝
# 3주 전
# 11
# 세탁실 수납과 비움_ 분리수거함 팁
# 플라스틱함은 직접 가져가서 분리 해야하지만 공간차지하지 않고 딱 3개 정도로만 구분하는 게 좋더라구요. 세척은 욕실에서 샴푸로 씻어주면 깨끗하고 냄새없이 오래 사용할 수 있어요. 저희도 할 때가 한참 지났는데... #살림습관 구석구석 공기가 순환되도록 살펴 봅니다. 미니멀캐슝 나만의 공간에서 행복하게 지내요. #심플라이프 #미니멀라이프 #세탁실수납 #함
# Post 15: 문서 저장하기
# 인천광역시 공식 블로그
# 공식
# 2024.04.03.
# 23
# 제로웨이스트 실천! 올바른 재활용 분리수거 방법은?
# 수거함이 없는 곳이라면, 일반 종이류와 섞이지 않게 나누어 주시면 좋습니다. 마지막으로 스티로폼 분리수거 방법은 아래와 같습니다. 1) 포장 테이프 등 이물질 제거 2) 플라스틱, 페트병 분리배출 3) 물로 헹구기 4) 오염된 스티로폼은 일반 쓰레기로 버리기 (ex. 컵라면) ⬇ 재활용품 요령 확인하기 ⬇ 환경을 생각하는 인천 시민이라면, 위 내용을 잘 숙지하셔서...
# Post 16: 문서 저장하기
# 수인환경개선 010-3581-7815
# 2주 전
# 6
# 계란껍질 분리수거 방법
# 오늘은 그래서 계란껍질의 올바른 분리수거 방법에 대해 자세히 알려드리고자 합니다. 먼저 계란 껍질을 처리할 때 가장 중요한 것은 바로 청결함입니다. 계란 껍질 내부에 남아있을 수 있는 남은 물질을 깨끗이 제거하는 것이 중요합니다. 이는 시 다른 재활용 가능한 자원에 악영향을 끼치지 않기 위함입니다. 따라서 계란을 사용한 후에는 껍질을 깨끗이...
# Post 17: 문서 저장하기
# 봄곰
# 인플루언서
# 4주 전
# 20
# 쓰레기 재활용분리수거, 오늘수거로 졸업
# 생각하며 수거비용만 내고 이렇게 저렇게 사용해보기 좋더라구요- 그럼 제 일상이 어떻게 변했는지 보여드릴게요. 배달 음식을 주문하고나면 나오는 플라스틱 분리수거를 하려면 남은 음식물을 비우고 음식물이 남은 용기를 닦아내야 플라스틱용기를 분리배출 할 수 있잖아요. 하지만 이 과정을 스킵할 수 있어요! 이제는 절 괴롭히던 건전지도 그때그때 버릴 수...
# 봄곰의 #재활용분리수거
# 콘텐츠 더보기
# Post 18: 문서 저장하기
# 눈노넷 [nunno . net]
# 4주 전
# 7
# 분리수거함 친환경 생활의 첫걸음을 내딛어 보세요
# 별도로 분리해 수거함에 넣는 제도로 투명 페트병을 별도 분리수거함에 넣을 때는 내용물을 비우고 세척한 후 겉에 붙은 라벨지 등은 떼야 한다 이 같은 제도를 실시하고 있는 이유는 사용한 페트병을 모아 파쇄 세척한 후 아모레퍼시픽그룹, 화장품 유리병 수거 시범사업 본격 시행 시범사업에 참여한 아파트 단지에는 화장품 유리병 수거함이 설치됐으며...
# 재활용분리수거함 쉽고 효율적인 환경보호 방법을 알아보세요
# Post 19: 문서 저장하기
# 지인리빙
# 인플루언서
# 2주 전
# 17
# 택배 비닐 분리수거 뽁뽁이 재활용 방법
# 재활용 표시 없는 비닐 위생 비닐, 위생장갑, 검정 봉지 모두 가능하다. 많은 비닐 버릴 때 속이 보이는 투명 비닐에 넣어 버리기 비닐의 부피를 줄이기 위해 딱지 모양으로 접어서 버리거나 묶어서 버릴 경우 재활용 공장에서 하나하나 펼 수 없어 일반 쓰레기로 분류된다고 해요. 애써 하였는데 재활용될 수 있도록 펴서 분리해 주세요.
# 지인리빙의 #비닐분리수거
# 콘텐츠 더보기
# Post 20: 문서 저장하기
# 살림나우
# 2주 전
# 5
# 멀티탭 버리기 멀티탭 버리는법 분리수거 교체주기
# 만약 분리수거를 한다면 이 모든 물질을 분리해서 각각 배출해야 합니다. 하지만 전문가가 아닌 일반인들이 이를 분리하기에는 감전위험이 있고 무리가 있죠. 아직까지는 명확하게... 나온 분리배출 지침이나 시스템이 없기 때문에 종량제 봉투에 담아 일반쓰레기로 배출하고 있다고 합니다. 아파트에 거주하시는 분들은 경비실이나 재활용공간에 폐가전수거함이 있다면...
# 원룸 분리수거함 대용량 쓰레기 재활용 분리수거함 추천
# Post 21: 문서 저장하기
# 체리오렌지
# 인플루언서
# 7시간 전
# 9
# 수박의 효능 수박껍질 일반쓰레기 분리수거 음식물쓰레기 버리는법
# 수박의 효능 수박껍질 일반쓰레기 분리수거 음식물쓰레기 버리는법 요즘 시장이나 마트에 가보니 이제 제법 수박 가격이 괜찮더라고요. 수박 한 통 사 놓으면 마음이 든든하잖아요.... 음식물쓰레기 버리는법은 음식물쓰레기 통에 버리거나 종량제 봉투에 넣어 버리는 방법, 그리고 음식물쓰레기수거함에 버리는 방법이 있어요. 스마트카라 음식물처리기로 수박껍질을...
# 체리오렌지의 #음식물쓰레기버리는법
# 콘텐츠 더보기
# Post 22: 문서 저장하기
# 가격변동 알림어플 [폴센트]
# 2주 전
# 8
# 오렌지껍질 일반쓰레기 분리수거 재활용 방법
# 오늘은 오렌지껍질 일반쓰레기 음식물쓰레기 구분과 분리수거, 재활용 방법에 대해 정확하게 정리해드리겠습니다 오렌지껍질 일반쓰레기 음식물쓰레기? 분리수거 방법? 껍질이 두껍다... 쉽게 분리됩니다 오렌지껍질 재활용 방법? 오렌지는 다양한 방법으로 재활용이 가능한데요 바로 음식물쓰레기로 버리는 것보다 다양하게 재활용해보면 좋습니다 일단 오렌지의...
# 신발버리는법 4가지 분리수거 가능할까
# 젤 아이스팩 버리는법 분리수거 재활용 방법
# Post 23: 문서 저장하기
# 꼼아랑 같이 세상여행기
# 4주 전
# 10
# 과천 별양동 주민센터에서 멸균팩 종이팩 교환하기 | 멸균팩 세척 후 | 알뜰살뜰 생활비 아끼기
# 우리 아파트에는 따로 멸균팩 분리수거를 할 수 있지만, 나는 동사무소에서 교환하려 오랜시간 모아보았다 ㅎㅎ 멸균팩 세척 방법 분리수거 시 꼭 깨끗히 씻어 말려 가져가야 한다 : ) 멸균팩을 재활용하기 위해서는 내부를 깨끗히 세척해서 가져가야 한다. 우리 꼼아는 상하목장 유기농우유를 먹는데, 요 팩은 가위없이 분리가 거의 불가능하다.ㅋㅋ 그래서...
# Post 24: 문서 저장하기
# 예시카
# 인플루언서
# 2024.04.27.
# 21
# 네스프레소호환 핀 캡슐커피 분리수거는 리사이클러로 간편하게
# 하지만 커피 추출은 편할지 몰라도 커피 찌꺼기를 분리해 캡슐까지 씻어줘야 하는 캡슐커피 분리수거는 너무나 귀찮은 일이죠. 그런데 두둥!! 1초 만에 알루미늄 캡슐과 커피 찌꺼기를 분리해 주는 핀 캡슐 리사이클러 덕분에 캡슐커피 가 아주 쉬워졌는데요 어떤 제품인지 소개해 드릴게요~ 커피의 맛은 최적의 블렌딩과 로스팅이겠지만 최종적으로 신선함이...
# 예시카의 #네스프레소캡슐
# 콘텐츠 더보기
# Post 25: 문서 저장하기
# 써니사이드
# 2024.03.26.
# 18
# 베란다 데크타일 부분 셀프시공 & 분리수거함 설치 후기
# ㅎㅎ 오늘의집에 나올만한 감성은 없지만 부분 타일과 분리수거함으로 깔끔하게 바꿔줬어요 ! 제가 산 타일은 분리수거함은 또 택배를 사들였어요 역시 오늘의집VIP 남편 오기 전에 뜯어야 합니다... 작은 타일 16개가 하나로 연결되어 있구요 미끄럼 방지 끼우개도 있어요 조립은 어렵지 않았구요 사이즈 조절을 위해 컷팅은 그냥 가위는 절대 안되구요 전용 가위를 같이...
# Post 26: 문서 저장하기
# Rosa의 행복한 육아여행
# 2주 전
# 12
# 지구가 아파요 수업 플라스틱 뚜껑 재활용 분리수거 하기
# 가장 중요한 것은 바로 분리수거랍니다. 우리 어린 친구들도 할 수 있는 지구를 보살피는 행위이기도 해요. 이야기를 나눈 후에는 플라스틱 뚜껑을 이용해 조작 놀이를 시작했어요.... 플라스틱 뚜껑 가지고 놀았으니 이번에 에 대해서 배워보았어요. 친구들과 함께 플라스틱, 캔, 우유갑 등 선생님이 전해준 물건들을 바르게 버려봤답니다. 리안이는 우유갑을 잘...
# Post 27: 문서 저장하기
# 까망호두네 블로그
# 2024.04.27.
# 2
# 분리수거 in NC
# Town of Cary에 서비스를 신청하면 매주 화요일에 쓰레기를 수거해간다. 온라인으로 신청하려면 SSN이 필요해서 한국에서 전화로 서비스를 신청해뒀었다. 미국에 입국한 이후 첫... 이 곳은 딱 2개의 통으로 분리해서 넣으면 된다. 종이, 플라스틱, 캔, 유리는 갈색의 “ 통”에 넣고, 나머지는 초록색의 “종량제 통”에 넣으면 된다. 종량제 통에는 비닐을 포함한...
# Post 28: 문서 저장하기
# 나노씨
# 인플루언서
# 3주 전
# 15
# 핀캡슐커피 리사이클링챌린지 분리수거 배출 방법
# 알루미늄의 경우 분리수거가 되지만 원두를 깔끔하게 분리하기가 쉽지않았습니다. 뾰족한 도구를 사용하다보니 손을 다칠 수 있고 깔끔하게 분리가 되지도 않았고요. 핀 캡슐리사이클러를 사용하면서 캡슐커피를 편하게 하고 있어요. 캡슐리사이클러 사용법 캡슐리사이클러 뚜껑을 열고 홈안에 맞추어 사용한 캡슐을 올려줍니다. 캡슐리사이클러의 뚜껑을...
# Post 29: 문서 저장하기
# 달래빛
# 인플루언서
# 4주 전
# 9
# 재활용 분리수거함 종결자 좁은집 세탁실인테리어 프랑코
# 재활용 분리수거함 종결자 좁은집 세탁실인테리어 창신리빙 프랑코 스탠드 분리수거함으로 선택. 얼마전 릴스, 클립을 올려서 다들 분리수거함 뭐쓰냐고 핫이슈가 되었었다. 블로그에 후기를 쓴다고하고는 또 아이가 아파서 너무 힘들어 후기를 적지 못하고 5월이 되어버렸다. 지금은 벌써 1.7만뷰...ㄷㄷ 사실 클립하나만으로도 그냥 대 추천하는 프랑코 스탠드...
# 달래빛의 #세탁실인테리어
# 콘텐츠 더보기
# Post 30: 문서 저장하기
# 잔망스런류주부
# 인플루언서
# 2024.04.18.
# 15
# 쓰레기 재활용 3단분리수거함 듬뿍 들어가네
# 쓰레기 분리수거할때 쓰레기가 듬뿍 들어가서 좋았던 후기 직접 경험한 정보만 전해 드리는 잔망스런 류주부예요:) 오늘은 제가 사용 중인 분리수거함 리뷰를 들려 드릴 건데요. 재활용 분리수거할 때 상당히 많은 양이 들어가서 너무 만족스러워서 공유드리도록 할게요. 비숨 3단함 50L 1. 생산지 : 대한민국 2. 한 개당 사이즈 : 바닥면은 31cm * 23 cm/ 상단은 36cm...
# 잔망스런류주부의 #분리수거함
# 콘텐츠 더보기
# Post 31: 문서 저장하기
# 테니스 위키피디아
# 4주 전
# 21
# 오래된 테니스공 버리는 방법 분리수거 재활용 아이디어
# 테니스 공 분리수거함 / US 오픈 게임볼 재활용통 외국에서는 테니스공의 용도 변경을 전문으로 하는 단체가 있어서 테니스공 수거함이 주변에 있다고 합니다. 재활용 전문 회사로 테니스공이 가게 되면 테니스 공을 다시 재사용할 수 있는 기계를 제작해 테니스 공을 많이 사용하는 학교, 어린 선수들이 있는 테니스 클럽 및 기관에서도 효과적으로 사용할 수 있다고...
# Post 32: 문서 저장하기
# 포츈의 물생활
# 4주 전
# 17
# 전참시 최강희 와이어 빨랫줄 빨래줄 오토바이 헬멧 서랍장 분리수거함 전지적참견시점
# 와이어 빨랫줄 받침대와 본체를 분리한다음에 접착제를 충분히 발라주세요 . 받침대를 부착하고 보조스티커를 붙여서 한번더 튼튼하게 고정해주세요. 72시간을 기다려주세요. 그래야 접착력이 높아진답니다. 보조스티커를 땐 다름에 본체를 선치해주세요. 그다음에 와이어줄을 늘려서 반대편 고리에 걸어주면 설치가 끝납니다! 정말 쉽죠? 함, 빨래바구니...
# Post 33: 문서 저장하기
# 슈슈션션
# 인플루언서
# 4주 전
# 19
# 우산버리는법 분리수거 할 수 있는 건 몽땅 분리해서 버리기
# 우산버리는법 분리수거 할 수 있는 건 몽땅 분리 여름나기를 할 수 있는 튼튼한 우산을 장만했는데요. 집에 있는 우산꽂이에 사용하지 않는 우산이 많더라고요. 어차피 쓰지도 않는데, 정리하자 싶어 고장난 것들은 미련없이 버렸답니다. 우산버리는법과 우산 하는 법을 자세히 알려드려 볼게요. 여러분도 사용하지 않는 우산은 올바르게 버려보세요. :) 워낙...
# 슈슈션션의 #우산버리는법
# 콘텐츠 더보기
# Post 34: 문서 저장하기
# 큐땡의 맛난 놀이터
# 2주 전
# 27
# 칫솔분리수거 가능한 친환경제품 앙고라 왕칫솔
# 특히나 앙고라칫솔은 친환경제품으로 분리수거가 힘들었던 플라스틱칫솔의 단점을 보완하고자 칫솔모를 분리해 배출할 수 있도록 세심히 신경써서 만든게 특징이에요. 이렇게 세심한 배려는 정말 친환경이 필요한 요즘에 소비할 수 있도록 만드는 제품이 아닐까해요. 칫솔대 또한 부드러운 곡선으로 색상마저 파스텔 컬러에요. 군더더기없는 심플한 칫솔대 마음에 들고...
# Post 35: 문서 저장하기
# 린나이 양천구 공식 대리점(시티에너지) 블로그
# 4주 전
# 5
# 장난감 분리수거 버리는방법 한번 확인해보세요
# 아이들에게도 올바른 분리배출습관을 길러줌으로써 미래사회를 이끌 주체로서의 책임을 일러주는 것이 중요하다고 생각합니다. 분리수거된 장난감은 지방자치단체에서 정기적으로 수거하여, 재활용 처리를 진행하게 됩니다. 지방자치단체에서는 먼저 장난감 종류와 재질에 따라 정확하게 분류한 후, 각각의 재질에 맞는 재활용 방식을 적용합니다. 플라스틱 장난감의...
# Post 36: 문서 저장하기
# 짜니의 카르페디엠
# 4주 전
# 20
# 알찬리필 3단 분리수거가방 재활용가방
# 개인적으로 재활용가방 분리수거가방으로 사용할 때에는 비닐봉지를 덧대서 사용하면 좀 더 깔끔하게 사용할 수 있을듯! 그리고 요건 세탁물수거함으로 사용할때! 하얀빨래, 검정빨래... 사용하지 않을땐 처음 배송된 상태처럼 접어서 보관하면 되니 공간활용 최고다-:) 함이 따로 없어서 큰 통에 비닐로 나눠서 분리하거나 상자는 그냥 여기저기 널부러진 내 뒷...
# Post 37: 문서 저장하기
# 남궁괴도
# 인플루언서
# 3일 전
# 6
# 젤 아이스팩 버리는법 재활용 분리수거 버리기
# 지자체 재활용 분리수거 박스 운영 젤 아이스팩 버리는법은 원래 종량제봉투에 그대로 버리기였는데(내용물의 환경오염 문제로 분리배출 불가능) 요즘은 지자체에서 아이스팩 수거함을 운영한다. 나도 찾아보기 전에 주민센터에 갔다가 우연히 발견하고 젤 아이스팩은 물론 물로만 된 것도 어쩐지 아까워서 재활옹되었으면 하는 마음에 여기에다 버리기 한다. 동네...
# 남궁괴도의 #재활용분리수거
# 콘텐츠 더보기
# Post 38: 문서 저장하기
# 쓰리신의 개인취향
# 2024.04.16.
# 12
# 깔끔한 가정용 쓰레기 분리수거함 대용량 50리터 재활용 분리수거함제품 내돈내산 추천
# 깔끔한 가정용 쓰레기 분리수거함 대용량 50리터 재활용 분리수거함 제품 내돈내산 추천 글/사진 ⓒ쓰리신 지난번, 세탁실을 뒤집어서 셀프인테리어 데코타일 시공을 했는데 이곳을 마음잡고 할려고 구상하다가 지난번, 블로그 이웃님이 이 제품을 샀길래 장바구니에 담아두고있다가, 이번에 데코타일로 시공마음먹고 구매해서 설치했다 기존의 재활용 함인데...
# Post 39: 문서 저장하기
# bbo
# 인플루언서
# 2024.04.21.
# 18
# 비숨 3단 재활용 쓰레기 분리수거함 사용 후기
# 그중에서도 비숨 이라는 브랜드의 3단 모듈 분리수거함을 사용하고 있답니다 :) 위로 한층 한층 쌓아 올릴 수 있어서 자리 차지도 덜 하고, 50L의 넉넉한 대용량으로 일주일 치 분리수거 쓰레기를 담기에도 적당한 비숨 모듈형 3단 함! 조립은, 조립이라고 할 것도 없이 뚜껑만 끼우면 끝이라 간편했고 이 뚜껑은 분리도 되는 뚜껑이라 뜯어내고 사용해도 돼서...
# Post 40: 문서 저장하기
# 따심이맘
# 인플루언서
# 3주 전
# 16
# 핀캡슐커피와 착하게버리기프로젝트 분리수거챌린지
# 커피랑 캡슐이 바로 분리가 된다는 점 :-) 분리수거챌린티 참여하기 딱 이죠! 너무 신기하지 않나요!ㅎㅎ 커피찌꺼기는 탈취용으로도 사용해도 되니 재활용도 가능하고 분리된 캡슐은 물에 헹궈서 알루미늄으로 분리배출하면 끝! 지속적으로 착하게버리기프로젝트를 참여하면 지금 소개해드린 핀 캡슐 리사이클러와 캡슐커피머신, 커피까지 세트로 드리고 있어요 약 17만원...
# Post 41: 문서 저장하기
# Bang’s story
# 4일 전
# 2
# 폐기물 음식물 분리수거 위반 문자 민원24 보이스피싱 귀하께 법적기준위반으로 법적기준위반 문자
# 이번에 댓글로 피싱 문자 내용을 알려주신 분이 계신데 귀하께 음식물분리수거 위반으로 신고되었습니다. 그리고 민원24 폐기물 분리위반으로 법적기준초과 접수되었습니다. 등의 내용 적혀있었어요 기관 공식 홈페이지 링크 꼬오옥 주소 확인하세용 그럼 폐기물 음식물 위반 문자 민원24 보이스피싱 귀하께 법적기준위반으로 법적기준위반 문자 포스팅을...
# Post 42: 문서 저장하기
# 올리브와레몬나무
# 인플루언서
# 2024.04.05.
# 10
# 벤쿠버 쓰레기 분리수거
# 윗두껑은 보통때는 닫혀있음 나라마다 쓰레기 분리수거 다르대요. 독일에서는 병을 색깔별로 모으는게 신기하더니(결국 수거할땐 다 섞음), 벤쿠버는 박스 버리는 통이 그렇네요. 일반쓰레기 버리는 곳 일반쓰레기 버리는 것은 하이테크놀로지 수준. 별건 아님ㅋㅋㅋ 초록색 불이 들어온 것 옆에 손잡이를 돌리고 쓰레기를 버리면 웽~~버린쓰레기 꼭꼭 누르는 느낌이랄까....
# Post 43: 문서 저장하기
# 꿈꾸는엄마♥️
# 2024.04.19.
# 7
# 컵라면 용기 분리수거 쓰레기 재활용 알고 버립시다
# 누들로 된 컵라면은 ㅋㄴㄷ이 진리가 아닐까 싶었어요 ^^ 컵라면을 먹고난 후 이 용기를 어떻게 분리수거 하는지 어떻게 재활용을 하는건지 헷갈려하시는분들이 저 포함해서 굉장히... 쓰레기 분리수거는 제가 앞에도 먼저 언급을 하였듯이 종이 or 스티로폼 두가지의 재질로 만들어지고 있죠?! 종이로 제작이 됐다고 한들 내부가 폴리에틸렌으로 코팅이 되있으므로 이런...
# Post 44: 문서 저장하기
# 귤향이솝
# 인플루언서
# 4주 전
# 19
# 3단분리수거함, 재활용가방 빨래가방 둘다 되네요.
# 진짜 다용도실 열때마다 극혐 ㅋㅋㅋ 이제 3단분리수거함이 있으니 깔끔하게 정리해봐야겠어요! 저희집은 빨래바구니 용도 구분할때 흰티나 수건속옷/ 청바지 겉옷 / 세차 수건+ 강아지옷감 등을 구분해서 세탁하는편인데 세개로 매일 소분해서 나눠담고 빨래하기 좋은 사이즈와 용량입니다. 일러스트 패턴도 촌스럽지 않고 귀여워서 들고 재활용 나가기도 좋고 볼때 마다...
# Post 45: 문서 저장하기
# 달로이
# 인플루언서
# 2024.04.16.
# 11
# 미국 포틀랜드 코스트코에서 공병 분리수거하고 보증금 환급받기
# 코스트코에서 공병 보증금 환급받기 오레건 포틀랜드 공병 수거 내 1.5일치 물 포틀랜드가 속한 오레건주는 분리수거를 장려하기 위한 정책의 일환으로 공병 수거 프로그램을 실시하고 있어요. 특정 병이나 캔, 플라스틱 병을 반납하면 음료 가격에 포함되어 있던 디파짓을 돌려주는 시스템인데요. 미시간, 메릴랜드, 버몬트, 메사추세츠 등 다른 몇몇 주에서도 이...
# Post 46: 문서 저장하기
# 김수일포장박사블로그
# 4일 전
# 다음 중 가장 착한 분리수거 방법은?
# 1번은 은박지를 빈 병 안에 깔끔하게(?) 넣은 채로 분리수거 2번은 은박지를 완전히 분리하여 은박지와 병을 별도로 분리수거 3번은 은박지를 병과 분리되지(?) 않도록 붙인 채로 분리수거 4번은 은박지를 새 것 처럼 원상복구(?) 후에 위의 방법 중 제일로 착한 방법은? 정답은 2번 모두 정답을 맞춰 주셔서 다행입니다.^^ ㅋㅋ
# Post 47: 문서 저장하기
# ★당골가게-처음처럼★
# 3주 전
# 17
# 은박보냉백 아이스팩 주문생산가능 한 제조공장 아이스원 / 은박보냉백 폐기 재활용 하는법
# 은박보냉백 구성 분리수거시 은박증착필름은 종량제 봉투에 버려 주시고 발포폼은 스치로폴로 하이덴비닐은 비닐류로 분리 배출 해주시면 됩니다. 분리수거하는 법은 은박보냉백 가장자리 접착되어있는 부분을 가위로 잘라낸후 은박증착필름과 발포폼을 분리 하시고 발포폼과 하이덴비닐을 순서대로 분리해주시면 됩니다. 서로 부착되어있는 부분을 잡아 당기시면 쉽게...
# Post 48: 문서 저장하기
# 루라기 블로그
# 4주 전
# 2
# 분리수거 이렇게까지 해야 하는가? 실용성에 의문이 든다
# 출처 : 환경부 예전에는 분리수거가 참 쉬웠다 그런데 세상이 점점 복잡해지는 것처럼 분리수거도 점점 복잡해지더라 물론, 관심을 가지면 분리수거도 쉽다 문제는 대한민국 인구 5천만 인구가 모두 분리수거에 관심이 있고 똑똑하고 이성적이고 도덕적이지 않다는 게 문제다 생각보다 비상식적인, 뻔뻔한, 무례한 사람들이 굉장히 많다 '법'이라는 게 있어서 자신의...
# Post 49: 문서 저장하기
# 전국환경산업
# 4주 전
# 12
# 성남시유품정리 가정폐기물 안양시 적절한 분리 수거업체
# 안양시 지역의 가정폐기물처리를 하는 당사는 적절한 분리수거로 작업비를 절감합니다. 가정에서 파생되는 버려지는 물건들은 분리수거가 필수적이며 평상시에도 개인별로 하시는 분리수거를 안양유품정리나 안양가정폐기물을 처리하는 상황에서도 마찬가지입니다. 오늘이 가정은 정리해야 할 물건들이 상당량입니다. 거실과 방마다 많은 물건들이 있습니다. 아무리...
# Post 50: 문서 저장하기
# 람람스러운 일상
# 4주 전
# 22
# 분리수거비닐봉투 알찬리필 재활용쓰레기봉투
# 이렇게 들고가서 분리해서 버리면 되겠죠. (조금 더 쓰레기가 많이 나오는 집은 종류별로 나눠서 비닐봉지별로 들고가도 좋을 것 같아요.) 남편이 분리수거하는 장면을 사진으로 찍어왔어요. 비닐은 비닐대로, 종이는 종이대로 버리면 되겠죠. 철지난 물건들 보관용 저희는 재활용비닐봉투를 철 지난 물건들을 보관하는 용도로도 사용해보았어요. 옷들은 서랍에...
# Post 51: 문서 저장하기
# 초록스토리
# 인플루언서
# 2주 전
# 4
# 수박껍질 일반쓰레기? 음식물 쓰레기로 분리수거~
# 수박껍질 일반쓰레기 음식물 쓰레기로 분리수거 여름철 대표 과일 수박은 달콤하고 시원한 맛에 여름 내내 자주 먹는 과일인데요, 먹다 남은 껍질은 어떻게 처리하는지 궁금하신 분들이 계실 것 같아요, 많은 분들이 수박껍질을 일반쓰레기로 버리는 경우가 많은데 음식물 쓰레기로 해야 한답니다. 이번 글은 수박껍질 음식물 쓰레기 에 대해 정리해...
# 초록스토리의 #수박껍질쓰레기
# 콘텐츠 더보기
# Post 52: 문서 저장하기
# 보 파 랑 놀 자 ♥
# 2024.04.17.
# 19
# [보파 살림템] 매직캔 쓰레기통, 재활용 분리수거함 개봉기 (내돈내산~)
# 이사오기 전에는 재활용 분리수거날이 종이빼고는 아무때나 버려도 됐었다. 그래서 걍 현관문앞에다가 커다란 봉투 걸어놓고 차면 비우고, 차면 비우고 했었는데... 근데 이사온 집 여기는 재활용 버리는 날이 일주일에 딱 하루뿐 ㅠㅠ 모아야하느니라..... 오늘의집 - 라이피스트 재활용함 가격:29,900원 재활용함을 예전에도 몇가지 시도해봤으나 결국...
# Post 53: 문서 저장하기
# 새댁유미씨의 이모저모
# 3주 전
# 5
# 집에서 쉽게 실천하는 환경 보호, 분리수거의 방법
# 재활용품 분리수거 가장 기본적이면서도 중요한 분리수거는 재활용품이에요. 플라스틱, 종이, 유리, 금속 등 다양한 재료들을 올바르게 분리하여 버리는 것이 중요해요. 각 재료에 맞는 재활용함을 사용하거나, 재활용이 가능한 봉투에 담아서 버릴 수 있어요. 재활용품을 버리기 전에는 가능한 한 세척해야 해요. 플라스틱병이나 유리병은 내용물을 비우고 헹구어야 하며...
# Post 54: 문서 저장하기
# 소비요정의 꼼꼼한 소비 라이프♩
# 3주 전
# 16
# 온핌 스틸형 종이컵수거함으로 분리수거를 깔끔하고 간편하게
# 막힘없이 쑥 내려가네요 ^^ 온핌 스틸형 종이컵수거함에 쌓인 종이컵들을 분리수거 할 때는 아래에 있는 손잡이를 당긴 후 쏙 빼주면 깔끔하고 간편한 분리수거가 가능해요 ^^ 여기까지 온핌 스틸형 종이컵수거함 사용후기를 포스팅 해보았는데요, 인테리어를 해치지 않으면서 깔끔하고 간편하게 할 수 있는 종이컵수거함을 찾고계신 분들께 요 제품 추천합니다 ^^
# Post 55: 문서 저장하기
# 원더로우
# 2주 전
# 6
# [음식물분리수거 위반 문자] 절대로 클릭! 하면 안됩니다 이유는?
# #음식물분리수거위반 #스팸문자 #사기문자 최근들어서 자주 이런 광고 및 스팸 문자들이 지속적으로 오고 있네요. 5월12일에도 문자 뭐가 왔나 했더니 이런게 와 있더라구요. 내용은 대략 이렇습니다. [Web 발신] [민원24]음식물 위반신고되어 알려드립니다. 내용확인 : 일단 어? 내가 음식물 잘못 버린게 있나 하고 혹시나 하는 마음에 위에 내용 클릭하면 절대...
# Post 56: 문서 저장하기
# 뽕빠스빠니엘의 블로그
# 5일 전
# 대박. 대통령 기록물 그거 분리수거함에서 찾은분 매불쇼 출연.
# 그걸 분리수거장에서 습득. 씨발 "디올 백"은 어디 갔는지 대통령 기록물이라 공개 못하면서. 책은 막 버려? 대통령 습득 책은 국가 기록물이다. 함부로 버리지 못해. 대박이 매불쇼에... 무슨 의미일까? 김건희 너 죽어라이다. 그양반이 "아크로 비스타" 분리 수거 장에서 책을 가져온것. 그걸 갖고있어. 김건희, 윤대통령 지적 수준을 드러내는 것이다.
# Post 57: 문서 저장하기
# 일상이 여행.꽃내느루
# 2024.03.12.
# 9
# 분리수거하기 참기름 병 분리수거 하기
# 어느 날 참기름 병 분리수거하는 방법을 보고 분리수거를 해야겠다 생각을 했다. 마침 참기름을 다 먹었다. 방앗간에서 구입한 참기름 참기름 병 씻기 준비물: 주방 세제. 베이킹소다.... ♤♤ 3차 참기름 병에서 빨간 뚜껑 분리하기. 뜨거운 물을 사용하여 세척해서 뚜껑이 부드러워져서 쉽게 분리가 되었다. 싱크대에 엎어서 참기름 병 물기 제거하기 세척이 잘 되어서...
# Post 58: 문서 저장하기
# 이스트시큐리티 알약 블로그
# 4주 전
# 2
# [*정부24] 음식물분리수거 위반으로 민원신고되었습니다. 내용확인 : hxxp://cy[.]h****.sbs
# 내용확인: hxxp://hin[.]s***.sbs 4 [*정부24] 음식물분리수거 위반으로 민원신고되었습니다. 내용확인 : hxxp://cy[.]h****.sbs 5 [Web발신](*정부24)법적기준초과로 민원접수 되셨습니다. 접수내용 : hxxp://ba[.]b***.sbs 6 한국 방문이 다가오고 있는데 아직 연락이 안 돼. 네가 필요해, 지금 내 새 LINE ID를 추가해:xi***** 7 [국외발신] 고객님 [관세징수과]...
# Post 59: 문서 저장하기
# 인플부부
# 인플루언서
# 2024.04.03.
# 10
# 우산버리는법 3가지(생활 폐기물 스티커 및 종량제, 우산 분리수거 버리기)
# 저는 여자 힘으로 혼자 해보려고 했는데 전혀 분리되지 않았어요~~~~ 우산 내부만 봐도 우산살과 플라스틱이 서로 얽혀있는 형태로 우산 분리수거를 제대로 하려면 니퍼도 필요하답니다. 혼자 우산 분리수거해 본다고 하다 결국엔 포기. 마지막 세 번째 우산 버리기를 알아볼게요. 우산버리는법, 3번째 종량제 봉투에 버리기 손쉽게 우산버리는법은 세 번째 종량제 봉투에...
# 인플부부의 #재활용분리수거
# 콘텐츠 더보기
# Post 60: 문서 저장하기
# Holiy Holic♡
# 4주 전
# 8
# 스미싱(음식물분리수거 위반) 분석 및 대응
# 예전에 분리수거 한번 잘못해서 딱지뗀적이 있어서...ㅋㅋㅋ 메세지에 포함된 URL 눌러보면 안돼지만 너무 궁금하다 어떤식으로 속일지 일단 PC로 접속해 보기로 하고 바이러스토탈로 조회한번 해본다 클린이네? 사이트를 만든지 얼마 안돼서 클린으로 나올수도 있는거고... 궁금하다 드가즈아~~~~~~~~~~~ 이쁘게 그럴듯하게 만들어 놨네ㅎㅎ...
# Post 61: 문서 저장하기
# RS324J
# 2주 전
# 2
# 음식물 분리수거 위반 민원24 -피싱 경고!!! 절대 누르지 마세요~
# 일어나니 이런 문자가 와있었습니다 [민원24] 음식물 분리수거위반으로 민원접수 되었습니다 응??? 순간 당황했어요 음식물 쓰레기 처리 기계를 사용하지 않고서는 음식물은 따로 버리죠~ 이런 문자를 받게 되면 누구나 가슴 철렁하고 바로 링크를 눌러볼 것 같아요 근데 발신된 번호를 보고는 피싱이구나~알아차렸어요 휴대폰 번호로 올리도 없고 띄어쓰기가 틀린...
# Post 62: 문서 저장하기
# 흰돌하우징
# 2024.04.25.
# 21
# 인천 쓰레기분리수거지붕 시공 캐노피공사 전문
# 흰돌캐노피 쓰레기분리수거장 캐노피시공 흰돌하우징에서는 다양한 캐노피 시공을 하고 있는데요 원하시는 곳에 원하시는 사이즈로 시공하실 수 있습니다 . 상담을 해보시면 바로... 쓰레기 분리수거라 사실은 충분히 설명으로 얘기가 되었을텐데 너무 원하셔서 ㅎㅎ 간단하게 도면을 그렸습니다. 그림보다 더 라운드를 주길 원해서 시공은 살짝 더 라운드 모양으로...
# Post 63: 문서 저장하기
# 마스의 재태크하루
# 2주 전
# 2
# 음식물쓰레기 분리수거 위반 문자가 보이스피싱
# ***-****-**** 귀하께 음식물분리수거 위반으로 신고 접수되었습니다. 우리집은 아파트 음식물분리수거함에 음식물을 버리는데 위반될게 뭐가 있지?? 하고 잠시나마 고민을 했었습니다. 아무리 생각해도 이상해서 알아보니 보이스피싱입니다. 벌써 이문자를 받은 사람들이 꽤 있더군요 혹시라도 이 문자를 받으신다면 링크를 절대 클릭 하지 마세요 하.. 하다하다 이젠...
# Post 64: 문서 저장하기
# 좌충우돌 남매와 소문난 엄마의 알콩달콩 육아 이야기
# 5일 전
# 9
# 해피코 필웰 스탠드 틈새 2단 분리수거함, 주부 맘에 쏙!
# 이사와서 정말 잘 샀다 싶은 건 바로 해피코 필웰 스탠드 틈새 2단 분리수거함이에요. 해피코 필웰 스탠드 틈새 2단 분리수거함 재활용 분리수거함으로 딱! 이에요. 해피코 필웰 스탠드 틈새 2단 분리수거함 재활용 분리수거함으로 딱! 이에요. 해피코 필웰 스탠드 틈새 2단 함 재활용 함으로 딱! 이에요. 해피코 필웰 스탠드 틈새 2단 함 재활용...
# Post 65: 문서 저장하기
# 꼼꼬미
# 인플루언서
# 2024.03.15.
# 29
# 다이소 분리수거함 재활용 분리수거거치대 봉투 사이즈
# 뚜껑이 달려있어 밀폐효과도 있어서~ 여름철에 사용하기도 좋겠다라고요 사각형으로 입구가 넓은 편이라 쏙쏙~ 재활용품 분리하기 아주 딱이더라고요! 멀리서~ 골인시키는 맛^^ 분리수거함에서 봉투를 뺄 때는 옆으로 쓱~ 빼서 사용하고 있어요 처음 함을 2개 구매했는데~ 사용하다보니 아주 매력적으로 몇개를 더 구매하게 되었어요! 기둥이 나름 튼튼하고...
# 꼼꼬미의 #재활용분리수거
# 콘텐츠 더보기
# Post 66: 문서 저장하기
# 가온디자인 공식 블로그
# 2024.04.02.
# 재활용품의 다양한 종류와 분리수거 방법 알아보기
# 재활용품의 다양한 종류와 분리수거 방법 알아보기 재활용품은 종류에 따라 분리수거 방법이 다양합니다. 일반적으로 종이류, 금속류, 유리병 등이 대표적인 재활용품으로 분리수거됩니다. 종이류는 신문지, 책, 상자 등으로 구분되며 플라스틱류는 병, 비닐봉지 등이 있습니다. 금속류는 알루미늄 캔, 철캔, 철류 등이 해당되며 유리병은 깨지지 않은 상태에서 배출해야...
# Post 67: 문서 저장하기
# 꼬비가족의 생활 속 경제,리뷰 이야기
# 2주 전
# 음식물분리수거 위반신고 문자 주의
# 음식물 분리수거 위반...이런게 자꾸 뜨길래 뭔가 했다. 알고 봤더니 피싱 문자였던 것. 주위에 꼭 알려줬으면 한다. 혹시 아래와 같은 문자가 온다면 클릭하지 말아야 한다. 아파트에서 음식물 쓰레기 별도로 통에 버리는데, 이런 걸 보낼 리 없다. 혹시 개인주택, 빌라 등이어도 민원24에서 문자를 보냈는지 확인할 때는 링크를 들어가지 말고, 본인이 민원24를 들어가서...
# Post 68: 문서 저장하기
# 스토리가 있는 단정한 집
# 2024.03.11.
# 16
# 우산 버리는법 재활용 분리수거 될까
# 고철은 자동 분류되어 별도의 처리 과정을 거친다고 해요) 02 최대한 소재 분리 후 각각 분리수거하는 방법 03 너무 크거나 긴 우산의 경우 스티커를 부착해 대형 생활폐기물로 버리는 방법 결론적으로 우산은 비닐 고철 합성섬유 알루미늄 플라스틱 등 여러 가지 소재로 만들어지기에 재활용이 되지 않는답니다 각각 소재에 맞는 우산 버리는법 기억해 두면 좋을 것 같아요 :-)
# Post 69: 문서 저장하기
# 행복한 상상*^*
# 2024.03.13.
# 12
# 프로메이드 가정용 재활용 분리 수거함 내돈내산
# 그란데 정리함 재활용 분리 수거함은 분리가 가능합니다. 그래서 분리 수거함인가요? 서랍을 꺼내어 쓰레기 정리를 할 때 편리하게 할 수 있습니다. 다양한 수납공간이 있는것도 좋아요. 프로메이드 그란데 가정용 재활용 함중에서 가장 만족스러운 점은 상단에 수납공간이 있다는 것입니다. 수납 공간을 만들어 내기 위한 제품 개발의 흔적이 보입니다. 재활용...
# Post 70: 문서 저장하기
# Wednesday Story
# 2024.03.25.
# 24
# 다이소 대용량 적재수납박스 ( 재활용품 정리함, 분리수거함 )
# 5cm 높이 28cm 2단계로 뚜껑이 고정되는 스타일 넣고 빼기 쉬운 구조에 열어두고도 사용이 가능해서 물품을 깔끔하게 보관하거나 분리 수거함으로 사용 가능 이렇게 확 열리고 닫으면... 그러다가 울집 아들이 집에 재활용품 넣는 바구니에서 하기 힘들다고 해서 이 다이소 대용량 수납박스를 가정용 함으로 쓰기로 했다. 이렇게 층층이 적재가 되니까...
# Post 71: 문서 저장하기
# 쥬뚱바월드
# 2024.03.15.
# 20
# 페블 3단 분리수거함 추천
# 3번째 분리함을 앞에서 뒤로 껴주기 이거 껴줄 때 아래 동그라미 친 부분처럼 딱 껴질 때 까지 이 맞물리게 껴줘야 함!! step 4. 젤 윗칸에 손잡이 달면 끗 완성!! 여기서 깰끔하게 쓸 사람은 스티커 안붙이고 사용해도 좋고~ 취향대로 하면 됨 난 사실 스티커 안붙이고 쓰고 싶었는데 스티커 안붙여두면 밤구가 헷갈려서 막 쑤셔넣을까봐 스티커를 붙이기로.. 함이...
# Post 72: 문서 저장하기
# 생활 속 리빙 이야기
# 2024.04.05.
# 재활용 종류별 분리수거 방법과 환경 보호의 중요성
# 또한 잘 분리수거된 재활용품은 재활용 시설에서 쉽게 분리되어 처리되기 때문에 자원의 효율적인 이용이 가능합니다. 환경 보호를 위해서는 개인의 노력이 꼭 필요합니다. 일상 생활에서 쉽게 실천할 수 있는 재활용 종류별 는 우리의 미래를 위한 작은 노력으로 이어지는 중요한 일입니다. 따라서 우리 모두가 자원을 아껴야 하고 환경을 보호하기 위해 재활용에...
# Post 73: 문서 저장하기
# 돈 무리, 비 해피 ◡̈
# 2024.03.04.
# 10
# 재활용 분리수거함 셀리나즈 넉넉해서 편해요
# 셀리나즈 가정용 대용량 분리수거함을 사용하고 이 내부에서 몇 개 분리해서 분리수거를 진행하고 있어요. 1인 가구라 그렇게 많이 쓰레기가 나오지 않는 편이라서 이 분리수거함... 있었고 분리 수거함이 작으니까 버릴 때 마다 쏟아지는 경우가 있었는데요. 이러한 불편함을 최소화할 수 있었어요. 저는 쓰레기가 많이 나오지 않아서 이 수거함 하나에 종이/비닐을 담아서...
# Post 74: 문서 저장하기
# 깍쟁얌치
# 인플루언서
# 2024.03.27.
# 11
# 배달용기 세척 수월한 기름때 제거 방법 재활용 분리수거 완료
# 플라스틱 재활용 분리수거하기 위해 배달용기 세척을 한 깍쟁얌치입니다. 기존에는 베이킹소다를 이용해서 기름때 제거를 했는데 요즘에는 그보다 조금 더 수월한 방법으로 완료하고... 플라스틱 재활용 분리수거하기 하얗게 변신 완료 틈새 사이도 깔끔! 처음과 다르게 하얗게 깨끗해진 모습을 보니 개운하더라고요. 그냥 버렸으면 찜찜했을 텐데 이러한 과정을 잊지 않고...
# 깍쟁얌치의 #재활용분리수거
# 콘텐츠 더보기
# Post 75: 문서 저장하기
# 앱테크로 커피한잔
# 2024.04.07.
# 18
# 티끌 모아 앱테크 153탄:리사이클팜/만보기, 분리수거로 돈버는앱
# 이 앱은 2024년 3월 4일 출시한 앱으로 만보기와 분리수거로 돈 버는 앱입니다. 돈 버는 방법은 크게 5가지로 1. 출석체크 10원 2. 영상 광고(하루 10번 50원) 3. 만보기(200원) 4. 분리수거(최대 300원/평균 5원) 5. XP 부스터 (체험 9원×7개=63원, 보러 가기 10원×7개=70원) 133원입니다. 계산해 드릴게요. 10+50+200+15+133= 하루 408원을 벌 수 있는 앱. 2시간에 한...
# Post 76: 문서 저장하기
# PC Geek's
# 2주 전
# 4
# 폐의약품 분리수거: 먹고 남은 처방약, 유효기한이 지난 상비약 등
# 쓰레기 분리수거보다 더 신경써서 해야 하는 것이 약 분리수거. 당신이 사용한 항생제가 당신이 죽을 때까지 효과가 있으려면. 지금도 하수구와 하천에서 항생제 성분이... 가까운 약국이나 보건소의 폐의약품 수거함에 버리기. 가루약은 그대로 모아 배출. 연고, 스프레이, 천식용 흡인제, 안약 등은 포장 그대로 배출 알약은 봉지를 하나...
# Post 77: 문서 저장하기
# 꼬치의품격 공식블로그
# 5일 전
# 7
# 두유팩 분리수거 어떤 재질이냐에 따라 분류해야 해요
# 예전에는 멸균팩이랑 종이팩을 합친 후 수거를 해왔지만 요즘은 재활용 용도가 달라져서 분리를 두 가지로 나누어서 합니다. 두유팩과 우유팩은 분리수거를 각각 다르게 하셔야 합니다. 두 가지 팩은 전혀 다른 개념으로 재활용이 이루어집니다. 멸균팩으로 이용된 두유팩은 알루미늄과 황색 펄프가 포함되어 있어서 재활용으로 버리게 되면 품질이나 백색도를 떨어뜨리기...
# 뽁뽁이분리수거 환경을 생각한다면 올바르게 실천해 보세요
# Post 78: 문서 저장하기
# Ruseum
# 3일 전
# 3
# 프링글스 통 분리수거
# 바닥과 분리할 수 있다. 이렇게 하면 플라스틱 뚜껑은 플라스틱으로 몸체 부분은 일반 쓰레기로 바닥 알루미늄은 알루미늄으로 분리배출이 가능하다. 요즘 프링글스 사이즈가 새삼 작아 보여 프링글스 인스타그램에 들어가 보니 네?? 네??? 저기요... 플라스틱 뚜껑은요?? 알루미늄 바닥은요??? 요것도 좀 없애든가 분리하기 쉽게 바꿔주던가... 하시지요?? 네??...
# Post 79: 문서 저장하기
# 단비마켓-공구/특가
# 2024.04.08.
# 특가공구) 깔끔한 다용도 분리수거/수납함!
# 적층으로 공간활용이 가능하고 전용비닐로 깔끔하게 사용이 가능해요 손잡이가 있어서 분리배출도 편하구요 분리수거함 대신에 수납함으로도 사용 가능하답니다. 거실 화장실 세탁실 어디에도 너무 깔끔하고 예쁘게 어울리는 디자인이에요 아이들 방 수납공간으로도 부족함 없답니다. 공구특가로 우리집 분위기 깔끔하고 예쁘게 꾸며보세요~ /배송 무료배송 주말제외1...
# Post 80: 문서 저장하기
# 세상 모든 이야기
# 3주 전
# 3
# 위험성과 분리수거에 대한 주의 사항
# 유통기한 지난 화장품 유통기한 지난 화장품 유통기한이 지난 화장품 분리수거 방법 유통기한이 지난 화장품을 분리수거하는 방법에 대해 자세히 알아보겠습니다. 이러한 분리수거 방법을 따라 화장품을 올바르게 처리하여 환경을 보호하는 데 도움이 됩니다. 유통기한 지난 화장품을 사용하면 안 되는 이유는 다양합니다. 그 중에서도 눈에 직접적으로 사용되는 화장품은...
# Post 81: 문서 저장하기
# 하루레나
# 인플루언서
# 2024.03.12.
# 9
# 배달용기세척 후 재활용 분리수거까지 바로바로
# 예전에는 배달음식을 주문하면 1회용 용기가 아닌 그릇에 담아다 주고 다시 수거해갔잖아요. 그때도 항상 이렇게 제대로 설거지해서 현관 밖 엘리베이터 문 근처에 봉지에 담아 내놓곤... 짜장 소스는 아주 말끔하게, 짬뽕 국물은 조금 흔적이 남았는데 부엌 창문에 비스듬히 기대 세워두고 하얗게 되면 분리배출하려고요. 배달용기 재활용 는 며칠만...
# 하루레나의 #재활용분리수거
# 콘텐츠 더보기
# Post 82: 문서 저장하기
# betty
# 인플루언서
# 3주 전
# 상하이의 쓰레기 분리 수거
# 취区 마다 다르겠지만 내가 살았던+ 살고 있는 동네는 쓰레기 분리수거를 버리는 사람이 직접하지 않는다. 그냥 버리면 담당자가 알아서 분리하고 처리해서 쓰레기 처리에 대한 부담이 없다. 음식물 쓰레기도 그냥 버림. 담당자는 하루에 두번 치워주고 정리한다. 배운티 낸다고 해서 버리면 큰일난다. 감히.. 담당자의 업무를 뺏을 수 없다…가 상하이 스타일 !!...
# Post 83: 문서 저장하기
# ◈상암DMC사무실,상암동사무실◈JMK.02-373-5600
# 6일 전
# 6
# 나무도마 버리기 분리수거 해야 할까?
# 나무도마 버리기 분리수거 해야 할까? 안녕하세요. 오늘은 나무도마 버리는법에 대해 알아보도록 하겠습니다. 요즘에는 스테인리스로 만들어진 도마가 많은 인기를 끌고 있습니다.... 나무도마 외에도 실리콘으로 만들어진 도마도 나무도마와 똑같은 방법으로 처분을 해주시면 되고 플라스틱으로 된 도마는 플라스틱 수거함으로 배출을 해주시면 됩니다. 나무도마를 생활...
# Post 84: 문서 저장하기
# 설수맘
# 인플루언서
# 4주 전
# 8
# 유리그릇 추천 버리는법 분리수거 전자렌지
# 법은 수거할 때 사람을 다치게 할 수 있으므로 쓰레기봉투가 찢어지지 않게 신문지 등으로 여러 번 감싼 후 버려주세요 플라스틱 식기는 깨끗하게 세척하신 후 플라스틱으로 분리수거해 주시고 방짜 유기, 스테인리스, 놋그릇 등 도 재활용 가능하니 세척하신 후 고철로 분리하여 해 주세요 유리그릇 전자렌지 유리그릇 전자렌지 활용방법은 해도 되는 것, 안 되는...
# 설수맘의 #그릇추천
# 콘텐츠 더보기
# Post 85: 문서 저장하기
# 깨끗한 곳 깨끗한 사람, 청소전문 클리어인
# 1일 전
# 8
# 분리수거 과태료 올바른 배출이 중요해요
# 재활용품과 일반 쓰레기가 섞어서 수거되면 재활용을 할 수 있는 제품들이 많이 없어지면서 처리하는 데 사용되는 비용도 많아지게 되는데요. 그래서 정부에서는 분리배출 규정을 정하고 위반 시 분리수거 과태료를 부과하고 있는 이유입니다. 의 뜻은? 란 각 물질의 재질마다 분류해서 수집하는 것을 의미합니다. 우리가 를 꼭 해야 하는 이유는...
# Post 86: 문서 저장하기
# 각종폐기물, 폐가구, 쓰레기 방문수거는 힘쎈 친구들
# 1일 전
# 15
# 의자 분리수거가 가능한지 궁금하셨던 분들을 위한 정보
# 가전은 수거 서비스를 신청할 수 있지만 의자는 어떻게 버려야 하는지 잘 모르는 분들이 많습니다. 의자를 버려야 할 때 사람들은 고민을 하게 됩니다. 가구로 분류되긴 하지만 크기가... 분리해서 재활용하는 것도 불가능합니다. 의자는 품목이 아니기 때문에 생활 폐기물 스티커를 부착하여 처리해야 합니다. 의자 대형 생활 폐기물로 신고한 다음...
# Post 87: 문서 저장하기
# path-of-blessing님 블로그
# 2일 전
# 38
# 페트병 분리수거, 라벨 쉽게 제거 난이도 비교 후기
# 오늘의 콘텐츠는 분리수거를 위하여 페트병 비닐을 벗기는 작업이다! 오늘은 분리수거를 위한 작업이다! 약 한 달 동안 이렇게나 많은 페트병을 사용하였다니... 되도록이면 텀블러를... 로레타는 중요하게 뜯지 않아도 분리배출이 가능한 제품이므로 재활용이 최우수 등급!!! 이런 제품을 역시 자주 사 먹어야 한다~~ 다음의 제품은 새싹보리 과연 시간은? 14초가 걸리는...
# Post 88: 문서 저장하기
# 류작가
# 인플루언서
# 3주 전
# 15
# 옷걸이 버리는법 철사 나무 재활용 분리수거 방법
# 재활용 분리수거 하기 쉬운 거에요 따로 분리할 것 없이 고철류 ( 캔류 )로 버려주시면 됩니다 전체 플라스틱 한가지 재질로 되어 있는 것은 역시나 버리는 방법이 쉬워요 플라스틱으로 분리수거 해주면 되거든요 정장용 고리 부분은 철제로 되어 있고 몸통은 플라스틱으로 된 굵은 것은 철과 플라스틱을 재질별로 분류해서 해야되는데요 시도를 해보았으나.....
# 류작가의 #옷걸이버리는법
# 콘텐츠 더보기
# Post 89: 문서 저장하기
# 현.주.하 맘의 제로웨이스트
# 1주 전
# 7
# 식용유 올리브유 기름병 오일병 분리수거하기
# 그렇게 젓가락을 지렛대 삼아 뚜껑을 분리하셨다면 이제 분리수거를 위한 재질별로 나눠주기는 완료가 된 상태인데요. 이제는 오일병을 최대한 깨끗하게 용기를 세척해 줄 일만이 남게 되었답니다. 저 같은 경우에는 본체에 설거지 세제를 물과 함께 넣고 흔들어준 뒤 하루 동안 방치해 두는데요. 그다음 날 미지근한 물로 몇 번 더 헹궈주면 어느 정도 기름기가 제거가...
# 은박보냉백 아이스팩 분리수거 하는 방법
# 비닐우산 제대로 분리수거 해보기
# Post 90: 문서 저장하기
# 딸바보이군의 단정한 리빙
# 8시간 전
# 8
# 비닐 분리수거 방법 과자 비닐류 재활용, 주의사항
# 비닐 분리수거 방법, 비닐류 재활용, 주의사항... 1. 비닐 종류 비닐에는 주변에서 흔히 볼 수 있는 과자, 라면, 택배 봉지 등 다양한 종류가 있지만 투명이든, 불투명이든 비닐류는 모두 재활용으로 분리배출이 가능합니다. 물론 몇 가지 조건이 있다는 사실은 아래 주의사항에 첨부할게요. 2. 배출 표시, 방법 재활용이 가능한 캔류와 플라스틱, 비닐류 등... 포장 부분을...
# Post 91: 문서 저장하기
# 봉봉레시피
# 인플루언서
# 3일 전
# 13
# 바나나껍질 일반쓰레기 분리수거 바나나 냉동 보관방법 기간
# 바나나껍질 분리수거 아침 대용으로 먹기에 좋고 가성비도 좋아 집에 바나나가 떨어질 때가 없는데 금세 익어서 껍질이 까맣게 변하곤 해요. 하루 소비량이 있으니 썩게 놔둘 수도 없고 곤란할 때가 있어요. 오늘은 바나나 보관법 냉동보관하는 방법과 보관 기간 자세히 알려드릴게요. 바나나껍질 바나나 먹고 나면 고민되는 하나는 껍질은 일반쓰레기인지...
# 봉봉레시피의 #바나나껍질음식물
# 콘텐츠 더보기
# Post 92: 문서 저장하기
# 소소제니의 해외상표, 노코드, 여행 이야기
# 2일 전
# 8
# 우유팩 분리수거 스마트한(?) 방법
# 우유팩은 종이와는 별도로 분리해야 하는 것 아시나요? 하지만 지역별로 분리수거시 우유팩을 수거해주는 곳도 있고 아닌 곳도 있어서 우유팩 분리수거가 생각보다 쉽지만은 않습니다. 오늘은 우유팩 분리배출 전 해야하는 조치와 자세한 방법에 대해 정리해보려고 합니다. 우유를 매일 먹는 건 아니지만 가끔 먹다보니 그동안 분리만 해놓고 재활용하지...
# Post 93: 문서 저장하기
# 파주 연세구치과의원
# 공식
# 6일 전
# 동영상
# 7
# 은박지 분리수거 가능할까? 일반 쓰레기 vs 캔
# 은박지 분리수거 가능할까? 일반 쓰레기 vs 캔 안녕하세요. 연세구치과입니다. 날씨가 무척 좋은 5월입니다. 근래에 들어 많이 더워지기는 했으나, 그래도 아직까지는 바람도 많이 불고... 그냥 일반 쓰레기로 버리면 되는 것 아닌가 싶으면서도, 알루미늄으로 제작이 된 만큼 은박지 를 해야 할 것 같다고 생각이 들기도 하는데요. 여기에 대한 답은 상태에 따라...
# Post 94: 문서 저장하기
# 하나씩 채워보는 살림도감
# 2주 전
# 9
# 소재별 텀블러 버리는 법 분리수거 가능한지 알아보기
# 이럴때는 플라스틱으로 분리수거 하시면 되겠습니다. 뚜껑 고무패킹 다만 뚜껑부의 고무패킹은 따로 분리해서 종량제에 담아 배출하시면 되겠습니다. 복합소재의 텀블러 버리는 법 복합소재 복합적인 소재로 이루어진 텀블러도 집에 있습니다. 외부는 플라스틱이고 내부는 스테인레스, 뚜껑은 고무 소재를 사용해 한 개의 텀블러에 여러 복합적인 소재로 이루어진...
# 빨대 분리수거 일반쓰레기로 배출?
# Post 95: 문서 저장하기
# 뿌니맘의 생활이야기
# 4일 전
# 13
# 수박껍질 일반쓰레기 vs 음식물쓰레기 분리수거 수박 쉽게 자르는법 보관법
# 올해 첫 수박을 구매했는데, 수박껍질 쓰레기 분리수거와 자르는법 및 보관법을 공유드려보려고 해요. 쉽게 자르는 방법 자르기 전에 꼭 세척한 후 잘라주세요. 뿌니맘은 베이킹소다를... 배출 시 껍질을 잘게 잘라서 음식물 쓰레기로 해 주시면 되구요, 단! 수박씨는 일반쓰레기라고하니 참고해 주세요. 혹시라도 수박 껍질을 일반쓰레기로 배출 시에는 과태료가...
# Post 96: 문서 저장하기
# ****원일LED 스크린전광판*******010-4465-5732***
# 6일 전
# 8
# 유리병 버리는법 확실한 분리수거법 알아보기
# 페트병은 유리병과는 다르게 뚜껑을 별도로 분리할 필요는 없습니다. 페트병 뚜껑은 플라스틱 재질로 파쇄해서 선발하는 과정에서 자동으로 분리됩니다. 오늘은 일상생활에서 종종 혼동하는 분리수거에 대해서 알아봤는데요! 공유해 드린 내용을 참고하셔서 올바른 방법으로 하여 환경보호에 앞장서시길 바랍니다. 감사합니다!
# Post 97: 문서 저장하기
# 후후의 리뷰
# 1일 전
# 33
# 무지개봉봉 레이어 휴지통 업소용 사무실 가정집 대형 분리수거 일반 쓰레기통 60L 40L
# 배송은 평일 기준으로 낮 12시 이전에 구매 시 당일 출고가 돼서 다음날 받아볼 수 있는 빠른 배송이었고 제품도 파손없이 안전하게 도착했어요:) 대형쓰레기통 사이즈는 20L, 40L, 60L 3가지 사이즈로 구성되어 있고 일반 종량제 봉투를 넣어 일반쓰레기를 담기 좋은 20L, 사물실이나 가게, 저처럼 통으로 사용하기 좋은 40L와 60L까지 사이즈가 넉넉해서 용도에 맞게...
# Post 98: 문서 저장하기
# 노마드잭슨의 N프로젝트
# 2주 전
# 45
# 가정용 와이드 3단분리수거함 이즈리빙 30L 대용량 써봄
# 내통을 분리할 수 있어서 재활용버리기도 편하면서도 위생적으로 세척해서 사용할 수 있어서 신혼집 베란다에 필요한 제품이구나 싶었다 적층으로 위로 쌓아서 보관할 수 있어서 부피차지도 다른것보다 덜한 것 같고 병렬이 아닌 직렬로 하다보니 안정감있게 함을 사용할 수 있어서 가정용 3단함 찾으시는 분들이라면 편하게 쓸 수 있을 것 같다...
# Post 99: 문서 저장하기
# 잇플레이로그
# 4일 전
# 12
# 모노플랫 3단 가정용 분리수거함 쓰레기통 내돈내산 후기
# 원터치 개폐방식이라 터치 한번으로 열고 닫는게 쉬워요 손잡이도 쓰레기통마다 달려있어 개별적으로 분리 가능해서 세척도 편하게 하실 수 있어요 깔끔한 디자인에 활용도도 좋은 모노플랫 3단 분리수거함 쓰레기통 내돈내산 후기였습니다 내돈내산 리뷰 #함 #쓰레기통 #모노플랫 #대 #쓰레기휴지통 #가정용 #가정용쓰레기통
# Post 100: 문서 저장하기
# 라이프 가(이)드
# 2일 전
# 6
# 프리이팬(후라이팬) 버리기, 분리수거하는 방법과 교체시기
# 스텐 프라이팬 출처 : 나무위키 무쇠팬 출처: 나무위키 사용방법이 까다롭고, 고가의 제품이지만 잘 길들이면 오랫동안 사용할 수 있어서 요리 잘하시는 분들은 꼭 하나씩 갖고 계십니다 저는 없음^^ 프라이팬 분리수거 방법 프라이팬은 캔류(철)로 구분되어 가능합니다. 음식물 깨끗히 닦아내기 플라스틱 손잡이 등 분리 가능한 것들 분해하기 캔류 / 캔류(철)로...

# %% [markdown]
# ---

# %%
reviews = []

# %%
# 다시 페이지 로드
soup=BeautifulSoup(driver.page_source,'html.parser')

# 모든 댓글 요소를 찾습니다.
spans = soup.find_all("a", class_="dsc_link")

for span in spans:
    reviews.append(span.text)
    
df = pd.DataFrame(reviews, columns=["Review"])
df
# Out:
#                                                 Review
# 0    한눈에 쉽게 알아볼 수 있어서 쓰레기 분리 투입할 때 편합니다. 그리고 박스 2개 ...
# 1    주민센터 아이스팩 분리수거함 아마 가까운 관할 주민센터, 행정복지센터 방문하시면 입...
# 2    #음식물분리수거위반문자 #스미싱주의 #스팸문자 왓씨~아침에 눈뜨자마자 문자 잘 못 ...
# 3    올바르게 프라이팬 버리기 실천해 보아요~ 금속으로 된 단일 소재 캔 금속으로 분리수...
# 4    (대학내일 독자들 말고 교수님 어릴 때) 하지만 놀랍게도 지금, 플라스틱 공병을 모...
# ..                                                 ...
# 115  오렌지껍질 일반쓰레기 분리수거 방법 오렌지껍질 활용 오렌지는 기분 좋은 상큼함과 새...
# 116  분기수거를 하는 제품 가운데 옷걸이가 고민이 되는데요. 재질이 하나가 아니고 여러개...
# 117  먹고 분리수거는 필수!⭐️ 위치는 공영화장실 옆에 위치하고 있어요 이쪽에 있고, 여...
# 118  요게 지자체마다 다른 것 같은데 대충 원리는 비슷~ 제가 거주하는 마포구는 '오늘의...
# 119  캠핑하다보면 플라스틱, 캔, 병 등 이것저것 분리해서 쓰레기 정리해야 할 때가 많은...
#
# [120 rows x 1 columns]

# %%
df.to_csv('reviews.csv', index=False, encoding='utf-8-sig')

# %%
df.iloc[0]['Review']
# Out:
# '한눈에 쉽게 알아볼 수 있어서 쓰레기 분리 투입할 때 편합니다. 그리고 박스 2개 구매 이상 구매하면 전용 비닐봉지(10장)이 제공되어서 좋았습니다. 물론 비닐봉지 없이 사용해도 되기는 한데요. 저는 비닐봉지에 담아서 분리수거를 하기 때문에 맞는 사이즈의 봉투를 구입하려고 알아보고 있었거든요. 그런데 이렇게 챙겨서 보내 주니깐 좋더라고요. 비닐은 내통에 넣고... '

# %%
# 텍스트 전처리 및 키워드 추출
def preprocess_text(text):
    # 특수 문자 제거
    text = re.sub(r'[^\w\s]', '', text)
    return text

# 한글 형태소 분석기 Okt를 사용하여 명사만 추출
okt = Okt()

def extract_keywords(text):
    words = okt.nouns(text)
    return words

# 모든 리뷰의 키워드를 추출하여 리스트에 저장
all_keywords = []
for review in df['Review']:
    preprocessed_text = preprocess_text(review)
    keywords = extract_keywords(preprocessed_text)
    all_keywords.extend(keywords)

# 키워드 빈도수 계산
keyword_counts = Counter(all_keywords)

# 가장 많이 나오는 키워드 10개 추출
top_keywords = keyword_counts.most_common(100)

# 결과를 데이터프레임으로 변환
top_keywords_df = pd.DataFrame(top_keywords, columns=['Keyword', 'Frequency'])

def visualize_word_cloud(top_keywords, filename):
    if len(word_counts) > 0:
        wc = WordCloud(font_path='malgun', width=400, height=400, scale=2.0, max_font_size=250)
        gen = wc.generate_from_frequencies(top_keywords)
        plt.figure()
        plt.imshow(gen)
        plt.axis('off')
        plt.savefig(filename, bbox_inches='tight')
    else:
        print(f"No words found for {filename}")

# 결과 출력
print(top_keywords_df)

# 웹드라이버 종료
driver.quit()
# Out:
#    Keyword  Frequency
# 0     분리수거        228
# 1       분리         86
# 2        함         79
# 3      쓰레기         70
# 4      재활용         68
# ..     ...        ...
# 95      지난          8
# 96      센터          7
# 97      한번          7
# 98      지금          7
# 99      발신          7
#
# [100 rows x 2 columns]

# %%
top_keywords_dict = dict(top_keywords)

# %% [markdown]
# ---

# %%
import numpy as np
from PIL import Image, ImageDraw, ImageFont
from wordcloud import ImageColorGenerator

# image_names = ['그림1.png']
image_names = ['그림2.png']
# image_names = ['그림3.png']


for image_name in image_names:
    target_image = Image.open(image_name)
    try:
        mask = Image.new('RGB', target_image.size, (255, 255, 255))
        mask.paste(target_image, target_image)
        mask = np.array(mask)
        print("mask 변환 방식 1")
    except:
        print(image_name)
        mask = np.array(Image.open(image_name))
        print("mask 변환 방식 2")
    finally:
        plt.imshow(target_image)
        plt.show()
# Out:
# mask 변환 방식 1

# %%
from wordcloud import WordCloud
from PIL import Image, ImageDraw, ImageFont

# count = Counter(word_list)
font_path = 'NanumBarunGothic.ttf'

wc_rey = WordCloud(
    font_path = font_path,
    # mask=moon_mask,
    mask=mask,
    background_color="white"
)

# %%
wc_rey = wc_rey.generate_from_frequencies(top_keywords_dict)

plt.figure(figsize=(8, 8))
plt.imshow(wc_rey, interpolation='bilinear')
plt.axis("off")
plt.show()
plt.savefig(f"{keyword}_wordcloud.png", bbox_inches='tight')

# %% [markdown]
# ---

# %%
reviews_df = pd.read_csv('reviews.csv')
print(reviews_df)

# %%
polarity_df = pd.read_csv('polarity.csv')
print(polarity_df)

# %%
negative_keywords = polarity_df[polarity_df['max.value'] == 'NEG']['ngram'].tolist()

# %%
# 전처리 함수: 리뷰 텍스트에서 불필요한 문자 제거 및 소문자 변환
def preprocess_text(text):
    text = re.sub(r'[^\w\s]', '', text)  # 특수 문자 제거
    text = text.lower()  # 소문자 변환
    return text

# 각 리뷰에서 부정적 키워드 추출 함수
def find_negative_keywords(review):
    tokens = preprocess_text(review).split()
    return [token for token in tokens if token in negative_keywords]

# 부정적 키워드 추출 적용
reviews_df['negative_keywords'] = reviews_df['Review'].apply(find_negative_keywords)

# 부정적 키워드를 포함한 리뷰 필터링
negative_reviews = reviews_df[reviews_df['negative_keywords'].apply(lambda x: len(x) > 0)]

# 부정적 키워드 평탄화
flat_negative_keywords = [keyword for sublist in negative_reviews['negative_keywords'] for keyword in sublist]

# 가장 빈번한 부정적 키워드 출력
negative_keywords_counts = Counter(flat_negative_keywords).most_common(10)

# 결과 출력
print("분리수거의 어려움을 나타내는 주요 키워드:", negative_keywords_counts)

# 결과 저장
# negative_reviews.to_csv('/mnt/data/negative_reviews.csv', index=False, encoding='utf-8-sig')
